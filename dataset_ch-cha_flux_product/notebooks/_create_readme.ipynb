# %%
import os
from pathlib import Path
from diive.core.io.filereader import search_files

notebooks = search_files(searchdirs="./", pattern="*.ipynb")
notebooks = [n for n in notebooks if ".ipynb_checkpoints" not in str(n)]
notebooks = [n for n in notebooks if "x-" not in str(n)]
notebooks = [n for n in notebooks if "tests" not in str(n)]
notebooks = [n for n in notebooks if not str(n.stem).startswith("_")]
  
chapter = ""

with open("README.md", 'w') as f:
    f.write("# Notebook overview\n")
    
    for nb in notebooks:   
        
        rel_filepath = nb.parent
        this_chapter = rel_filepath        
        
        if this_chapter != chapter:
            chapter = this_chapter
            f.write(f"\n\n## {chapter}\n")
            
        file_extension = nb.suffix      
        filename = nb.name
        filename_noext = nb.stem               
        filelink = rel_filepath / filename_noext
        link = f"- [{filename}]({filelink})\n"
        f.write(link)               
        print(link)                                            

print(f"\nLinks generated and saved to {output_markdown}")
# Out:
# - [01_L0_merge_output_to_parquet.ipynb](00_L0_checks\01_L0_merge_output_to_parquet)
#
# - [02_L0_timelags_check.ipynb](00_L0_checks\02_L0_timelags_check)
#
# - [03_L0_winddir_check.ipynb](00_L0_checks\03_L0_winddir_check)
#
# - [LW_IN_T1_2_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\LW_IN_T1_2_1_2021-2023)
#
# - [PA_GF1_0.9_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\PA_GF1_0.9_1_2021-2023)
#
# - [PPFD_IN_T1_2_2_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\PPFD_IN_T1_2_2_2021-2023)
#
# - [RH_T1_2_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\RH_T1_2_1_2021-2023)
#
# - [SW_IN_T1_2_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SW_IN_T1_2_1_2021-2023)
#
# - [SWC_GF1_0.05_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.05_1_2021-2023)
#
# - [SWC_GF1_0.15_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.15_1_2021-2023)
#
# - [SWC_GF1_0.1_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.1_1_2021-2023)
#
# - [SWC_GF1_0.2_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.2_1_2021-2023)
#
# - [SWC_GF1_0.3_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.3_1_2021-2023)
#
# - [SWC_GF1_0.4_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.4_1_2021-2023)
#
# - [SWC_GF1_0.5_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_GF1_0.5_1_2021-2023)
#
# - [SWC_LOWRES_GF1_0.75_3_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\SWC_LOWRES_GF1_0.75_3_2021-2023)
#
# - [TA_T1_2_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TA_T1_2_1_2021-2023)
#
# - [TS_GF1_0.025_2_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.025_2_2021-2023)
#
# - [TS_GF1_0.04_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.04_1_2021-2023)
#
# - [TS_GF1_0.05_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.05_1_2021-2023)
#
# - [TS_GF1_0.15_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.15_1_2021-2023)
#
# - [TS_GF1_0.1_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.1_1_2021-2023)
#
# - [TS_GF1_0.1_2_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.1_2_2021-2023)
#
# - [TS_GF1_0.25_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.25_1_2021-2023)
#
# - [TS_GF1_0.2_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.2_1_2021-2023)
#
# - [TS_GF1_0.2_2_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.2_2_2021-2023)
#
# - [TS_GF1_0.3_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.3_1_2021-2023)
#
# - [TS_GF1_0.4_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.4_1_2021-2023)
#
# - [TS_GF1_0.5_1_2021-2023.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_GF1_0.5_1_2021-2023)
#
# - [TS_LOWRES_GF1_0.05_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.05_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.1_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.1_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.2_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.2_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.3_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.3_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.4_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.4_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.5_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.5_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.6_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.6_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_0.75_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_0.75_3_2021-2024.09)
#
# - [TS_LOWRES_GF1_1_3_2021-2024.09.ipynb](10_METEO\11_meteoscreening_diive_2021-2023\TS_LOWRES_GF1_1_3_2021-2024.09)
#
# - [LW_IN_T1_2_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\LW_IN_T1_2_1_2024)
#
# - [PA_GF1_0.9_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\PA_GF1_0.9_1_2024)
#
# - [PPFD_IN_T1_2_2_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\PPFD_IN_T1_2_2_2024)
#
# - [PREC_RAIN_TOT_GF1_0.5_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\PREC_RAIN_TOT_GF1_0.5_1_2024)
#
# - [RH_T1_2_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\RH_T1_2_1_2024)
#
# - [SW_IN_T1_2_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\SW_IN_T1_2_1_2024)
#
# - [SWC_GF1_0.05_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\SWC_GF1_0.05_1_2024)
#
# - [SWC_GF1_0.2_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\SWC_GF1_0.2_1_2024)
#
# - [SWC_LOWRES_GF1_0.75_3_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\SWC_LOWRES_GF1_0.75_3_2024)
#
# - [TA_T1_2_1_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\TA_T1_2_1_2024)
#
# - [TS_LOWRES_GF1_0.05_3_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\TS_LOWRES_GF1_0.05_3_2024)
#
# - [TS_LOWRES_GF1_0.2_3_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\TS_LOWRES_GF1_0.2_3_2024)
#
# - [TS_LOWRES_GF1_0.4_3_2024.ipynb](10_METEO\11_meteoscreening_diive_2024\TS_LOWRES_GF1_0.4_3_2024)
#
# - [12.0_DownloadMeteo_2005-2024_FLUXNET_diive_for_eddypro.ipynb](10_METEO\12.0_DownloadMeteo_2005-2024_FLUXNET_diive_for_eddypro)
#
# - [13.0_DownloadMeteo20_2005-2020_FEIGENW.ipynb](10_METEO\13.0_DownloadMeteo20_2005-2020_FEIGENW)
#
# - [14.0_DownloadMeteo6_2021-2024_DB-PROCESSED_meteoscreening_diive.ipynb](10_METEO\14.0_DownloadMeteo6_2021-2024_DB-PROCESSED_meteoscreening_diive)
#
# - [15.0_MergeMeteo6_2005-2024.ipynb](10_METEO\15.0_MergeMeteo6_2005-2024)
#
# - [16.0_GapFillingMeteo7_2005-2024.ipynb](10_METEO\16.0_GapFillingMeteo7_2005-2024)
#
# - [17.0_AddAdditionalMeteoData_PREC_SWC_TS.ipynb](10_METEO\17.0_AddAdditionalMeteoData_PREC_SWC_TS)
#
# - [17.2_GapFilling_TS.ipynb](10_METEO\17.2_GapFilling_TS)
#
# - [17.4_GapFilling_SWC.ipynb](10_METEO\17.4_GapFilling_SWC)
#
# - [STATS.ipynb](10_METEO\STATS)
#
# - [22.0_ConvertMgmtToTimeseries.ipynb](20_MANAGEMENT\22.0_ConvertMgmtToTimeseries)
#
# - [31.0_FLUXES_L1_IRGA.ipynb](30_MERGE_DATA\31.0_FLUXES_L1_IRGA)
#
# - [31.2_ProblematicSonicPeriods_2021-2023.ipynb](30_MERGE_DATA\31.2_ProblematicSonicPeriods_2021-2023)
#
# - [32.0_FLUXES_L1_QCL+LGR.ipynb](30_MERGE_DATA\32.0_FLUXES_L1_QCL+LGR)
#
# - [33.0_FLUXES_L1_IRGA+QCL+LGR+METEO10+MGMT.ipynb](30_MERGE_DATA\33.0_FLUXES_L1_IRGA+QCL+LGR+METEO10+MGMT)
#
# - [33.2_CalcMean3HVars_SWC_TS_PREC.ipynb](30_MERGE_DATA\33.2_CalcMean3HVars_SWC_TS_PREC)
#
# - [33.4_CalcMean3HVarsStepLag_SWC_TS_PREC.ipynb](30_MERGE_DATA\33.4_CalcMean3HVarsStepLag_SWC_TS_PREC)
#
# - [41.0_FluxProcessingChain_L3.3_NEE_QCF10.ipynb](40_FLUX_PROCESSING_CHAIN\41.0_FluxProcessingChain_L3.3_NEE_QCF10)
#
# - [42.0_FluxProcessingChain_L3.3_LE_QCF11.ipynb](40_FLUX_PROCESSING_CHAIN\42.0_FluxProcessingChain_L3.3_LE_QCF11)
#
# - [43.0_FluxProcessingChain_L3.3_H_QCF11.ipynb](40_FLUX_PROCESSING_CHAIN\43.0_FluxProcessingChain_L3.3_H_QCF11)
#
# - [51.0_FluxProcessingChain_L3.3_FN2O_QCF11.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\51.0_FluxProcessingChain_L3.3_FN2O_QCF11)
#
# - [51.2_CorrectionGapFilling_FN2O_CUT50.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\51.2_CorrectionGapFilling_FN2O_CUT50)
#
# - [51.4_CorrectionGapFilling_FN2O_CUT16.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\51.4_CorrectionGapFilling_FN2O_CUT16)
#
# - [51.6_CorrectionGapFilling_FN2O_CUT84.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\51.6_CorrectionGapFilling_FN2O_CUT84)
#
# - [52.0_FluxProcessingChain_L3.3_FCH4_QCF11.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\52.0_FluxProcessingChain_L3.3_FCH4_QCF11)
#
# - [52.2_CorrectionGapFilling_FCH4_CUT50.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\52.2_CorrectionGapFilling_FCH4_CUT50)
#
# - [52.4_CorrectionGapFilling_FCH4_CUT16.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\52.4_CorrectionGapFilling_FCH4_CUT16)
#
# - [52.6_CorrectionGapFilling_FCH4_CUT84.ipynb](50_FLUX_PROCESSING_CHAIN_QCL+LGR\52.6_CorrectionGapFilling_FCH4_CUT84)
#
# - [61.0_MergeFluxProcessingChainResults.ipynb](60_MERGE_DATA_FLUXES\61.0_MergeFluxProcessingChainResults)
#
# - [FLUX_NEE_RidgePlots.ipynb](90_DATASET_OVERVIEW\FLUX_NEE_RidgePlots)
#
# - [FLUXES.ipynb](90_DATASET_OVERVIEW\FLUXES)
#
# - [METEO_TA.ipynb](90_DATASET_OVERVIEW\METEO_TA)
#
# - [METEO_TA_RidgePlots.ipynb](90_DATASET_OVERVIEW\METEO_TA_RidgePlots)
#
# - [Variables.ipynb](90_DATASET_OVERVIEW\Variables)
#
#
# Links generated and saved to README.md
