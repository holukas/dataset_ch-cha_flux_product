# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `9.0` (26 Nov 2024)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **BACKGROUND**

# %% [markdown]
# ---

# %% [markdown]
# - This notebook demonstrates part of the flux post-processing used for fluxes from Swiss FluxNet research stations
# - For a description of the different flux levels, see [Flux Processing Chain](https://www.swissfluxnet.ethz.ch/index.php/data/ecosystem-fluxes/flux-processing-chain/)
# - Flux calculations (Level-1) were done in a previous step
# - This notebook uses the calculated fluxes (Level-1) and applies several post-processing steps:
#     - Quality flag extension (Level-2)
#     - Storage correction (Level-3.1)
#     - Outlier removal (Level-3.2)
#     - USTAR filtering (Level-3.3) - needs *known* thresholds from separate analysis, e.g. from FLUXNET
#     - Gap-filling (Level-4.1) for flux using multiple methods ([MDS](../GapFilling/FluxMDSGapFilling.ipynb), [long-term random forest](../GapFilling/LongTermRandomForestGapFilling.ipynb))
# - Other flux levels are currently not produced in this example:
#
#     - NEE Partitioning (Level-4.2)
#
# **Important**
# - Flux variable names in the input files should follow the [FLUXNET convention](https://fluxnet.org/data/fluxnet2015-dataset/fullset-data-product/)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **GENERAL SETTINGS**

# %% [markdown]
# ---

# %% [markdown]
# ## Flux variable
# `FLUXVAR` is the name of the flux variable in the data files. In the EddyPro `_fluxnet_` output files, the flux variables we primarily use are:
#   - `FC` ... CO2 flux, becomes `NEE` after storage correction (Level-3.1)
#   - `LE` ... Latent heat flux (water)
#   - `H` ... Sensible heat flux
#   - `FN2O` ... Nitrous oxide flux
#   - `FCH4` ... Methane flux
#
# There are more flux variables in the output file, but we rarely need them:
#   - `FH2O` ... H2O flux, very important but it is the same as `ET` and `LE` but with different units
#   - `ET` ... Evapotranspiration, very important but it is the same as `FH2O` and `LE` but with different units. We can easily calculte `ET` later from `LE`, e.g. in `ReddyProc`.
#   - `TAU` ... Momentum flux, a measure of the turbulent transfer of momentum between the land surface and the atmosphere
#
# Set the name of the flux variable in the output file(s), must use the FLUXNET naming convention, e.g. FC, FH2O, LE, ET, H, FN2O, FCH4:

# %%
FLUXVAR = "FC"

# %% [markdown]
# ## Site location
# - Latitude and longitude of the site where data were recorded. This info is mainly used to calculate potential radiation, which is then used to divide the dataset into daytime and nighttime data.
# - UTC offset of the timestamp used in the dataset, important for calculating potential radiation for this location with the correct timestamp.

# %%
SITE_LAT = 47.210227
SITE_LON = 8.410645
UTC_OFFSET = 1  # Time stamp offset in relation to UTC, e.g. 1 for UTC+01:00 (CET), important for the calculation of potential radiation for detecting daytime and nighttime

# %% [markdown]
# ## Daytime/nighttime
# - Threshold for potential radiation in `W m-2`, records below threshold are considered nighttime

# %%
NIGHTTIME_THRESHOLD = 20

# %% [markdown]
# ## Quality requirements
# - The default setting is to accept highest-quality and medium-quality fluxes for daytime (overall quality flag `QCF` = 0 or 1), and highest-quality fluxes only for nighttime (flag `QCF` = 0)
# - `DAYTIME_ACCEPT_QCF_BELOW = 2` accepts high- (`QCF=0`) and medium-quality (`QCF=1`) fluxes for *daytime*, rejects low-quality (`QCF=2`) fluxes
# - `NIGHTTIMETIME_ACCEPT_QCF_BELOW = 1` accepts high-quality (`QCF=0`) fluxes for *nighttime*, rejects medium-quality (`QCF=1`) and low-quality (`QCF=2`) fluxes
# - This strict quality-filtering removes a lot of data points during nighttime

# %%
DAYTIME_ACCEPT_QCF_BELOW = 2
NIGHTTIMETIME_ACCEPT_QCF_BELOW = 1

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **IMPORTS**

# %% [markdown]
# ---

# %% [markdown]
# - This notebook uses `diive` ([source code](https://github.com/holukas/diive)) to check eddy covariance fluxes for quality

# %%
import importlib.metadata
import warnings
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 9999)
import scipy.stats
import seaborn as sns

from diive.core.dfun.stats import sstats  # Time series stats
from diive.core.io.files import save_parquet, load_parquet
from diive.core.plotting.timeseries import TimeSeries  # For simple (interactive) time series plotting
from diive.pkgs.flux.hqflux import analyze_highest_quality_flux
from diive.pkgs.fluxprocessingchain.fluxprocessingchain import FluxProcessingChain
from diive.pkgs.fluxprocessingchain.fluxprocessingchain import LoadEddyProOutputFiles

warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.85.0

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **DOCSTRING** for `FluxProcessingChain`

# %% [markdown]
# ---

# %%
# help(FluxProcessingChain)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **LOAD DATA** (2 options)

# %% [markdown]
# ---

# %% [markdown]
# - It is possible to load data from (multiple) EddyPro _fluxnet_ output files (data from files will be merged), or directly from one single [parquet](https://parquet.apache.org/) file.
# - parquet files are a good option for large datasets because they load and save much faster than when using conventional CSV files.
# - For large datasets, it makes sense to first load and merge data from the original EddyPro _fluxnet_ output files, then convert the merged data to one single parquet file and then use this file as input file.

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Load data from single or multiple EddyPro *_fluxnet_* output files
# - Used to read data from the EddyPro _fluxnet_ output files
# - Found files will be merged together into one single dataframe (`maindf`)

# %% [markdown]
# If you want to search for EddyPro _fluxnet_ files in specific locations, you can specify multiple folders here:

# %%
# # Folder(s) where input file(s) are located
# SOURCEDIRS = [r'example_data/']

# %%
# ep = LoadEddyProOutputFiles(sourcedir=SOURCEDIRS, filetype='EDDYPRO-FLUXNET-CSV-30MIN')
# ep.searchfiles()
# ep.loadfiles()
# maindf = ep.maindf
# metadata = ep.metadata

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Load data from `parquet` file
# - Can be used to continue a previous session where another flux variable was already post-processed
# - For example, if you have already post-processed CO2 flux and now want to post-process H2O flux
# - Also detects time resolution of time series, this info was lost when saving to the parquet file

# %% [markdown]
# If you want to load data directly from a specific parquet file, you can specify its name and location here:

# %%
SOURCEDIR = r"../30_MERGE_DATA"
FILENAME = r"33.1_CH-CHA_IRGA+QCL+LGR+M7+MGMT_Level-1_eddypro_fluxnet_2005-2023.parquet"
FILEPATH = Path(SOURCEDIR) / FILENAME
print(f"Data will be loaded from the following file:\n{FILEPATH}")
# Out:
# Data will be loaded from the following file:
# ..\30_MERGE_DATA\33.1_CH-CHA_IRGA+QCL+LGR+M7+MGMT_Level-1_eddypro_fluxnet_2005-2023.parquet

# %%
maindf = load_parquet(filepath=FILEPATH)
# Out:
# Loaded .parquet file ..\30_MERGE_DATA\33.1_CH-CHA_IRGA+QCL+LGR+M7+MGMT_Level-1_eddypro_fluxnet_2005-2023.parquet (2.756 seconds). Detected time resolution of <30 * Minutes> / 30min

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 3: Load example data

# %%
# from diive.configs.exampledata import load_exampledata_EDDYPRO_FLUXNET_CSV_30MIN
# maindf, metadata = load_exampledata_EDDYPRO_FLUXNET_CSV_30MIN()

# %% [markdown]
# </br>

# %% [markdown]
# ## (Optional) Restrict data to time range

# %%
# # Restrict data range
# maindf = maindf.loc[(maindf.index.year >= 2005) & (maindf.index.year <= 2010)].copy()

# %% [markdown]
# </br>

# %% [markdown]
# ## Check data

# %%
display(maindf.head(3))
display(maindf.tail(3))
display(sstats(maindf[FLUXVAR]))
# Out:
#                      AIR_MV  AIR_DENSITY  AIR_RHO_CP  AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  TIMESINCE_MGMT_SOILCULTIVATION_PARCEL-A  TIMESINCE_MGMT_SOILCULTIVATION_PARCEL-B  TIMESINCE_MGMT_SOWING  TIMESINCE_MGMT_SOWING_FOOTPRINT  TIMESINCE_MGMT_SOWING_PARCEL-A  TIMESINCE_MGMT_SOWING_PARCEL-B
# TIMESTAMP_MIDDLE                                                                                ...
# 2005-01-01 00:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...                                   1304.0                                    278.0                  278.0                            278.0                           653.0                           278.0
# 2005-01-01 00:45:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...                                   1304.0                                    278.0                  278.0                            278.0                           653.0                           278.0
# 2005-01-01 01:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...                                   1304.0                                    278.0                  278.0                            278.0                           653.0                           278.0
#
# [3 rows x 494 columns]
#                        AIR_MV  AIR_DENSITY  AIR_RHO_CP   AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  TIMESINCE_MGMT_SOILCULTIVATION_PARCEL-A  TIMESINCE_MGMT_SOILCULTIVATION_PARCEL-B  TIMESINCE_MGMT_SOWING  TIMESINCE_MGMT_SOWING_FOOTPRINT  TIMESINCE_MGMT_SOWING_PARCEL-A  TIMESINCE_MGMT_SOWING_PARCEL-B
# TIMESTAMP_MIDDLE                                                                                   ...
# 2023-12-31 22:45:00  0.023718      1.21785     1228.93  1009.10         0.0                   1.0  ...                                    863.0                                    863.0                  843.0                            863.0                           843.0                           863.0
# 2023-12-31 23:15:00  0.023710      1.21827     1229.34  1009.09         0.0                   1.0  ...                                    863.0                                    863.0                  843.0                            863.0                           843.0                           863.0
# 2023-12-31 23:45:00  0.023715      1.21807     1229.13  1009.08         0.0                   1.0  ...                                    863.0                                    863.0                  843.0                            863.0                           843.0                           863.0
#
# [3 rows x 494 columns]
#                               FC
# STARTDATE       2005-01-01 00:15
# ENDDATE         2023-12-31 23:45
# PERIOD        6938 days 23:30:00
# NOV                       279497
# MISSING                    53575
# MISSING_PERC           16.085111
# MEAN                   -0.604917
# MEDIAN                 -0.223481
# SD                      44.83582
# VAR                  2010.250721
# SD/MEAN               -74.118953
# SUM               -169072.504612
# MIN                     -2662.94
# MAX                      6188.27
# P01                   -72.950268
# P05                    -23.88704
# P25                     -7.85281
# P75                      4.12454
# P95                      25.2573
# P99                     94.65422

# %%
# TimeSeries(series=maindf[FLUXVAR]).plot_interactive()
TimeSeries(series=maindf[FLUXVAR]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **START FLUX PROCESSING CHAIN**

# %% [markdown]
# ---

# %% [markdown]
# - First we need to initialize the processing chain by providing some basic info.
# - At the same time, some fundamental variables are also created: potential radiation, and two flags based on it: daytime flag (1=daytime) and nighttime flag (1=nighttime).

# %%
fpc = FluxProcessingChain(
    df=maindf,
    fluxcol=FLUXVAR,
    site_lat=SITE_LAT,
    site_lon=SITE_LON,
    utc_offset=UTC_OFFSET,    
    nighttime_threshold=NIGHTTIME_THRESHOLD,
    daytime_accept_qcf_below=DAYTIME_ACCEPT_QCF_BELOW,
    nighttimetime_accept_qcf_below=NIGHTTIMETIME_ACCEPT_QCF_BELOW
)
# Out:
# Detected base variable CO2 for FC. (CO2 was used to calculate FC.)
# Calculated potential radiation from latitude and longitude (SW_IN_POT) ...
# Calculated daytime flag DAYTIME and nighttime flag NIGHTTIME from SW_IN_POT ...
# ++ Added new columns ['SW_IN_POT', 'DAYTIME', 'NIGHTTIME'] to input data.

# %% [markdown]
# - Let's check the flux processing chain dataframe: this are the data the chain is working with in this run:

# %%
fpc.fpc_df
# Out:
#                            FC     USTAR  SW_IN_POT  DAYTIME  NIGHTTIME
# TIMESTAMP_MIDDLE
# 2005-01-01 00:15:00       NaN       NaN        0.0      0.0        1.0
# 2005-01-01 00:45:00       NaN       NaN        0.0      0.0        1.0
# 2005-01-01 01:15:00       NaN       NaN        0.0      0.0        1.0
# 2005-01-01 01:45:00       NaN       NaN        0.0      0.0        1.0
# 2005-01-01 02:15:00       NaN       NaN        0.0      0.0        1.0
# ...                       ...       ...        ...      ...        ...
# 2023-12-31 21:45:00       NaN  0.114945        0.0      0.0        1.0
# 2023-12-31 22:15:00       NaN  0.154797        0.0      0.0        1.0
# 2023-12-31 22:45:00  7.476970  0.183323        0.0      0.0        1.0
# 2023-12-31 23:15:00  0.836672  0.201075        0.0      0.0        1.0
# 2023-12-31 23:45:00  1.191700  0.184102        0.0      0.0        1.0
#
# [333072 rows x 5 columns]

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-2: **QUALITY FLAG EXTENSION**

# %% [markdown]
# ---

# %% [markdown]
# > Extract additional quality information from the EddyPro output and store it in newly added quality flags.
#
#
#
# Note that the USTAR filtering is not part of the Level-2 calculations.

# %% [markdown]
# </br>

# %% [markdown]
# ## User settings
# - A test for missing values is always included: flag calculated here from missing flux values in the EddyPro output file

# %% [markdown]
# </br>

# %% [markdown]
# ### SSITC tests (default: `True`)
# - Flag calculated in EddyPro
# - Combination of the two partial tests *steady state test* and *developed turbulent conditions test*
# - This notebook expects the SSITC flag to follow the flagging policy according to Mauder and Foken 2004:
#     - `0` for best quality fluxes
#     - `1` for fluxes suitable for general analysis such as annual budgets (although this is debatable for nighttime data)
#     - `2` for fluxes that should be discarded from the dataset

# %%
TEST_SSITC = True  # Default True

# %% [markdown]
# </br>

# %% [markdown]
# ### Flux base variable completeness test (default: `True`)
# - Flag newly calculated here
# - Check completeness of the variable that was used to calculate the respective flux
# - Example: `CO2` is the base variable that was used to calculate flux `FC`, the test is therefore run on `CO2`
# - Checks number of records of the relevant base variable available for each averaging Interval and calculates completeness flag as follows:
#     - `0` for files where >= 99% of base variable are available
#     - `1` for files where >= 97% and < 99% of base variable are available
#     - `2` for files where < 97% of base variable are available
#
# List of flux base variables and the corresponding fluxes:
# - `CO2`: used to calculate `FC`
# - `H2O`: used to calculate `FH2O`
# - `H2O`: used to calculate `LE`
# - `H2O`: used to calculate `ET`
# - `T_SONIC`: used to calculate `H`
# - `N2O`: used to calculate `FN2O`
# - `CH4`: used to calculate `FCH4`

# %%
TEST_GAS_COMPLETENESS = True  # Default True

# %% [markdown]
# </br>

# %% [markdown]
# ### Spectral correction factor test (default: `True`)
# - Flag calculated here from the gas `SCF` variable in EddyPro output file

# %%
TEST_SPECTRAL_CORRECTION_FACTOR = True  # Default True

# %% [markdown]
# </br>

# %% [markdown]
# ### Signal strength test

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Always recommended if flux was calculated using a gas analyzer.</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Do not use for H (sensible heat flux).</b> This test is only relevant for fluxes where the concentration/temperature was measured by a gas analyzer, e.g. FC, FH2O, LE, ET, N2O, CH4, etc ...
# </div>

# %% [markdown]
# - Signal strength / AGC / window dirtiness test (if available)
# - Flag calculated here from the signal strength / AGC variable for the gas analyzer in EddyPro output file
# - `SIGNAL_STRENGTH_COL`: Name of the column storing the signal strength, typically 'CUSTOM_AGC_MEAN' for LI-7500, 'CUSTOM_SIGNAL_STRENGTH_IRGA72_MEAN' for LI-7200, or something similar
# - `SIGNAL_STRENGTH_THRESHOLD`: Signal strength threshold, flux values where threshold is exceeded are flagged as rejected
# - `SIGNAL_STRENGTH_METHOD`: `discard above` flags fluxes where signal strength > threshold, `discard below` where signal strength < threshold

# %%
# Signal strength
TEST_SIGNAL_STRENGTH = True
TEST_SIGNAL_STRENGTH_COL = 'CUSTOM_AGC_MEAN'  # Typical variable name in fluxnet files
TEST_SIGNAL_STRENGTH_METHOD = 'discard above'
TEST_SIGNAL_STRENGTH_THRESHOLD = 90

# %%
# TimeSeries(series=df_orig[SIGNAL_STRENGTH_COL]).plot_interactive()
TimeSeries(series=maindf[TEST_SIGNAL_STRENGTH_COL]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# ### Raw data screening tests
# - Flags were calculated in EddyPro
# - See here for more details: [Despiking and raw data statistical screening (EddyPro help)](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html)

# %%
TEST_RAWDATA = True  # Default True
TEST_RAWDATA_SPIKES = True  # Default True
TEST_RAWDATA_AMPLITUDE = True  # Default True
TEST_RAWDATA_DROPOUT = True  # Default True
TEST_RAWDATA_ABSLIM = False  # Default False
TEST_RAWDATA_SKEWKURT_HF = False  # Default False
TEST_RAWDATA_SKEWKURT_SF = False  # Default False
TEST_RAWDATA_DISCONT_HF = False  # Default False
TEST_RAWDATA_DISCONT_SF = False  # Default False

# %% [markdown]
# </br>

# %% [markdown]
# ### Angle-of-attack test (default: `False`)
# > This test calculates sample-wise Angle of Attacks throughout the current flux averaging period, and flags it if the percentage of angles of attack exceeding a user-defined range is beyond a (user-defined) threshold.
# > Source: [EddyPro help](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html?Highlight=angle%20of%20attack#Angleofattack)  *(3 Jan 2024)*
# - Flag was calculated in EddyPro
# - Flag can be useful during some time periods when the sonic anemometer had issues
# - Not used by default (similar to ICOS)

# %%
TEST_RAWDATA_ANGLE_OF_ATTACK = True  # Default False
# TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES = []
TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES = [['2008-01-01', '2010-01-01'],
                                                  ['2016-03-01', '2016-05-01']]

# %% [markdown]
# </br>

# %% [markdown]
# ### Steadiness of horizontal wind test (default: `False`)
# > This test assesses whether the along-wind and crosswind components of the wind vector undergo a systematic reduction (or increase) throughout the file. If the quadratic combination of such systematic variations is beyond the user-selected limit, the flux averaging period is hard-flagged for instationary horizontal wind (Vickers and Mahrt, 1997, Par. 6g).
# > Source: [EddyPro help](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html?Highlight=angle%20of%20attack#Steadinessofhorizontalwind)  *(3 Jan 2024)*
# - Flag was calculated in EddyPro

# %%
TEST_RAWDATA_STEADINESS_OF_HORIZONTAL_WIND = False  # Default False

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Run

# %%
LEVEL2_SETTINGS = {
    'signal_strength': {
        'apply': TEST_SIGNAL_STRENGTH,
        'signal_strength_col': TEST_SIGNAL_STRENGTH_COL,
        'method': TEST_SIGNAL_STRENGTH_METHOD,
        'threshold': TEST_SIGNAL_STRENGTH_THRESHOLD},
    'raw_data_screening_vm97': {
        'apply': TEST_RAWDATA,
        'spikes': TEST_RAWDATA_SPIKES,
        'amplitude': TEST_RAWDATA_AMPLITUDE,
        'dropout': TEST_RAWDATA_DROPOUT,
        'abslim': TEST_RAWDATA_ABSLIM,
        'skewkurt_hf': TEST_RAWDATA_SKEWKURT_HF,
        'skewkurt_sf': TEST_RAWDATA_SKEWKURT_SF,
        'discont_hf': TEST_RAWDATA_DISCONT_HF,
        'discont_sf': TEST_RAWDATA_DISCONT_SF},
    'ssitc': {
        'apply': TEST_SSITC},
    'gas_completeness': {
        'apply': TEST_GAS_COMPLETENESS},
    'spectral_correction_factor': {
        'apply': TEST_SPECTRAL_CORRECTION_FACTOR},
    'angle_of_attack': {
        'apply': TEST_RAWDATA_ANGLE_OF_ATTACK,
        'application_dates': TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES},
    'steadiness_of_horizontal_wind': {
        'apply': TEST_RAWDATA_STEADINESS_OF_HORIZONTAL_WIND}
}
fpc.level2_quality_flag_expansion(**LEVEL2_SETTINGS)
# Out:
# [MissingValues]  running MissingValues ...
# SSITC TEST: Generated new flag variable FLAG_L2_FC_SSITC_TEST, values taken from output variable FC_SSITC_TEST ...
# FLUX BASE VARIABLE COMPLETENESS TEST: Generated new flag variable FLAG_L2_FC_COMPLETENESS_TEST, newly calculated from variable CO2, with flag 0 (good values) where available number of records for CO2 >= 0.99, flag 1 (ok values) >= 0.97 and < 0.99, flag 2 (bad values) < 0.97...
# SPECTRAL CORRECTION FACTOR TEST: Generating new flag variable FLAG_L2_FC_SCF_TEST, newly calculated from output variable FC_SCF, withflag 0 (good values) where FC_SCF < 2, flag 1 (ok values) where FC_SCF >= 2 and < 4, flag 2 (bad values) where FC_SCF >= 4...
# SIGNAL STRENGTH TEST: Generating new flag variable FLAG_L2_FC_SIGNAL_STRENGTH_TEST, newly calculated from output variable CUSTOM_AGC_MEAN, with flag 0 (good values) where CUSTOM_AGC_MEAN <= 90, flag 2 (bad values) where CUSTOM_AGC_MEAN > 90 ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST, values taken from output variable CO2_VM97_TEST from position 1, based on CO2, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST, values taken from output variable CO2_VM97_TEST from position 2, based on CO2, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FC_CO2_VM97_DROPOUT_TEST, values taken from output variable CO2_VM97_TEST from position 3, based on CO2, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# ANGLE OF ATTACK TEST: will be applied on the following dates only: [['2008-01-01', '2010-01-01'], ['2016-03-01', '2016-05-01']]
# ANGLE OF ATTACK TEST: Generated new flag variable FLAG_L2_FC_VM97_AOA_HF_TEST, values taken from output variable None, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed ...

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Finalize Level-2

# %%
fpc.finalize_level2()
# Out:
# ++Added new column FLAG_L2_FC_MISSING_TEST.
# ++Added new column FLAG_L2_FC_SSITC_TEST.
# ++Added new column FLAG_L2_FC_COMPLETENESS_TEST.
# ++Added new column FLAG_L2_FC_SCF_TEST.
# ++Added new column FLAG_L2_FC_SIGNAL_STRENGTH_TEST.
# ++Added new column FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST.
# ++Added new column FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST.
# ++Added new column FLAG_L2_FC_CO2_VM97_DROPOUT_TEST.
# ++Added new column FLAG_L2_FC_VM97_AOA_HF_TEST.
# ++Added new column SUM_L2_FC_HARDFLAGS.
# ++Added new column SUM_L2_FC_SOFTFLAGS.
# ++Added new column SUM_L2_FC_FLAGS.
# ++Added new column FLAG_L2_FC_QCF.
# ++Added new column FC_L2_QCF.
# ++Added new column FC_L2_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-2` variables
# - This shows all available Level-2 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L2' in x]
# Out:
# ['FLAG_L2_FC_MISSING_TEST',
#  'FLAG_L2_FC_SSITC_TEST',
#  'FLAG_L2_FC_COMPLETENESS_TEST',
#  'FLAG_L2_FC_SCF_TEST',
#  'FLAG_L2_FC_SIGNAL_STRENGTH_TEST',
#  'FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST',
#  'FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST',
#  'FLAG_L2_FC_CO2_VM97_DROPOUT_TEST',
#  'FLAG_L2_FC_VM97_AOA_HF_TEST',
#  'SUM_L2_FC_HARDFLAGS',
#  'SUM_L2_FC_SOFTFLAGS',
#  'SUM_L2_FC_FLAGS',
#  'FLAG_L2_FC_QCF',
#  'FC_L2_QCF',
#  'FC_L2_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plots

# %%
fpc.level2_qcf.showplot_qcf_heatmaps()

# %%
# fpc.level2_qcf.showplot_qcf_timeseries()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
fpc.level2_qcf.report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FC.
#
# Number of FC records before QC: 279497
# +++ FLAG_L2_FC_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 279497 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FC_SSITC_TEST rejected 127121 values (+45.48%)      TOTALS: flag 0: 108139 (38.69%) / flag 1: 44237 (15.83%) / flag 2: 127121 (45.48%)
# +++ FLAG_L2_FC_COMPLETENESS_TEST rejected 678 values (+0.24%)      TOTALS: flag 0: 107495 (38.46%) / flag 1: 44203 (15.82%) / flag 2: 127799 (45.72%)
# +++ FLAG_L2_FC_SCF_TEST rejected 194 values (+0.07%)      TOTALS: flag 0: 107273 (38.38%) / flag 1: 44231 (15.83%) / flag 2: 127993 (45.79%)
# +++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST rejected 9483 values (+3.39%)      TOTALS: flag 0: 103275 (36.95%) / flag 1: 38746 (13.86%) / flag 2: 137476 (49.19%)
# +++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST rejected 905 values (+0.32%)      TOTALS: flag 0: 102612 (36.71%) / flag 1: 38504 (13.78%) / flag 2: 138381 (49.51%)
# +++ FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 3821 values (+1.37%)      TOTALS: flag 0: 100085 (35.81%) / flag 1: 37210 (13.31%) / flag 2: 142202 (50.88%)
# +++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 100085 (35.81%) / flag 1: 37210 (13.31%) / flag 2: 142202 (50.88%)
# +++ FLAG_L2_FC_VM97_AOA_HF_TEST rejected 2607 values (+0.93%)      TOTALS: flag 0: 99138 (35.47%) / flag 1: 35550 (12.72%) / flag 2: 144809 (51.81%)
#
# In total, 144809 (51.81%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 1

# %%
fpc.level2_qcf.report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L2_FC_QCF, QCF FLAG FOR FC
# ========================================
# Between 2005-01-01 00:15 and 2023-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 279497 (83.91% of potential)
#     Available flux records AFTER quality checks: 134688 (48.19% of total)
#     Rejected flux records: 144809 (51.81% of total)
#     Potential flux records: 333072
#     Potential flux records missed: 53575 (16.09% of potential)

# %%
# fpc.level2_qcf.report_qcf_flags()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-3.1: **STORAGE CORRECTION**

# %% [markdown]
# ---

# %% [markdown]
# - The flux storage term (single point) is added to the flux
# - For some records, the storage term can be missing. In such cases, missing terms are gap-filled using the rolling mean in an expanding window.
# - Without gap-filling the storage term, we can lose an additional e.g. 2-3% of flux data

# %% [markdown]
# </br>

# %% [markdown]
# ## Run

# %%
fpc.level31_storage_correction(gapfill_storage_term=True)
# Out:
# Detected storage variable SC_SINGLE for FC.
# Calculating storage-corrected flux NEE_L3.1 from flux FC and storage term SC_SINGLE ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 6757
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 3 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 6757
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 5 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 5254
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 7 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1492
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 9 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1072
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 11 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 662
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 13 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 452
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 15 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 299
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 17 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 207
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 19 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 153
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 21 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 115
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 23 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 91
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 25 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 74
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 27 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 62
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 29 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 54
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 31 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 40
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 33 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 35
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 35 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 29
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 37 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 25
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 39 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 25
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 41 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 24
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 43 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 22
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 45 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 20
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 47 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 17
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 49 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 17
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 51 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 17
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 53 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 16
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 55 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 15
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 57 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 13
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 59 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 13
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 61 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 13
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 63 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 13
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 65 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 12
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 67 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 12
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 69 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 11
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 71 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 11
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 73 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 11
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 75 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 10
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 77 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 10
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 79 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 10
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 81 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 10
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 83 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 10
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 85 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 10
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 87 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 9
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 89 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 7
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 91 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 7
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 93 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 6
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 95 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 5
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 97 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 5
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 99 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 3
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 101 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 3
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 103 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 3
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 105 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 107 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 109 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 111 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 113 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 115 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 117 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 119 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 121 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 123 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 125 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 127 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 129 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 131 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 133 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 135 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 137 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 139 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 141 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 143 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 145 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 147 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 149 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 151 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 153 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 155 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 157 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 159 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 161 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 163 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 165 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 167 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 169 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 171 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 173 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 175 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 177 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 179 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 181 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 183 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 2
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 185 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 187 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 189 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 191 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 193 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 195 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 1
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 197 records) ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 0

# %% [markdown]
# </br>

# %% [markdown]
# ## **Finalize Level-3.1**

# %%
fpc.finalize_level31()
# Out:
# ++Added new column SC_SINGLE.
# ++Added new column SC_SINGLE_gfRMED_L3.1.
# ++Added new column FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED.
# ++Added new column NEE_L3.1.
# ++Added new column NEE_L3.1_QCF (Level-3.1 with applied quality flag from Level-2).
# ++Added new column NEE_L3.1_QCF0 (Level-3.1 with applied quality flag from Level-2).

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.1` variables
# - This shows all available Level-3.1 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.1' in x]
# Out:
# ['SC_SINGLE_gfRMED_L3.1',
#  'FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED',
#  'NEE_L3.1',
#  'NEE_L3.1_QCF',
#  'NEE_L3.1_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plots

# %%
fpc.level31.showplot()

# %% [markdown]
# </br>

# %% [markdown]
# ### Report

# %%
fpc.level31.report()
# Out:
# ========================================
# REPORT: STORAGE CORRECTION FOR FC
# ========================================
# Swiss FluxNet processing chain, _L3.1: Storage Correction
#
# The gap-filled storage term SC_SINGLE_gfRMED_L3.1 was added to flux FC.
# The storage-corrected flux was stored as NEE_L3.1.
#
# The flux was available for 279497 records (FC).
# The original, non-gapfilled storage term was available for 275510 records (SC_SINGLE).
# The original storage term SC_SINGLE was missing for 6757 flux records.
# Without gap-filling the storage term (SC_SINGLE), 6757 measured flux records (FC) are lost.
#
# For this run, gap-filling of SC_SINGLE was * SELECTED *.
# After gap-filling the storage term, it was available for an additional 6757 records (SC_SINGLE_gfRMED_L3.1).
#
# In the storage-corrected flux NEE_L3.1 with 279497 records,
#   - 97.6% (275510 records) of used storage terms come from originally calculated data (SC_SINGLE)
#   - 2.4% (6757 records) of used storage terms come from gap-filled data (SC_SINGLE_gfRMED_L3.1)
#
# Stats for gap-filled storage terms:
#                         NOV       P01   MEDIAN       P99
# SC_SINGLE_gfRMED_L3.1  6757 -8.420792 -0.17515  6.822962
#
# Stats for measured storage terms:
#                           NOV       P01    MEDIAN       P99
# SC_SINGLE_gfRMED_L3.1  272740 -7.550003 -0.015552  6.736438

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Optional: **Analyze highest-quality flux** (so far)

# %% [markdown]
# ---

# %% [markdown]
# - Analysis of fluxes after Level-3.1 where the overall quality flag `QCF` = 0
# - This helps in understanding in what range the "true" flux occurs
# - Here, the highest-quality fluxes are additionally filtered for outlier values using the relatively fast Local Outlier Factor test
# - For this quick analysis, it is possible that the outlier test cuts off some "real" values that should be retained, but it nevertheless helps in understanding the flux range
# - `QCF` = 0 is best quality, `QCF` = medium quality, `QCF` = 2 bad quality and always rejected
# - The difference between quality 0 and quality 1 or 2 is huge

# %%
analyze_highest_quality_flux(flux=fpc.fpc_df[fpc.filteredseries_hq.name], nighttime_flag=fpc.fpc_df['NIGHTTIME'])
# Out:
# >>> Removing outliers from highest-quality DAYTIME fluxes (NEE_L3.1_QCF0)
# >>> Outlier removal method: Local outlier factor across all data (n_neighbors=742, contamination=auto, repeat=False)
# [LocalOutlierFactorAllData]  running LocalOutlierFactorAllData ...
# ITERATION#1: Total found outliers: 893 values (daytime+nighttime)
# >>> Largest non-outlier flux >= 0 DAYTIME:   11.76358553
# >>> Smallest non-outlier flux >= 0 DAYTIME:  7.00000000000145e-05
# >>> Largest non-outlier flux < 0 DAYTIME:    -0.00035999999999991594
# >>> Smallest non-outlier flux < 0 DAYTIME:   -33.87713
# >>> Removing outliers from highest-quality NIGHTTIME fluxes (NEE_L3.1_QCF0)
# >>> Outlier removal method: Local outlier factor across all data (n_neighbors=249, contamination=auto, repeat=False)
# [LocalOutlierFactorAllData]  running LocalOutlierFactorAllData ...
# ITERATION#1: Total found outliers: 342 values (daytime+nighttime)
# >>> Largest non-outlier flux >= 0 NIGHTTIME:   32.5053692
# >>> Smallest non-outlier flux >= 0 NIGHTTIME:  0.0008900000000000574
# >>> Largest non-outlier flux < 0 NIGHTTIME:    -0.0001500000000000945
# >>> Smallest non-outlier flux < 0 NIGHTTIME:   -12.07409

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-3.2: **OUTLIER DETECTION**

# %% [markdown]
# ---

# %% [markdown]
# - Running an outlier test creates a *preview* plot of the results
# - If the output looks as desired, run `fpc.level32_addflag()` cell below the preview to accept the results you see in the plot
# - All subsequent tests will then be based on these results
# - This means that each test is run on the data already filtered by the previous test
# - Each test creates its own quality flag
# - At the end of Level-3.2, an overall quality flag `QCF` is created that combines all of the individual flags into one single flag

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot time series

# %%
print(f"{fpc.filteredseries.name} \n(quality-controlled Level-3.1 version of {fpc.fluxcol})")
# Out:
# NEE_L3.1_QCF
# (quality-controlled Level-3.1 version of FC)

# %%
# TimeSeries(series=fpc.fpc_df[fpc.filteredseries.name]).plot_interactive()
TimeSeries(series=fpc.fpc_df[fpc.filteredseries.name]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# ## Initiate calculations

# %%
fpc.level32_stepwise_outlier_detection()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Absolute limits**
# - remove values outside a physically plausible range
# - typical value for CO2 flux `FC`: +/-50 µmol m-2 s-1
# - typical value for latent evaporation flux `LE`: +800 / -50 W m-2
# - typical value for sensible heat flux `H`: +400 / -200 W m-2

# %%
# from diive.pkgs.outlierdetection.absolutelimits import AbsoluteLimits
# help(AbsoluteLimits)

# %%
MIN = -50
MAX = 50
fpc.level32_flag_outliers_abslim_test(minval=MIN, maxval=MAX, showplot=True, verbose=True)
# Out:
# [AbsoluteLimits]  running AbsoluteLimits ...

# %%
fpc.level32_addflag()
# Out:
# ++Added flag column FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST to flag data

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Manual flag**
# - The interactive plot can be used to determine the exact start and end of time ranges or data points that need to be removed, e.g. due to known instrument failure

# %%
# from diive.pkgs.outlierdetection.manualremoval import ManualRemoval
# help(ManualRemoval)

# %%
# fpc.level32.showplot_cleaned(interactive=True)  # True or False
# fpc.level32.showplot_cleaned(interactive=False)  # True or False

# %%
# REMOVE_DATES = [
#     ['2022-03-18 12:15:00', '2022-05-03 06:45:00'],  # Removes date range between two datetimes (inclusive)
#     # '2023-12-12 12:45:00'  # Removes data point with specific timestamp
# ]
# fpc.level32_flag_manualremoval_test(
#     remove_dates=REMOVE_DATES,
#     showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %%
# fpc.level32.showplot_cleaned(interactive=True)  # True or False

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Hampel filter**, separate for daytime and nighttime
# - Recommended filter
# - Is slow compared to other filters:
#     - tested with 1 year of 30MIN time resolution data and it needed approx. 43 seconds on a fast desktop computer

# %%
# from diive.pkgs.outlierdetection.hampel import Hampel
# help(Hampel)

# %%
# %%time
WINDOW_LENGTH = 48 * 13
N_SIGMA_DT = 3.5
N_SIGMA_NT = 3.5
fpc.level32_flag_outliers_hampel_dtnt_test(window_length=WINDOW_LENGTH, n_sigma_dt=N_SIGMA_DT, n_sigma_nt=N_SIGMA_NT,
                                           showplot=True, verbose=True, repeat=True)
# Out:
# [HampelDaytimeNighttime]  running HampelDaytimeNighttime ...
# ITERATION#1: Total found outliers: 3872 (daytime+nighttime), 2372 (daytime), 1500 (nighttime)
# ITERATION#2: Total found outliers: 208 (daytime+nighttime), 107 (daytime), 101 (nighttime)
# ITERATION#3: Total found outliers: 10 (daytime+nighttime), 4 (daytime), 6 (nighttime)
# ITERATION#4: Total found outliers: 1 (daytime+nighttime), 1 (daytime), 0 (nighttime)
# ITERATION#5: Total found outliers: 0 (daytime+nighttime), 0 (daytime), 0 (nighttime)
# CPU times: total: 9min 18s
# Wall time: 9min 43s

# %%
fpc.level32_addflag()
# Out:
# ++Added flag column FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST to flag data

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **z-score across all data**

# %%
# from diive.pkgs.outlierdetection.zscore import zScore
# help(zScore)

# %%
# THRES_ZSCORE = 6
# fpc.level32_flag_outliers_zscore_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Hampel filter**
# - Recommended filter
# - Is slow compared to other filters:
#     - tested with 1 year of 30MIN time resolution data and it needed approx. 33 seconds on a fast desktop computer
#     - tested with 19 years of 30MIN time resolution data and it needed approx. 20 minutes on a fast desktop computer

# %%
# from diive.pkgs.outlierdetection.hampel import Hampel
# help(Hampel)

# %%
# WINDOW_LENGTH = 48 * 13
# N_SIGMA = 6
# %%time
# fpc.level32_flag_outliers_hampel_test(window_length=WINDOW_LENGTH, n_sigma=N_SIGMA, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **z-score over all data**, separate for daytime and nighttime

# %%
# from diive.pkgs.outlierdetection.zscore import zScoreDaytimeNighttime
# help(zScoreDaytimeNighttime)

# %%
# THRES_ZSCORE = 6
# fpc.level32_flag_outliers_zscore_dtnt_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Rolling z-score over all data**

# %%
# from diive.pkgs.outlierdetection.zscore import zScoreRolling
# help(zScoreRolling)

# %%
# THRES_ZSCORE = 5.5
# WINSIZE = 48 * 13
# fpc.level32_flag_outliers_zscore_rolling_test(winsize=WINSIZE, thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local standard deviation**, with rolling median and *rolling* standard deviation

# %%
# from diive.pkgs.outlierdetection.localsd import LocalSD
# help(LocalSD)

# %%
# N_SD = 4.5
# WINSIZE = 48 * 9
# fpc.level32_flag_outliers_localsd_test(n_sd=N_SD, winsize=WINSIZE, constant_sd=False, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local standard deviation**, with rolling median and *constant* standard deviation
# - keep standard deviation constant by setting parameter `constant_sd=True`

# %%
# N_SD = 4.5
# WINSIZE = 48 * 9
# fpc.level32_flag_outliers_localsd_test(n_sd=N_SD, winsize=WINSIZE, constant_sd=True, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Increments z-score**

# %%
# from diive.pkgs.outlierdetection.incremental import zScoreIncrements
# help(zScoreIncrements)

# %%
# THRES_ZSCORE = 4
# fpc.level32_flag_outliers_increments_zcore_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local outlier factor**, daytime/nighttime
# - Test is run separately for daytime and nighttime data
# - Description of local outlier factor: [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
# from diive.pkgs.outlierdetection.lof import LocalOutlierFactorDaytimeNighttime
# help(LocalOutlierFactorDaytimeNighttime)

# %%
# N_NEIGHBORS = 100
# CONTAMINATION = None
# fpc.level32_flag_outliers_lof_dtnt_test(n_neighbors=N_NEIGHBORS, contamination=CONTAMINATION, showplot=True, verbose=True, repeat=False, n_jobs=-1)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local outlier factor**
# - Test is run across all data
# - Description of local outlier factor: [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
# from diive.pkgs.outlierdetection.lof import LocalOutlierFactorAllData
# help(LocalOutlierFactorAllData)

# %%
# N_NEIGHBORS = 24
# CONTAMINATION = None
# fpc.level32_flag_outliers_lof_test(n_neighbors=N_NEIGHBORS, contamination=CONTAMINATION, showplot=True, verbose=True, repeat=False, n_jobs=-1)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Absolute limits**, separate for daytime and nighttime data

# %%
# from diive.pkgs.outlierdetection.absolutelimits import AbsoluteLimitsDaytimeNighttime
# help(AbsoluteLimitsDaytimeNighttime)

# %%
# MIN_DT = -50
# MAX_DT = 50
# MIN_NT = -25
# MAX_NT = 25
# fpc.level32_flag_outliers_abslim_dtnt_test(daytime_minmax=[MIN_DT, MAX_DT], nighttime_minmax=[MIN_NT, MAX_NT], showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Trim nighttime flux data**

# %%
# from diive.pkgs.outlierdetection.trim import TrimLow
# help(TrimLow)

# %%
# fpc.level32_flag_outliers_trim_low_test(trim_nighttime=True, lower_limit=-5, showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## **Finalize Level-3.2**: Calculate overall quality flag (so far)

# %%
fpc.finalize_level32()
# Out:
# ++Added new column FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST.
# ++Added new column FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST.
# ++Added new column SUM_L3.2_NEE_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.2_NEE_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.2_NEE_L3.1_FLAGS.
# ++Added new column FLAG_L3.2_NEE_L3.1_QCF.
# ++Added new column NEE_L3.1_L3.2_QCF.
# ++Added new column NEE_L3.1_L3.2_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.2` variables
# - This shows all available Level-3.2 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.2' in x]
# Out:
# ['FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST',
#  'FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST',
#  'SUM_L3.2_NEE_L3.1_HARDFLAGS',
#  'SUM_L3.2_NEE_L3.1_SOFTFLAGS',
#  'SUM_L3.2_NEE_L3.1_FLAGS',
#  'FLAG_L3.2_NEE_L3.1_QCF',
#  'NEE_L3.1_L3.2_QCF',
#  'NEE_L3.1_L3.2_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plot filtered flux after Level-3.2
# In the four panels, from left to right:
# - flux after Level-3.1, before outlier removal
# - flux after Level-3.2, after outlier removal
# - sum of the individual test flags
# - overall flag `QCF` (quality control flag), where `0`=best quality, `1`=medium quality, `2`=bad quality

# %%
fpc.level32_qcf.showplot_qcf_heatmaps()

# %%
TimeSeries(series=fpc.filteredseries).plot()
# TimeSeries(series=fpc.filteredseries).plot_interactive()

# %%
# fpc.level32_qcf.showplot_qcf_timeseries()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
fpc.level32_qcf.report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable NEE_L3.1.
#
# Number of NEE_L3.1 records before QC: 279497
# +++ FLAG_L2_FC_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 279497 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FC_SSITC_TEST rejected 127121 values (+45.48%)      TOTALS: flag 0: 108139 (38.69%) / flag 1: 44237 (15.83%) / flag 2: 127121 (45.48%)
# +++ FLAG_L2_FC_COMPLETENESS_TEST rejected 678 values (+0.24%)      TOTALS: flag 0: 107495 (38.46%) / flag 1: 44203 (15.82%) / flag 2: 127799 (45.72%)
# +++ FLAG_L2_FC_SCF_TEST rejected 194 values (+0.07%)      TOTALS: flag 0: 107273 (38.38%) / flag 1: 44231 (15.83%) / flag 2: 127993 (45.79%)
# +++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST rejected 9483 values (+3.39%)      TOTALS: flag 0: 103275 (36.95%) / flag 1: 38746 (13.86%) / flag 2: 137476 (49.19%)
# +++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST rejected 905 values (+0.32%)      TOTALS: flag 0: 102612 (36.71%) / flag 1: 38504 (13.78%) / flag 2: 138381 (49.51%)
# +++ FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 3821 values (+1.37%)      TOTALS: flag 0: 100085 (35.81%) / flag 1: 37210 (13.31%) / flag 2: 142202 (50.88%)
# +++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 100085 (35.81%) / flag 1: 37210 (13.31%) / flag 2: 142202 (50.88%)
# +++ FLAG_L2_FC_VM97_AOA_HF_TEST rejected 2607 values (+0.93%)      TOTALS: flag 0: 99138 (35.47%) / flag 1: 35550 (12.72%) / flag 2: 144809 (51.81%)
# +++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST rejected 1930 values (+0.69%)      TOTALS: flag 0: 98894 (35.38%) / flag 1: 33864 (12.12%) / flag 2: 146739 (52.50%)
# +++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST rejected 4091 values (+1.46%)      TOTALS: flag 0: 97180 (34.77%) / flag 1: 31487 (11.27%) / flag 2: 150830 (53.96%)
#
# In total, 150830 (53.96%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 1

# %%
fpc.level32_qcf.report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L3.2_NEE_L3.1_QCF, QCF FLAG FOR NEE_L3.1
# ========================================
# Between 2005-01-01 00:15 and 2023-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 279497 (83.91% of potential)
#     Available flux records AFTER quality checks: 128667 (46.04% of total)
#     Rejected flux records: 150830 (53.96% of total)
#     Potential flux records: 333072
#     Potential flux records missed: 53575 (16.09% of potential)

# %%
fpc.level32_qcf.report_qcf_flags()
# Out:
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 279497 values (83.91%)
#     OVERALL flag 2.0: 53575 values (16.09%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142850 values (87.30%)
#     DAYTIME flag 2.0: 20785 values (12.70%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136647 values (80.65%)
#     NIGHTTIME flag 2.0: 32790 values (19.35%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 109075 values (32.75%)
#     OVERALL flag 1.0: 119585 values (35.90%)
#     OVERALL flag 2.0: 53649 values (16.11%)
#     OVERALL flag missing: 50763 values (15.24%)
#
#     DAYTIME flag 0.0: 80020 values (48.90%)
#     DAYTIME flag 1.0: 44603 values (27.26%)
#     DAYTIME flag 2.0: 19234 values (11.75%)
#     DAYTIME flag missing: 19778 values (12.09%)
#
#     NIGHTTIME flag 0.0: 29055 values (17.15%)
#     NIGHTTIME flag 1.0: 74982 values (44.25%)
#     NIGHTTIME flag 2.0: 34415 values (20.31%)
#     NIGHTTIME flag missing: 30985 values (18.29%)
#
# FLAG_L2_FC_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 302128 values (90.71%)
#     OVERALL flag 1.0: 2234 values (0.67%)
#     OVERALL flag 2.0: 2869 values (0.86%)
#     OVERALL flag missing: 25841 values (7.76%)
#
#     DAYTIME flag 0.0: 148529 values (90.77%)
#     DAYTIME flag 1.0: 1109 values (0.68%)
#     DAYTIME flag 2.0: 1155 values (0.71%)
#     DAYTIME flag missing: 12842 values (7.85%)
#
#     NIGHTTIME flag 0.0: 153599 values (90.65%)
#     NIGHTTIME flag 1.0: 1125 values (0.66%)
#     NIGHTTIME flag 2.0: 1714 values (1.01%)
#     NIGHTTIME flag missing: 12999 values (7.67%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 281404 values (84.49%)
#     OVERALL flag 1.0: 688 values (0.21%)
#     OVERALL flag 2.0: 217 values (0.07%)
#     OVERALL flag missing: 50763 values (15.24%)
#
#     DAYTIME flag 0.0: 143683 values (87.81%)
#     DAYTIME flag 1.0: 145 values (0.09%)
#     DAYTIME flag 2.0: 29 values (0.02%)
#     DAYTIME flag missing: 19778 values (12.09%)
#
#     NIGHTTIME flag 0.0: 137721 values (81.28%)
#     NIGHTTIME flag 1.0: 543 values (0.32%)
#     NIGHTTIME flag 2.0: 188 values (0.11%)
#     NIGHTTIME flag missing: 30985 values (18.29%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 250009 values (75.06%)
#     OVERALL flag 2.0: 60270 values (18.10%)
#     OVERALL flag missing: 22793 values (6.84%)
#
#     DAYTIME flag 0.0: 136000 values (83.11%)
#     DAYTIME flag 2.0: 16235 values (9.92%)
#     DAYTIME flag missing: 11400 values (6.97%)
#
#     NIGHTTIME flag 0.0: 114009 values (67.29%)
#     NIGHTTIME flag 2.0: 44035 values (25.99%)
#     NIGHTTIME flag missing: 11393 values (6.72%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 310613 values (93.26%)
#     OVERALL flag 2.0: 1556 values (0.47%)
#     OVERALL flag missing: 20903 values (6.28%)
#
#     DAYTIME flag 0.0: 152444 values (93.16%)
#     DAYTIME flag 2.0: 834 values (0.51%)
#     DAYTIME flag missing: 10357 values (6.33%)
#
#     NIGHTTIME flag 0.0: 158169 values (93.35%)
#     NIGHTTIME flag 2.0: 722 values (0.43%)
#     NIGHTTIME flag missing: 10546 values (6.22%)
#
# FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 297217 values (89.24%)
#     OVERALL flag 2.0: 14952 values (4.49%)
#     OVERALL flag missing: 20903 values (6.28%)
#
#     DAYTIME flag 0.0: 145494 values (88.91%)
#     DAYTIME flag 2.0: 7784 values (4.76%)
#     DAYTIME flag missing: 10357 values (6.33%)
#
#     NIGHTTIME flag 0.0: 151723 values (89.55%)
#     NIGHTTIME flag 2.0: 7168 values (4.23%)
#     NIGHTTIME flag missing: 10546 values (6.22%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 312169 values (93.72%)
#     OVERALL flag missing: 20903 values (6.28%)
#
#     DAYTIME flag 0.0: 153278 values (93.67%)
#     DAYTIME flag missing: 10357 values (6.33%)
#
#     NIGHTTIME flag 0.0: 158891 values (93.78%)
#     NIGHTTIME flag missing: 10546 values (6.22%)
#
# FLAG_L2_FC_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 27738 values (8.33%)
#     OVERALL flag 2.0: 8024 values (2.41%)
#     OVERALL flag missing: 297310 values (89.26%)
#
#     DAYTIME flag 0.0: 13575 values (8.30%)
#     DAYTIME flag 2.0: 4296 values (2.63%)
#     DAYTIME flag missing: 145764 values (89.08%)
#
#     NIGHTTIME flag 0.0: 14163 values (8.36%)
#     NIGHTTIME flag 2.0: 3728 values (2.20%)
#     NIGHTTIME flag missing: 151546 values (89.44%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 99138 values (29.76%)
#     OVERALL flag 1.0: 35550 values (10.67%)
#     OVERALL flag 2.0: 198384 values (59.56%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 74235 values (45.37%)
#     DAYTIME flag 1.0: 35550 values (21.73%)
#     DAYTIME flag 2.0: 53850 values (32.91%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 24903 values (14.70%)
#     NIGHTTIME flag 2.0: 144534 values (85.30%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 331142 values (99.42%)
#     OVERALL flag 2.0: 1930 values (0.58%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 161801 values (98.88%)
#     DAYTIME flag 2.0: 1834 values (1.12%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 169341 values (99.94%)
#     NIGHTTIME flag 2.0: 96 values (0.06%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 328981 values (98.77%)
#     OVERALL flag 2.0: 4091 values (1.23%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 160889 values (98.32%)
#     DAYTIME flag 2.0: 2746 values (1.68%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 168092 values (99.21%)
#     NIGHTTIME flag 2.0: 1345 values (0.79%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 97180 values (29.18%)
#     OVERALL flag 1.0: 31487 values (9.45%)
#     OVERALL flag 2.0: 204405 values (61.37%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 73718 values (45.05%)
#     DAYTIME flag 1.0: 31487 values (19.24%)
#     DAYTIME flag 2.0: 58430 values (35.71%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 23462 values (13.85%)
#     NIGHTTIME flag 2.0: 145975 values (86.15%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 279497 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142850 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136647 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 108139 values (38.69%)
#     OVERALL flag 1.0: 118184 values (42.28%)
#     OVERALL flag 2.0: 53174 values (19.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 79502 values (55.65%)
#     DAYTIME flag 1.0: 44237 values (30.97%)
#     DAYTIME flag 2.0: 19111 values (13.38%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 28637 values (20.96%)
#     NIGHTTIME flag 1.0: 73947 values (54.12%)
#     NIGHTTIME flag 2.0: 34063 values (24.93%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 277099 values (99.14%)
#     OVERALL flag 1.0: 898 values (0.32%)
#     OVERALL flag 2.0: 1500 values (0.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 141782 values (99.25%)
#     DAYTIME flag 1.0: 506 values (0.35%)
#     DAYTIME flag 2.0: 562 values (0.39%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135317 values (99.03%)
#     NIGHTTIME flag 1.0: 392 values (0.29%)
#     NIGHTTIME flag 2.0: 938 values (0.69%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 278592 values (99.68%)
#     OVERALL flag 1.0: 688 values (0.25%)
#     OVERALL flag 2.0: 217 values (0.08%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142676 values (99.88%)
#     DAYTIME flag 1.0: 145 values (0.10%)
#     DAYTIME flag 2.0: 29 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135916 values (99.47%)
#     NIGHTTIME flag 1.0: 543 values (0.40%)
#     NIGHTTIME flag 2.0: 188 values (0.14%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 240695 values (86.12%)
#     OVERALL flag 2.0: 38802 values (13.88%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 132156 values (92.51%)
#     DAYTIME flag 2.0: 10694 values (7.49%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 108539 values (79.43%)
#     NIGHTTIME flag 2.0: 28108 values (20.57%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 277974 values (99.46%)
#     OVERALL flag 2.0: 1523 values (0.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142029 values (99.43%)
#     DAYTIME flag 2.0: 821 values (0.57%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135945 values (99.49%)
#     NIGHTTIME flag 2.0: 702 values (0.51%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 271050 values (96.98%)
#     OVERALL flag 2.0: 8447 values (3.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 138278 values (96.80%)
#     DAYTIME flag 2.0: 4572 values (3.20%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 132772 values (97.16%)
#     NIGHTTIME flag 2.0: 3875 values (2.84%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 279497 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142850 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136647 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 24570 values (8.79%)
#     OVERALL flag 2.0: 6868 values (2.46%)
#     OVERALL flag missing: 248059 values (88.75%)
#
#     DAYTIME flag 0.0: 12279 values (8.60%)
#     DAYTIME flag 2.0: 3717 values (2.60%)
#     DAYTIME flag missing: 126854 values (88.80%)
#
#     NIGHTTIME flag 0.0: 12291 values (8.99%)
#     NIGHTTIME flag 2.0: 3151 values (2.31%)
#     NIGHTTIME flag missing: 121205 values (88.70%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 99138 values (35.47%)
#     OVERALL flag 1.0: 35550 values (12.72%)
#     OVERALL flag 2.0: 144809 values (51.81%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 74235 values (51.97%)
#     DAYTIME flag 1.0: 35550 values (24.89%)
#     DAYTIME flag 2.0: 33065 values (23.15%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 24903 values (18.22%)
#     NIGHTTIME flag 2.0: 111744 values (81.78%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 277567 values (99.31%)
#     OVERALL flag 2.0: 1930 values (0.69%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 141016 values (98.72%)
#     DAYTIME flag 2.0: 1834 values (1.28%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136551 values (99.93%)
#     NIGHTTIME flag 2.0: 96 values (0.07%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 275406 values (98.54%)
#     OVERALL flag 2.0: 4091 values (1.46%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 140104 values (98.08%)
#     DAYTIME flag 2.0: 2746 values (1.92%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135302 values (99.02%)
#     NIGHTTIME flag 2.0: 1345 values (0.98%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 97180 values (34.77%)
#     OVERALL flag 1.0: 31487 values (11.27%)
#     OVERALL flag 2.0: 150830 values (53.96%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 73718 values (51.61%)
#     DAYTIME flag 1.0: 31487 values (22.04%)
#     DAYTIME flag 2.0: 37645 values (26.35%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 23462 values (17.17%)
#     NIGHTTIME flag 2.0: 113185 values (82.83%)
#     NIGHTTIME flag missing: 0 values (0.00%)

# %% [markdown]
# </br>

# %% [markdown]
# ## Save Level-3.2 results to file
# - If needed, save results so far (input data and all created variables, e.g. flags and filtered fluxes) to a file
# - This can be useful if e.g. USTAR filtering is not needed and gap-filling is done elsewhere (ReddyProc...)

# %%
# results_df = fpc.get_data()
# filename = "51.1_FluxProcessingChain_after-L3.3_NEE"
# results_df.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=results_df, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-3.3: **USTAR FILTERING**

# %% [markdown]
# ---

# %% [markdown]
# - Daytime and nighttime data are filtered based on USTAR thresholds
# - Example USTAR thresholds from the analysis done by FLUXNET (2005-2023) for the intensively managed grassland [CH-CHA, Chamau](https://www.swissfluxnet.ethz.ch/index.php/sites/site-info-ch-cha/):
#     - CUT_16: `0.0529445`
#     - CUT_50: `0.0698982`
#     - CUT_84: `0.0928408`

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     No USTAR filtering for: <b>H, LE, ET and FH2O.</b>
# </div>

# %% [markdown]
# > The USTAR filtering is not applied to H and LE, because it has not been proved that when there are CO2 advective fluxes, these also impact energy fluxes, specifically due to the fact that when advection is in general large (nighttime), energy fluxes are small.
#
# source: [Pastorello et al. (2020). The FLUXNET2015 dataset and the ONEFlux processing pipeline for eddy covariance data](https://doi.org/10.1038/s41597-020-0534-3)

# %%
USTAR_SCENARIOS = ['CUT_50']
USTAR_THRESHOLDS = [0.0698982]
# USTAR_SCENARIOS = ['CUT_16', 'CUT_50', 'CUT_84']
# USTAR_THRESHOLDS = [0.0529445, 0.0698982, 0.0928408]
fpc.level33_constant_ustar(thresholds=USTAR_THRESHOLDS,
                           threshold_labels=USTAR_SCENARIOS,
                           showplot=False)
# Out:
# [FlagSingleConstantUstarThreshold]  running FlagSingleConstantUstarThreshold ...
# Total found outliers for USTAR threshold _L3.3_CUT_50 0.0698982: 82234 values

# %% [markdown]
# </br>

# %% [markdown]
# ## **Finalize Level-3.3**: Caculate overall final quality flag

# %%
# Finalize: stores results for each USTAR scenario in a dict
fpc.finalize_level33()
# Out:
# Calculating overall quality flag QCF for USTAR scenario CUT_50...
# ++Added new column FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST.
# ++Added new column SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.3_CUT_50_NEE_L3.1_FLAGS.
# ++Added new column FLAG_L3.3_CUT_50_NEE_L3.1_QCF.
# ++Added new column NEE_L3.1_L3.3_CUT_50_QCF.
# ++Added new column NEE_L3.1_L3.3_CUT_50_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.3` variables
# - This shows all available Level-3.3 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.3' in x]
# Out:
# ['FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST',
#  'SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS',
#  'SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS',
#  'SUM_L3.3_CUT_50_NEE_L3.1_FLAGS',
#  'FLAG_L3.3_CUT_50_NEE_L3.1_QCF',
#  'NEE_L3.1_L3.3_CUT_50_QCF',
#  'NEE_L3.1_L3.3_CUT_50_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plot filtered flux after Level-3.3
# In the four panels, from left to right:
# - flux after Level-3.1, before outlier removal and USTAR filtering
# - flux after Level-3.3, after outlier removal and USTAR filtering
# - sum of the individual test flags
# - overall flag `QCF` (quality control flag), where `0`=best quality, `1`=medium quality, `2`=bad quality

# %%
for key, value in fpc.level33_qcf.items():
    # TimeSeries(series=fpc.fpc_df[fluxhq]).plot_interactive()
    # TimeSeries(series=fpc.fpc_df[FLUXVAR33QCF[key].name]).plot()
    fpc.level33_qcf[key].showplot_qcf_heatmaps()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable NEE_L3.1.
#
# Number of NEE_L3.1 records before QC: 279497
# +++ FLAG_L2_FC_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 279497 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FC_SSITC_TEST rejected 127121 values (+45.48%)      TOTALS: flag 0: 108139 (38.69%) / flag 1: 44237 (15.83%) / flag 2: 127121 (45.48%)
# +++ FLAG_L2_FC_COMPLETENESS_TEST rejected 678 values (+0.24%)      TOTALS: flag 0: 107495 (38.46%) / flag 1: 44203 (15.82%) / flag 2: 127799 (45.72%)
# +++ FLAG_L2_FC_SCF_TEST rejected 194 values (+0.07%)      TOTALS: flag 0: 107273 (38.38%) / flag 1: 44231 (15.83%) / flag 2: 127993 (45.79%)
# +++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST rejected 9483 values (+3.39%)      TOTALS: flag 0: 103275 (36.95%) / flag 1: 38746 (13.86%) / flag 2: 137476 (49.19%)
# +++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST rejected 905 values (+0.32%)      TOTALS: flag 0: 102612 (36.71%) / flag 1: 38504 (13.78%) / flag 2: 138381 (49.51%)
# +++ FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 3821 values (+1.37%)      TOTALS: flag 0: 100085 (35.81%) / flag 1: 37210 (13.31%) / flag 2: 142202 (50.88%)
# +++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 100085 (35.81%) / flag 1: 37210 (13.31%) / flag 2: 142202 (50.88%)
# +++ FLAG_L2_FC_VM97_AOA_HF_TEST rejected 2607 values (+0.93%)      TOTALS: flag 0: 99138 (35.47%) / flag 1: 35550 (12.72%) / flag 2: 144809 (51.81%)
# +++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST rejected 1930 values (+0.69%)      TOTALS: flag 0: 98894 (35.38%) / flag 1: 33864 (12.12%) / flag 2: 146739 (52.50%)
# +++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST rejected 4091 values (+1.46%)      TOTALS: flag 0: 97180 (34.77%) / flag 1: 31487 (11.27%) / flag 2: 150830 (53.96%)
# +++ FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST rejected 15267 values (+5.46%)      TOTALS: flag 0: 87564 (31.33%) / flag 1: 25836 (9.24%) / flag 2: 166097 (59.43%)
#
# In total, 166097 (59.43%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 1

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L3.3_CUT_50_NEE_L3.1_QCF, QCF FLAG FOR NEE_L3.1
# ========================================
# Between 2005-01-01 00:15 and 2023-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 279497 (83.91% of potential)
#     Available flux records AFTER quality checks: 113400 (40.57% of total)
#     Rejected flux records: 166097 (59.43% of total)
#     Potential flux records: 333072
#     Potential flux records missed: 53575 (16.09% of potential)

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_flags()
# Out:
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 279497 values (83.91%)
#     OVERALL flag 2.0: 53575 values (16.09%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142850 values (87.30%)
#     DAYTIME flag 2.0: 20785 values (12.70%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136647 values (80.65%)
#     NIGHTTIME flag 2.0: 32790 values (19.35%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 109075 values (32.75%)
#     OVERALL flag 1.0: 119585 values (35.90%)
#     OVERALL flag 2.0: 53649 values (16.11%)
#     OVERALL flag missing: 50763 values (15.24%)
#
#     DAYTIME flag 0.0: 80020 values (48.90%)
#     DAYTIME flag 1.0: 44603 values (27.26%)
#     DAYTIME flag 2.0: 19234 values (11.75%)
#     DAYTIME flag missing: 19778 values (12.09%)
#
#     NIGHTTIME flag 0.0: 29055 values (17.15%)
#     NIGHTTIME flag 1.0: 74982 values (44.25%)
#     NIGHTTIME flag 2.0: 34415 values (20.31%)
#     NIGHTTIME flag missing: 30985 values (18.29%)
#
# FLAG_L2_FC_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 302128 values (90.71%)
#     OVERALL flag 1.0: 2234 values (0.67%)
#     OVERALL flag 2.0: 2869 values (0.86%)
#     OVERALL flag missing: 25841 values (7.76%)
#
#     DAYTIME flag 0.0: 148529 values (90.77%)
#     DAYTIME flag 1.0: 1109 values (0.68%)
#     DAYTIME flag 2.0: 1155 values (0.71%)
#     DAYTIME flag missing: 12842 values (7.85%)
#
#     NIGHTTIME flag 0.0: 153599 values (90.65%)
#     NIGHTTIME flag 1.0: 1125 values (0.66%)
#     NIGHTTIME flag 2.0: 1714 values (1.01%)
#     NIGHTTIME flag missing: 12999 values (7.67%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 281404 values (84.49%)
#     OVERALL flag 1.0: 688 values (0.21%)
#     OVERALL flag 2.0: 217 values (0.07%)
#     OVERALL flag missing: 50763 values (15.24%)
#
#     DAYTIME flag 0.0: 143683 values (87.81%)
#     DAYTIME flag 1.0: 145 values (0.09%)
#     DAYTIME flag 2.0: 29 values (0.02%)
#     DAYTIME flag missing: 19778 values (12.09%)
#
#     NIGHTTIME flag 0.0: 137721 values (81.28%)
#     NIGHTTIME flag 1.0: 543 values (0.32%)
#     NIGHTTIME flag 2.0: 188 values (0.11%)
#     NIGHTTIME flag missing: 30985 values (18.29%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 250009 values (75.06%)
#     OVERALL flag 2.0: 60270 values (18.10%)
#     OVERALL flag missing: 22793 values (6.84%)
#
#     DAYTIME flag 0.0: 136000 values (83.11%)
#     DAYTIME flag 2.0: 16235 values (9.92%)
#     DAYTIME flag missing: 11400 values (6.97%)
#
#     NIGHTTIME flag 0.0: 114009 values (67.29%)
#     NIGHTTIME flag 2.0: 44035 values (25.99%)
#     NIGHTTIME flag missing: 11393 values (6.72%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 310613 values (93.26%)
#     OVERALL flag 2.0: 1556 values (0.47%)
#     OVERALL flag missing: 20903 values (6.28%)
#
#     DAYTIME flag 0.0: 152444 values (93.16%)
#     DAYTIME flag 2.0: 834 values (0.51%)
#     DAYTIME flag missing: 10357 values (6.33%)
#
#     NIGHTTIME flag 0.0: 158169 values (93.35%)
#     NIGHTTIME flag 2.0: 722 values (0.43%)
#     NIGHTTIME flag missing: 10546 values (6.22%)
#
# FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 297217 values (89.24%)
#     OVERALL flag 2.0: 14952 values (4.49%)
#     OVERALL flag missing: 20903 values (6.28%)
#
#     DAYTIME flag 0.0: 145494 values (88.91%)
#     DAYTIME flag 2.0: 7784 values (4.76%)
#     DAYTIME flag missing: 10357 values (6.33%)
#
#     NIGHTTIME flag 0.0: 151723 values (89.55%)
#     NIGHTTIME flag 2.0: 7168 values (4.23%)
#     NIGHTTIME flag missing: 10546 values (6.22%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 312169 values (93.72%)
#     OVERALL flag missing: 20903 values (6.28%)
#
#     DAYTIME flag 0.0: 153278 values (93.67%)
#     DAYTIME flag missing: 10357 values (6.33%)
#
#     NIGHTTIME flag 0.0: 158891 values (93.78%)
#     NIGHTTIME flag missing: 10546 values (6.22%)
#
# FLAG_L2_FC_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 27738 values (8.33%)
#     OVERALL flag 2.0: 8024 values (2.41%)
#     OVERALL flag missing: 297310 values (89.26%)
#
#     DAYTIME flag 0.0: 13575 values (8.30%)
#     DAYTIME flag 2.0: 4296 values (2.63%)
#     DAYTIME flag missing: 145764 values (89.08%)
#
#     NIGHTTIME flag 0.0: 14163 values (8.36%)
#     NIGHTTIME flag 2.0: 3728 values (2.20%)
#     NIGHTTIME flag missing: 151546 values (89.44%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 99138 values (29.76%)
#     OVERALL flag 1.0: 35550 values (10.67%)
#     OVERALL flag 2.0: 198384 values (59.56%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 74235 values (45.37%)
#     DAYTIME flag 1.0: 35550 values (21.73%)
#     DAYTIME flag 2.0: 53850 values (32.91%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 24903 values (14.70%)
#     NIGHTTIME flag 2.0: 144534 values (85.30%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 331142 values (99.42%)
#     OVERALL flag 2.0: 1930 values (0.58%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 161801 values (98.88%)
#     DAYTIME flag 2.0: 1834 values (1.12%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 169341 values (99.94%)
#     NIGHTTIME flag 2.0: 96 values (0.06%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 328981 values (98.77%)
#     OVERALL flag 2.0: 4091 values (1.23%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 160889 values (98.32%)
#     DAYTIME flag 2.0: 2746 values (1.68%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 168092 values (99.21%)
#     NIGHTTIME flag 2.0: 1345 values (0.79%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 97180 values (29.18%)
#     OVERALL flag 1.0: 31487 values (9.45%)
#     OVERALL flag 2.0: 204405 values (61.37%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 73718 values (45.05%)
#     DAYTIME flag 1.0: 31487 values (19.24%)
#     DAYTIME flag 2.0: 58430 values (35.71%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 23462 values (13.85%)
#     NIGHTTIME flag 2.0: 145975 values (86.15%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 250838 values (75.31%)
#     OVERALL flag 2.0: 82234 values (24.69%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 144102 values (88.06%)
#     DAYTIME flag 2.0: 19533 values (11.94%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 106736 values (62.99%)
#     NIGHTTIME flag 2.0: 62701 values (37.01%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 87564 values (26.29%)
#     OVERALL flag 1.0: 25836 values (7.76%)
#     OVERALL flag 2.0: 219672 values (65.95%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 68939 values (42.13%)
#     DAYTIME flag 1.0: 25836 values (15.79%)
#     DAYTIME flag 2.0: 68860 values (42.08%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 18625 values (10.99%)
#     NIGHTTIME flag 2.0: 150812 values (89.01%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 279497 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142850 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136647 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 108139 values (38.69%)
#     OVERALL flag 1.0: 118184 values (42.28%)
#     OVERALL flag 2.0: 53174 values (19.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 79502 values (55.65%)
#     DAYTIME flag 1.0: 44237 values (30.97%)
#     DAYTIME flag 2.0: 19111 values (13.38%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 28637 values (20.96%)
#     NIGHTTIME flag 1.0: 73947 values (54.12%)
#     NIGHTTIME flag 2.0: 34063 values (24.93%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 277099 values (99.14%)
#     OVERALL flag 1.0: 898 values (0.32%)
#     OVERALL flag 2.0: 1500 values (0.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 141782 values (99.25%)
#     DAYTIME flag 1.0: 506 values (0.35%)
#     DAYTIME flag 2.0: 562 values (0.39%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135317 values (99.03%)
#     NIGHTTIME flag 1.0: 392 values (0.29%)
#     NIGHTTIME flag 2.0: 938 values (0.69%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 278592 values (99.68%)
#     OVERALL flag 1.0: 688 values (0.25%)
#     OVERALL flag 2.0: 217 values (0.08%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142676 values (99.88%)
#     DAYTIME flag 1.0: 145 values (0.10%)
#     DAYTIME flag 2.0: 29 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135916 values (99.47%)
#     NIGHTTIME flag 1.0: 543 values (0.40%)
#     NIGHTTIME flag 2.0: 188 values (0.14%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 240695 values (86.12%)
#     OVERALL flag 2.0: 38802 values (13.88%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 132156 values (92.51%)
#     DAYTIME flag 2.0: 10694 values (7.49%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 108539 values (79.43%)
#     NIGHTTIME flag 2.0: 28108 values (20.57%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 277974 values (99.46%)
#     OVERALL flag 2.0: 1523 values (0.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142029 values (99.43%)
#     DAYTIME flag 2.0: 821 values (0.57%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135945 values (99.49%)
#     NIGHTTIME flag 2.0: 702 values (0.51%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 271050 values (96.98%)
#     OVERALL flag 2.0: 8447 values (3.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 138278 values (96.80%)
#     DAYTIME flag 2.0: 4572 values (3.20%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 132772 values (97.16%)
#     NIGHTTIME flag 2.0: 3875 values (2.84%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 279497 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 142850 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136647 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 24570 values (8.79%)
#     OVERALL flag 2.0: 6868 values (2.46%)
#     OVERALL flag missing: 248059 values (88.75%)
#
#     DAYTIME flag 0.0: 12279 values (8.60%)
#     DAYTIME flag 2.0: 3717 values (2.60%)
#     DAYTIME flag missing: 126854 values (88.80%)
#
#     NIGHTTIME flag 0.0: 12291 values (8.99%)
#     NIGHTTIME flag 2.0: 3151 values (2.31%)
#     NIGHTTIME flag missing: 121205 values (88.70%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 99138 values (35.47%)
#     OVERALL flag 1.0: 35550 values (12.72%)
#     OVERALL flag 2.0: 144809 values (51.81%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 74235 values (51.97%)
#     DAYTIME flag 1.0: 35550 values (24.89%)
#     DAYTIME flag 2.0: 33065 values (23.15%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 24903 values (18.22%)
#     NIGHTTIME flag 2.0: 111744 values (81.78%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 277567 values (99.31%)
#     OVERALL flag 2.0: 1930 values (0.69%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 141016 values (98.72%)
#     DAYTIME flag 2.0: 1834 values (1.28%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 136551 values (99.93%)
#     NIGHTTIME flag 2.0: 96 values (0.07%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 275406 values (98.54%)
#     OVERALL flag 2.0: 4091 values (1.46%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 140104 values (98.08%)
#     DAYTIME flag 2.0: 2746 values (1.92%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 135302 values (99.02%)
#     NIGHTTIME flag 2.0: 1345 values (0.98%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 97180 values (34.77%)
#     OVERALL flag 1.0: 31487 values (11.27%)
#     OVERALL flag 2.0: 150830 values (53.96%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 73718 values (51.61%)
#     DAYTIME flag 1.0: 31487 values (22.04%)
#     DAYTIME flag 2.0: 37645 values (26.35%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 23462 values (17.17%)
#     NIGHTTIME flag 2.0: 113185 values (82.83%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 209632 values (75.00%)
#     OVERALL flag 2.0: 69865 values (25.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 125666 values (87.97%)
#     DAYTIME flag 2.0: 17184 values (12.03%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 83966 values (61.45%)
#     NIGHTTIME flag 2.0: 52681 values (38.55%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 87564 values (31.33%)
#     OVERALL flag 1.0: 25836 values (9.24%)
#     OVERALL flag 2.0: 166097 values (59.43%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 68939 values (48.26%)
#     DAYTIME flag 1.0: 25836 values (18.09%)
#     DAYTIME flag 2.0: 48075 values (33.65%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 18625 values (13.63%)
#     NIGHTTIME flag 2.0: 118022 values (86.37%)
#     NIGHTTIME flag missing: 0 values (0.00%)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Overview: data after `Level-3.3`

# %% [markdown]
# ## Flux variable names

# %%
fluxes_qcf = [c for c in fpc.fpc_df.columns if str(c).endswith("_QCF") and not str(c).startswith("FLAG_") and "L3.3" in c]
fluxes_qcf0 = [c for c in fpc.fpc_df.columns if
               str(c).endswith("_QCF0") and not str(c).startswith("FLAG_") and "L3.3" in c]
print(f"Quality-controlled fluxes: {fluxes_qcf}")
print(f"Quality-controlled fluxes, HIGHEST QUALITY: {fluxes_qcf0}")
if (DAYTIME_ACCEPT_QCF_BELOW == 1) & (NIGHTTIMETIME_ACCEPT_QCF_BELOW == 1):
    print(f"{'*' * 100}\nNote that since only QCF below 1 is accepted for daytime and nighttime data, "
          f"the _QCF and _QCF0 variables are identical.")
# Out:
# Quality-controlled fluxes: ['NEE_L3.1_L3.3_CUT_50_QCF']
# Quality-controlled fluxes, HIGHEST QUALITY: ['NEE_L3.1_L3.3_CUT_50_QCF0']

# %% [markdown]
# </br>

# %%
FLUXVAR2QCF = fpc.filteredseries_level2_qcf.name
FLUXVAR31QCF = fpc.filteredseries_level31_qcf.name
FLUXVAR32QCF = fpc.filteredseries_level32_qcf.name
FLUXVAR32QCF_HQ = f"{FLUXVAR32QCF}0"
FLUXVAR33QCF = fpc.filteredseries_level33_qcf

print("--------------------------")
print("OVERVIEW OF FLUX VARIABLES")
print("--------------------------")
print(
    f""
    f"{FLUXVAR} ... original input flux\n"
    f"{FLUXVAR2QCF} ... flux quality-controlled with Level-2 flags\n    -->  not used in any further processing steps\n"
    f"{FLUXVAR31QCF} ... flux quality-controlled with Level-2 flags, including Level-3.1 storage correction\n   -->  not used in any further processing steps\n"
    f"{FLUXVAR32QCF} ... flux quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)\n    -->  not used in any further processing steps\n"
    f"{FLUXVAR32QCF_HQ} ... highest-quality flux (QCF=0), quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)\n    -->  not used in any further processing steps\n"
)
print("Variables for further steps:")
for key, value in FLUXVAR33QCF.items():
    print(
        f"{FLUXVAR33QCF[key].name} ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering ({key}), including Level-3.1 storage correction\n-->   to be used in gap-filling and all further steps")

if (DAYTIME_ACCEPT_QCF_BELOW == 1) & (NIGHTTIMETIME_ACCEPT_QCF_BELOW == 1):
    print(f"{'*' * 100}\nNote that since only QCF below 1 is accepted for daytime and nighttime data, "
          f"the _QCF and _QCF0 variables are identical.")
# Out:
# --------------------------
# OVERVIEW OF FLUX VARIABLES
# --------------------------
# FC ... original input flux
# FC_L2_QCF ... flux quality-controlled with Level-2 flags
#     -->  not used in any further processing steps
# NEE_L3.1_QCF ... flux quality-controlled with Level-2 flags, including Level-3.1 storage correction
#    -->  not used in any further processing steps
# NEE_L3.1_L3.2_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)
#     -->  not used in any further processing steps
# NEE_L3.1_L3.2_QCF0 ... highest-quality flux (QCF=0), quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)
#     -->  not used in any further processing steps
#
# Variables for further steps:
# NEE_L3.1_L3.3_CUT_50_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering (CUT_50), including Level-3.1 storage correction
# -->   to be used in gap-filling and all further steps

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot quality-controlled flux after `Level-3.3`
# - Plot flux after storage-correction, flux quality control, outlier removal and USTAR filtering

# %%
for key, value in FLUXVAR33QCF.items():
    # TimeSeries(series=fpc.fpc_df[fluxhq]).plot_interactive()
    TimeSeries(series=fpc.fpc_df[FLUXVAR33QCF[key].name]).plot()

# %%
# Creating a dictionary by passing Series objects as values

frame = {
    f'original ({FLUXVAR})': fpc.fpc_df[FLUXVAR],
    f'+ flux quality flags ({FLUXVAR2QCF})': fpc.fpc_df[FLUXVAR2QCF],
    f'++ storage correction ({FLUXVAR31QCF})': fpc.fpc_df[FLUXVAR31QCF],
    f'+++ outlier removal ({FLUXVAR32QCF})': fpc.fpc_df[FLUXVAR32QCF]
}
for key, value in FLUXVAR33QCF.items():
    frame[f'+++ USTAR filtering ({key}, {FLUXVAR33QCF[key].name})'] = FLUXVAR33QCF[key]

overview = pd.DataFrame(frame)
overview.cumsum().plot(title=f"Cumulative", figsize=(14, 7), x_compat=True, alpha=1);

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Available `Level-3.3` fluxes

# %%
_fluxcols = [x for x in fpc.fpc_df.columns if
             'L3.1' and 'L3.3' in x and str(x).endswith('_QCF') and not str(x).startswith('FLAG_')]
_fluxcols
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF']

# %%
_subset = fpc.fpc_df[_fluxcols].copy()
_subset.head()
# Out:
#                      NEE_L3.1_L3.3_CUT_50_QCF
# TIMESTAMP_MIDDLE
# 2005-01-01 00:15:00                       NaN
# 2005-01-01 00:45:00                       NaN
# 2005-01-01 01:15:00                       NaN
# 2005-01-01 01:45:00                       NaN
# 2005-01-01 02:15:00                       NaN

# %%
_subset.plot(subplots=True, x_compat=True,
             title="Available Level-3.3 fluxes after application of all quality checks", figsize=(12, 4.5));

# %%
# # Draw boxplots
# for _f in _fluxcols:
#     boxplots_df = fpc.fpc_df[[_f, "DAYTIME"]].copy()
#     boxplots_df["MONTH"] = boxplots_df.index.month
#     sns.set_theme(style="ticks", palette="pastel")
#     plt.figure(figsize=(12, 3))
#     sns.boxplot(x="MONTH", y=_f, palette=["r", "b"], hue="DAYTIME", data=boxplots_df).set_title(f"Boxplot of {_f}")
#     sns.despine(offset=10, trim=True)
#     plt.axhline(0, color="black");

# %%
# # Draw a nested violinplot and split the violins for easier comparison
# for _f in _fluxcols:
#     plt.figure(figsize=(20, 2))
#     sns.violinplot(data=boxplots_df, x="MONTH", y=fpc.fpc_df[_f], hue="DAYTIME", split=True, palette=["r", "b"], gap=.1,
#                    inner="quart")
#     plt.axhline(0, color="black")

# %% [markdown]
# </br>

# %% [markdown]
# ## Save Level-3.3 results to file
# - If needed, save results so far (input data and all created variables, e.g. flags and filtered fluxes) to a file
# - This can be useful if e.g. gap-filling should be done elsewhere (ReddyProc...)

# %%
# # results_df = fpc.get_data()
# out_df = fpc.fpc_df.copy()
# filename = "32.2_FluxProcessingChain_L3.3_NEE-results"
# out_df.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=out_df, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Export for MDS gap-filling in REddyProc

# %%
# from diive.core.times.times import insert_timestamp
# export = results_df.copy()

# %%
# exportcols = ['NEE_L3.1_L3.3_CUT_16_QCF', 'NEE_L3.1_L3.3_CUT_50_QCF', 'NEE_L3.1_L3.3_CUT_84_QCF',
#               'SW_IN_T1_2_1', 'TA_T1_2_1', 'VPD_T1_2_1']
# export = export[exportcols].copy()
# locs = (export.index.year >= 2005) & (export.index.year <= 2023)
# export = export[locs].copy()
# export = insert_timestamp(data=export, convention="end", set_as_index=True)
# export

# %%
# filename = "32.3_FluxProcessingChain_L3.3_NEE-subset-forREddyProc"
# export.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=export, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-4.1: **GAP-FILLING**

# %% [markdown]
# ---

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %%
MGMT_VARS = ["TIMESINCE_MGMT_FERT_MIN_FOOTPRINT", "TIMESINCE_MGMT_FERT_ORG_FOOTPRINT",
             "TIMESINCE_MGMT_GRAZING_FOOTPRINT", "TIMESINCE_MGMT_MOWING_FOOTPRINT",
             "TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT", "TIMESINCE_MGMT_SOWING_FOOTPRINT",
             "TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT"]
FEATURES = ["SW_IN_T1_2_1", "TA_T1_2_1", "VPD_T1_2_1"] + MGMT_VARS

fpc.level41_gapfilling_longterm(
    run_mds=False,
    run_random_forest=True,
    verbose=True,
    ml_feature_settings={
        'features': FEATURES,
        'features_lag': [-1, -1],
        'features_lag_exclude_cols': MGMT_VARS,  # Management variables are not lagged
        'reduce_features': True,
        'include_timestamp_as_features': True,
        'add_continuous_record_number': False,
        'perm_n_repeats': 10,
        },
    rf_settings={
        'n_estimators': 1000,
        'random_state': 42,
        'min_samples_split': 2,
        'min_samples_leaf': 1,
        'n_jobs': -1
        },
    # mds_settings={
    #     'swin': "SW_IN_T1_2_1",
    #     'ta': "TA_T1_2_1",
    #     'vpd': "VPD_T1_2_1",
    #     'swin_class': 50,
    #     'ta_class': 2.5,
    #     'vpd_class': 0.5,
    #     'min_n_vals_nt': 0
    # }
)
# Out:
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['SW_IN_T1_2_1', 'TA_T1_2_1', 'VPD_T1_2_1'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['TIMESINCE_MGMT_FERT_MIN_FOOTPRINT', 'TIMESINCE_MGMT_FERT_ORG_FOOTPRINT', 'TIMESINCE_MGMT_GRAZING_FOOTPRINT', 'TIMESINCE_MGMT_MOWING_FOOTPRINT', 'TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT', 'TIMESINCE_MGMT_SOWING_FOOTPRINT', 'TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT', 'NEE_L3.1_L3.3_CUT_50_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.MONTH', '.WEEK', '.DOY', '.HOUR', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2005-01-01 00:15:00 and 2023-12-31 23:45:00 ...
# [neighboring_years] Assigned [2005, 2006, 2007] to data pool for 2005.
# [neighboring_years] Assigned [2005, 2006, 2007] to data pool for 2006.
# [neighboring_years] Assigned [2006, 2007, 2008] to data pool for 2007.
# [neighboring_years] Assigned [2007, 2008, 2009] to data pool for 2008.
# [neighboring_years] Assigned [2008, 2009, 2010] to data pool for 2009.
# [neighboring_years] Assigned [2009, 2010, 2011] to data pool for 2010.
# [neighboring_years] Assigned [2010, 2011, 2012] to data pool for 2011.
# [neighboring_years] Assigned [2011, 2012, 2013] to data pool for 2012.
# [neighboring_years] Assigned [2012, 2013, 2014] to data pool for 2013.
# [neighboring_years] Assigned [2013, 2014, 2015] to data pool for 2014.
# [neighboring_years] Assigned [2014, 2015, 2016] to data pool for 2015.
# [neighboring_years] Assigned [2015, 2016, 2017] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2023.
# Initializing model for 2005 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2006 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2007 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2008 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2009 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2010 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2011 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2012 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2013 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2014 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2015 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# ---
# Reducing features based on permutation importance for year 2005 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.0147966376028681.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2006 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.0147966376028681.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2007 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.017195600602648776.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2008 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.018306237771248558.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2009 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.019370927808216754.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2010 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.01756946743656912.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2011 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.017333646662037117.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2012 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.017968584109675466.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2013 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.015684450758200862.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2014 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.017146238242682466.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2015 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.015572500083963436.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2016 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.016873235788502517.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2017 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.018455316718528226.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2018 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.01761291325851728.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2019 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.01785650295160146.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2020 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.014494127839645621.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2021 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.016578049775110536.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2022 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.016555951576394102.
# >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2023 ...
#
# Feature reduction based on permutation importance ...
# >>> Calculating feature importances (permutation importance, 10 repeats) ...
# >>> Setting threshold for feature rejection to 0.016555951576394102.
# >>> Removing rejected features from model data ...
# ---
# Finished reducing features based on permutation importance for all years.
# List of features after reduction: ['.DOY', '.HOUR', '.SEASON', '.SW_IN_T1_2_1-1', '.TA_T1_2_1-1', '.VPD_T1_2_1-1', '.WEEK', '.YEARDOY', '.YEARMONTH', '.YEARWEEK', 'SW_IN_T1_2_1', 'TA_T1_2_1', 'TIMESINCE_MGMT_FERT_MIN_FOOTPRINT', 'TIMESINCE_MGMT_FERT_ORG_FOOTPRINT', 'TIMESINCE_MGMT_GRAZING_FOOTPRINT', 'TIMESINCE_MGMT_MOWING_FOOTPRINT', 'TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT', 'TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT', 'TIMESINCE_MGMT_SOWING_FOOTPRINT', 'VPD_T1_2_1'].
# Each feature was selected in at least one year.
# ---
# [neighboring_years] Assigned [2005, 2006, 2007] to data pool for 2005.
# [neighboring_years] Assigned [2005, 2006, 2007] to data pool for 2006.
# [neighboring_years] Assigned [2006, 2007, 2008] to data pool for 2007.
# [neighboring_years] Assigned [2007, 2008, 2009] to data pool for 2008.
# [neighboring_years] Assigned [2008, 2009, 2010] to data pool for 2009.
# [neighboring_years] Assigned [2009, 2010, 2011] to data pool for 2010.
# [neighboring_years] Assigned [2010, 2011, 2012] to data pool for 2011.
# [neighboring_years] Assigned [2011, 2012, 2013] to data pool for 2012.
# [neighboring_years] Assigned [2012, 2013, 2014] to data pool for 2013.
# [neighboring_years] Assigned [2013, 2014, 2015] to data pool for 2014.
# [neighboring_years] Assigned [2014, 2015, 2016] to data pool for 2015.
# [neighboring_years] Assigned [2015, 2016, 2017] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2023.
# Initializing model for 2005 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2006 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2007 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2008 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2009 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2010 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2011 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2012 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2013 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2014 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2015 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Training model for 2005 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2005-07-27 11:45:00 and 2007-12-31 15:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2005 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 38130 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2006 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2005-07-27 11:45:00 and 2007-12-31 15:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2006 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 38130 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2007 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2006-01-01 10:45:00 and 2008-12-31 15:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2007 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34472 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2008 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2007-01-01 13:15:00 and 2009-12-31 16:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2008 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 37394 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2009 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2008-01-01 15:15:00 and 2010-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2009 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 36807 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2010 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2009-01-01 20:15:00 and 2011-12-30 19:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2010 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 35920 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2011 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2010-01-01 08:45:00 and 2012-12-31 14:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2011 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34243 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2012 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2011-01-01 10:15:00 and 2013-12-31 13:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2012 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34308 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2013 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2012-01-01 08:15:00 and 2014-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2013 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34241 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2014 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2013-01-01 13:15:00 and 2015-12-31 14:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2014 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 33569 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2015 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2014-01-01 10:45:00 and 2016-12-31 22:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2015 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 36888 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2015-01-01 13:45:00 and 2017-12-31 16:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 36583 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-01 09:45:00 and 2018-12-31 20:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 35488 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 02:15:00 and 2019-12-31 21:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 31406 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-01-01 05:45:00 and 2020-12-31 17:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 30715 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 05:45:00 and 2021-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 31116 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-01 03:15:00 and 2022-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 31308 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-01 09:15:00 and 2023-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 31951 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Training model for 2023 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-01 09:15:00 and 2023-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
# Gap-filling 2023 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 31951 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2005 ...
# Collecting results for 2006 ...
# Collecting results for 2007 ...
# Collecting results for 2008 ...
# Collecting results for 2009 ...
# Collecting results for 2010 ...
# Collecting results for 2011 ...
# Collecting results for 2012 ...
# Collecting results for 2013 ...
# Collecting results for 2014 ...
# Collecting results for 2015 ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# Collecting results for 2023 ...

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
results = fpc.get_data(verbose=1)
results
# Out:
# NEW VARIABLES FROM FLUX PROCESSING CHAIN:
# ++ FLAG_L2_FC_MISSING_TEST
# ++ FLAG_L2_FC_SSITC_TEST
# ++ FLAG_L2_FC_COMPLETENESS_TEST
# ++ FLAG_L2_FC_SCF_TEST
# ++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST
# ++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST
# ++ FLAG_L2_FC_CO2_VM97_AMPLITUDE_RESOLUTION_HF_TEST
# ++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST
# ++ FLAG_L2_FC_VM97_AOA_HF_TEST
# ++ SUM_L2_FC_HARDFLAGS
# ++ SUM_L2_FC_SOFTFLAGS
# ++ SUM_L2_FC_FLAGS
# ++ FLAG_L2_FC_QCF
# ++ FC_L2_QCF
# ++ FC_L2_QCF0
# ++ SC_SINGLE_gfRMED_L3.1
# ++ FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED
# ++ NEE_L3.1
# ++ NEE_L3.1_QCF
# ++ NEE_L3.1_QCF0
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST
# ++ SUM_L3.2_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.2_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.2_NEE_L3.1_FLAGS
# ++ FLAG_L3.2_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.2_QCF
# ++ NEE_L3.1_L3.2_QCF0
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF0
# ++ NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# ++ FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED
# No variables in input data were overwritten, only new variables added.
#                        AIR_MV  AIR_DENSITY  AIR_RHO_CP   AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  SUM_L3.3_CUT_50_NEE_L3.1_FLAGS  FLAG_L3.3_CUT_50_NEE_L3.1_QCF  NEE_L3.1_L3.3_CUT_50_QCF  NEE_L3.1_L3.3_CUT_50_QCF0  NEE_L3.1_L3.3_CUT_50_QCF_gfRF  FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED
# TIMESTAMP_MIDDLE                                                                                   ...
# 2005-01-01 00:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       1.090249                                            1
# 2005-01-01 00:45:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       1.091413                                            1
# 2005-01-01 01:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       1.659150                                            1
# 2005-01-01 01:45:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       1.671205                                            1
# 2005-01-01 02:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       1.699090                                            1
# ...                       ...          ...         ...      ...         ...                   ...  ...                             ...                            ...                       ...                        ...                            ...                                          ...
# 2023-12-31 21:45:00  0.023667      1.22060     1231.56  1008.98         0.0                   1.0  ...                             4.0                            2.0                       NaN                        NaN                      -0.167606                                            1
# 2023-12-31 22:15:00  0.023709      1.21833     1229.43  1009.11         0.0                   1.0  ...                             4.0                            2.0                       NaN                        NaN                      -0.306642                                            1
# 2023-12-31 22:45:00  0.023718      1.21785     1228.93  1009.10         0.0                   1.0  ...                             1.0                            2.0                       NaN                        NaN                      -0.572163                                            1
# 2023-12-31 23:15:00  0.023710      1.21827     1229.34  1009.09         0.0                   1.0  ...                             0.0                            0.0                  1.190371                   1.190371                       1.190371                                            0
# 2023-12-31 23:45:00  0.023715      1.21807     1229.13  1009.08         0.0                   1.0  ...                             0.0                            0.0                  1.334124                   1.334124                       1.334124                                            0
#
# [333072 rows x 534 columns]

# %% [markdown]
# ## Model scores

# %%
fpc.report_gapfilling_model_scores()
# Out:
# MODEL SCORES (random_forest): CUT_50
#             2005       2006       2007       2008       2009       2010  ...       2018       2019       2020       2021       2022       2023
# mae     1.171922   1.171922   1.442564   1.716539   1.679392   1.351622  ...   1.133804   1.086451   1.175322   1.312718   1.413109   1.413109
# medae   0.568023   0.568023   0.675916   0.797423   0.768353   0.629363  ...   0.575942   0.549922   0.606069   0.641333   0.684289   0.684289
# mse     5.277356   5.277356   8.427767  12.334043  11.771475   7.933762  ...   4.709973   4.499816   5.102148   6.672469   8.176726   8.176726
# rmse    2.297250   2.297250   2.903062   3.511986   3.430958   2.816693  ...   2.170247   2.121277   2.258793   2.583112   2.859498   2.859498
# mape    0.748057   0.748057   0.770049   0.764953   0.584799   0.494619  ...   0.894780   0.715615   0.597818   0.538726   0.519381   0.519381
# maxe   40.741979  40.741979  50.752472  55.520180  62.457103  54.980297  ...  40.254185  40.156031  45.576882  50.959441  46.189418  46.189418
# r2      0.936702   0.936702   0.921285   0.900377   0.899226   0.908046  ...   0.934647   0.928592   0.932875   0.927248   0.920601   0.920601
#
# [7 rows x 19 columns]

# %%
fpc.report_gapfilling_feature_importances()
# Out:
# FEATURE IMPORTANCES (random_forest): CUT_50
# YEAR                                              2005      2006      2007      2008      2009      2010  ...      2018      2019      2020      2021      2022      2023
# FEATURE                                                                                                   ...
# SW_IN_T1_2_1                                  1.553339  1.553339  1.359284  1.366452  1.254999  1.402194  ...  1.353083  1.067996  1.107393  1.026889  1.162251  1.162251
# TIMESINCE_MGMT_MOWING_FOOTPRINT               0.285544  0.285544  0.297045  0.253026  0.258708  0.235531  ...  0.311543  0.278982  0.354390  0.353780  0.423633  0.423633
# .SW_IN_T1_2_1-1                               0.092978  0.092978  0.068567  0.055701  0.043383  0.048260  ...  0.048735  0.102464  0.104315  0.202989  0.107700  0.107700
# .YEARDOY                                      0.091976  0.091976  0.029871  0.040367  0.017000  0.020804  ...  0.018926  0.016753  0.020596  0.021276  0.015934  0.015934
# TA_T1_2_1                                     0.064852  0.064852  0.186504  0.113759  0.108159  0.075942  ...  0.086652  0.058738  0.089121  0.051420  0.045979  0.045979
# .TA_T1_2_1-1                                  0.062011  0.062011  0.055539  0.035509  0.037790  0.063311  ...  0.036986  0.052047  0.039865  0.051571  0.051005  0.051005
# .HOUR                                         0.057073  0.057073  0.070234  0.072239  0.066178  0.065263  ...  0.089649  0.095533  0.073963  0.065680  0.059228  0.059228
# VPD_T1_2_1                                    0.030339  0.030339  0.035309  0.052233  0.044564  0.027329  ...  0.027115  0.026694  0.028816  0.038178  0.042543  0.042543
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT             0.028849  0.028849  0.026418  0.035235  0.055050  0.055515  ...  0.013665  0.009807  0.015003  0.022925  0.048858  0.048858
# TIMESINCE_MGMT_SOWING_FOOTPRINT               0.028544  0.028544  0.023220  0.013871  0.012807  0.007363  ...  0.006401  0.006542  0.008848  0.008859  0.011351  0.011351
# .VPD_T1_2_1-1                                 0.023507  0.023507  0.033094  0.037855  0.040758  0.026894  ...  0.028494  0.028649  0.035027  0.042141  0.041579  0.041579
# TIMESINCE_MGMT_GRAZING_FOOTPRINT              0.020230  0.020230  0.012340  0.028603  0.017437  0.016716  ...  0.014123  0.018243  0.026258  0.041120  0.043512  0.043512
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT      0.017859  0.017859  0.020904  0.022671  0.021861  0.012541  ...  0.011594  0.006298  0.084367  0.103118  0.065042  0.065042
# .DOY                                          0.016799  0.016799  0.012002  0.016766  0.061014  0.088437  ...  0.020378  0.023732  0.012621  0.008705  0.011368  0.011368
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT             0.011217  0.011217  0.061881  0.016768  0.033556  0.043058  ...  0.010723  0.011937  0.011173  0.017820  0.023539  0.023539
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT  0.010400  0.010400  0.024427  0.009893  0.010964  0.007137  ...  0.034660  0.044251  0.057291  0.039469  0.052385  0.052385
# .YEARWEEK                                     0.003693  0.003693  0.010167  0.003232  0.005608  0.005795  ...  0.009336  0.014135  0.049613  0.021307  0.003796  0.003796
# .YEARMONTH                                    0.003098  0.003098  0.004231  0.003665  0.016765  0.016202  ...  0.031801  0.023614  0.002701  0.006362  0.002252  0.002252
# .SEASON                                       0.002600  0.002600  0.007792  0.031237  0.008302  0.003987  ...  0.011154  0.011965  0.021735  0.015844  0.004776  0.004776
# .WEEK                                         0.002029  0.002029  0.002557  0.003892  0.005557  0.005466  ...  0.005128  0.005152  0.024561  0.002084  0.001940  0.001940
#
# [20 rows x 19 columns]

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2005: random_forest used data from [2005, 2006, 2007] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2006: random_forest used data from [2005, 2006, 2007] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2007: random_forest used data from [2006, 2007, 2008] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2008: random_forest used data from [2007, 2008, 2009] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2009: random_forest used data from [2008, 2009, 2010] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2010: random_forest used data from [2009, 2010, 2011] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2011: random_forest used data from [2010, 2011, 2012] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2012: random_forest used data from [2011, 2012, 2013] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2013: random_forest used data from [2012, 2013, 2014] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2014: random_forest used data from [2013, 2014, 2015] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2015: random_forest used data from [2014, 2015, 2016] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2016: random_forest used data from [2015, 2016, 2017] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2017: random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2018: random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2019: random_forest used data from [2018, 2019, 2020] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2020: random_forest used data from [2019, 2020, 2021] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2021: random_forest used data from [2020, 2021, 2022] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2022: random_forest used data from [2021, 2022, 2023] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2023: random_forest used data from [2021, 2022, 2023] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# random_forest (CUT_50): NEE_L3.1_L3.3_CUT_50_QCF -> NEE_L3.1_L3.3_CUT_50_QCF_gfRF

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF_gfRF']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      NEE_L3.1_L3.3_CUT_50_QCF_gfRF  NEE_L3.1_L3.3_CUT_50_QCF
# TIMESTAMP_MIDDLE
# 2005-01-01 00:15:00                       1.090249                       NaN
# 2005-01-01 00:45:00                       1.091413                       NaN
# 2005-01-01 01:15:00                       1.659150                       NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF']

# %% [markdown]
# ## Plot: gap-filled heatmaps

# %%
fpc.showplot_gapfilled_heatmap()

# %% [markdown]
# ## Plot: Gap-filled cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=True)

# %% [markdown]
# ## Plot: gap-filled cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)

# %% [markdown]
# ## Plot: model feature ranks per year

# %%
fpc.showplot_feature_ranks_per_year()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Save results to file

# %% [markdown]
# ---

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %%
suffix = "NEE"

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results)

# %%
# outfile = f"FluxProcessingChain_L4.1_complete_{suffix}"
# results.to_csv(f"{outfile}.csv")  # large file, slow to read
# save_parquet(data=results, filename=f"{outfile}")  # Smaller file, very fast to read

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save flux processing chain results (without input data)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
outfile = f"41.1_FluxProcessingChain_L4.1_{suffix}"
fpc.fpc_df.to_csv(f"{outfile}.csv")  # large file, slow to read
save_parquet(data=fpc.fpc_df, filename=f"{outfile}")  # Smaller file, very fast to read
# Out:
# Saved file 41.1_FluxProcessingChain_L4.1_NEE.parquet (0.720 seconds).
# '41.1_FluxProcessingChain_L4.1_NEE.parquet'

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **End of notebook**

# %% [markdown]
# ---

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2024-12-10 17:11:02
