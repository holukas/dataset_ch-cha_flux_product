# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `9.1` (4 Mar 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **BACKGROUND**

# %% [markdown]
# ---

# %% [markdown]
# - This notebook demonstrates part of the flux post-processing used for fluxes from Swiss FluxNet research stations
# - For a description of the different flux levels, see [Flux Processing Chain](https://www.swissfluxnet.ethz.ch/index.php/data/ecosystem-fluxes/flux-processing-chain/)
# - Flux calculations (Level-1) were done in a previous step
# - This notebook uses the calculated fluxes (Level-1) and applies several post-processing steps:
#     - Quality flag extension (Level-2)
#     - Storage correction (Level-3.1)
#     - Outlier removal (Level-3.2)
#     - USTAR filtering (Level-3.3) - needs *known* thresholds from separate analysis, e.g. from FLUXNET
#     - Gap-filling (Level-4.1) for flux using multiple methods ([MDS](../GapFilling/FluxMDSGapFilling.ipynb), [long-term random forest](../GapFilling/LongTermRandomForestGapFilling.ipynb))
# - Other flux levels are currently not produced in this example:
#
#     - NEE Partitioning (Level-4.2)
#
# **Important**
# - Flux variable names in the input files should follow the [FLUXNET convention](https://fluxnet.org/data/fluxnet2015-dataset/fullset-data-product/)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **GENERAL SETTINGS**

# %% [markdown]
# ---

# %% [markdown]
# ## Flux variable
# `FLUXVAR` is the name of the flux variable in the data files. In the EddyPro `_fluxnet_` output files, the flux variables we primarily use are:
#   - `FC` ... CO2 flux, becomes `NEE` after storage correction (Level-3.1)
#   - `LE` ... Latent heat flux (water)
#   - `H` ... Sensible heat flux
#   - `FN2O` ... Nitrous oxide flux
#   - `FCH4` ... Methane flux
#
# There are more flux variables in the output file, but we rarely need them:
#   - `FH2O` ... H2O flux, very important but it is the same as `ET` and `LE` but with different units
#   - `ET` ... Evapotranspiration, very important but it is the same as `FH2O` and `LE` but with different units. We can easily calculte `ET` later from `LE`, e.g. in `ReddyProc`.
#   - `TAU` ... Momentum flux, a measure of the turbulent transfer of momentum between the land surface and the atmosphere
#
# Set the name of the flux variable in the output file(s), must use the FLUXNET naming convention, e.g. FC, FH2O, LE, ET, H, FN2O, FCH4:

# %%
FLUXVAR = "FN2O"

# %% [markdown]
# ## Site location
# - Latitude and longitude of the site where data were recorded. This info is mainly used to calculate potential radiation, which is then used to divide the dataset into daytime and nighttime data.
# - UTC offset of the timestamp used in the dataset, important for calculating potential radiation for this location with the correct timestamp.

# %%
SITE_LAT = 47.210227
SITE_LON = 8.410645
UTC_OFFSET = 1  # Time stamp offset in relation to UTC, e.g. 1 for UTC+01:00 (CET), important for the calculation of potential radiation for detecting daytime and nighttime

# %% [markdown]
# ## Daytime/nighttime
# - Threshold for potential radiation in `W m-2`, records below threshold are considered nighttime

# %%
NIGHTTIME_THRESHOLD = 20

# %% [markdown]
# ## Quality requirements
# - The default setting is to accept highest-quality and medium-quality fluxes for daytime (overall quality flag `QCF` = 0 or 1), and highest-quality fluxes only for nighttime (flag `QCF` = 0)
# - `DAYTIME_ACCEPT_QCF_BELOW = 2` accepts high- (`QCF=0`) and medium-quality (`QCF=1`) fluxes for *daytime*, rejects low-quality (`QCF=2`) fluxes
# - `NIGHTTIMETIME_ACCEPT_QCF_BELOW = 1` accepts high-quality (`QCF=0`) fluxes for *nighttime*, rejects medium-quality (`QCF=1`) and low-quality (`QCF=2`) fluxes
# - This strict quality-filtering removes a lot of data points during nighttime

# %%
DAYTIME_ACCEPT_QCF_BELOW = 2
NIGHTTIMETIME_ACCEPT_QCF_BELOW = 2

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **IMPORTS**

# %% [markdown]
# ---

# %% [markdown]
# - This notebook uses `diive` ([source code](https://github.com/holukas/diive)) to check eddy covariance fluxes for quality

# %%
import importlib.metadata
import warnings
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats
import seaborn as sns

from diive.core.dfun.stats import sstats  # Time series stats
from diive.core.io.files import save_parquet, load_parquet
from diive.core.plotting.timeseries import TimeSeries  # For simple (interactive) time series plotting
from diive.pkgs.flux.hqflux import analyze_highest_quality_flux
from diive.pkgs.fluxprocessingchain.fluxprocessingchain import FluxProcessingChain
from diive.pkgs.fluxprocessingchain.fluxprocessingchain import LoadEddyProOutputFiles

warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.86.0

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **DOCSTRING** for `FluxProcessingChain`

# %% [markdown]
# ---

# %%
# help(FluxProcessingChain)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **LOAD DATA** (2 options)

# %% [markdown]
# ---

# %% [markdown]
# - It is possible to load data from (multiple) EddyPro _fluxnet_ output files (data from files will be merged), or directly from one single [parquet](https://parquet.apache.org/) file.
# - parquet files are a good option for large datasets because they load and save much faster than when using conventional CSV files.
# - For large datasets, it makes sense to first load and merge data from the original EddyPro _fluxnet_ output files, then convert the merged data to one single parquet file and then use this file as input file.

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Load data from single or multiple EddyPro *_fluxnet_* output files
# - Used to read data from the EddyPro _fluxnet_ output files
# - Found files will be merged together into one single dataframe (`maindf`)

# %% [markdown]
# If you want to search for EddyPro _fluxnet_ files in specific locations, you can specify multiple folders here:

# %%
# # Folder(s) where input file(s) are located
# SOURCEDIRS = [r'example_data/']

# %%
# ep = LoadEddyProOutputFiles(sourcedir=SOURCEDIRS, filetype='EDDYPRO-FLUXNET-CSV-30MIN')
# ep.searchfiles()
# ep.loadfiles()
# maindf = ep.maindf
# metadata = ep.metadata

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Load data from `parquet` file
# - Can be used to continue a previous session where another flux variable was already post-processed
# - For example, if you have already post-processed CO2 flux and now want to post-process H2O flux
# - Also detects time resolution of time series, this info was lost when saving to the parquet file

# %% [markdown]
# If you want to load data directly from a specific parquet file, you can specify its name and location here:

# %%
SOURCEDIR = r"../30_MERGE_DATA"
FILENAME = r"33.5_CH-CHA_IRGA+QCL+LGR+M10+MGMT_Level-1_eddypro_fluxnet_2005-2024.parquet"
FILEPATH = Path(SOURCEDIR) / FILENAME
print(f"Data will be loaded from the following file:\n{FILEPATH}")
# Out:
# Data will be loaded from the following file:
# ..\30_MERGE_DATA\33.5_CH-CHA_IRGA+QCL+LGR+M10+MGMT_Level-1_eddypro_fluxnet_2005-2024.parquet

# %%
maindf = load_parquet(filepath=FILEPATH)
# Out:
# Loaded .parquet file ..\30_MERGE_DATA\33.5_CH-CHA_IRGA+QCL+LGR+M10+MGMT_Level-1_eddypro_fluxnet_2005-2024.parquet (4.591 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 3: Load example data

# %%
# from diive.configs.exampledata import load_exampledata_EDDYPRO_FLUXNET_CSV_30MIN
# maindf, metadata = load_exampledata_EDDYPRO_FLUXNET_CSV_30MIN()

# %% [markdown]
# </br>

# %% [markdown]
# ## (Optional) Restrict data to time range

# %%
# Restrict data range
maindf = maindf.loc[(maindf.index.year >= 2012) & (maindf.index.year <= 2022)].copy()

# %% [markdown]
# </br>

# %% [markdown]
# ## Check data

# %%
display(maindf.head(3))
display(maindf.tail(3))
display(sstats(maindf[FLUXVAR]))
# Out:
#                      .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6  .SWC_GF1_0.15_1_gfXG_MEAN3H-12  .SWC_GF1_0.15_1_gfXG_MEAN3H-18  ...   W_UNROT   W_U_COV  W_VM97_TEST   W_ZCD        ZL  ZL_UNCORR
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                    ...
# 2012-01-01 00:15:00                             0.57070                             1.00970                             1.53650                            0.72435                       47.686902                       47.485823  ...  0.022382 -0.035949  800000111.0  5356.0  0.069747   0.069651
# 2012-01-01 00:45:00                             0.65850                             0.85605                             1.58040                            0.70240                       47.700829                       47.515553  ...  0.022299 -0.003013  800000111.0  3291.0  0.203944   0.202421
# 2012-01-01 01:15:00                             0.59265                             0.81215                             1.55845                            0.87800                       47.711383                       47.553562  ...  0.016813 -0.010325  800000011.0  4613.0 -0.122844  -0.124493
#
# [3 rows x 537 columns]
#                      .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6  .SWC_GF1_0.15_1_gfXG_MEAN3H-12  .SWC_GF1_0.15_1_gfXG_MEAN3H-18  ...   W_UNROT   W_U_COV  W_VM97_TEST   W_ZCD        ZL  ZL_UNCORR
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                    ...
# 2022-12-31 22:45:00                                 0.0                                 0.0                                 0.0                                0.0                       40.148197                       40.229251  ... -0.002149  0.010704  800000011.0  4872.0  0.136834   0.135976
# 2022-12-31 23:15:00                                 0.0                                 0.0                                 0.0                                0.0                       40.136638                       40.213242  ...  0.001948  0.006083  800001111.0  1092.0 -0.526324  -0.526757
# 2022-12-31 23:45:00                                 0.0                                 0.0                                 0.0                                0.0                       40.124632                       40.198751  ... -0.010138  0.010709  800001111.0  2519.0  0.055496   0.055336
#
# [3 rows x 537 columns]
#                             FN2O
# STARTDATE       2012-01-01 00:15
# ENDDATE         2022-12-31 23:45
# PERIOD        4017 days 23:30:00
# NOV                       146459
# MISSING                    46405
# MISSING_PERC           24.060996
# MEAN                     1.17917
# MEDIAN                  0.208767
# SD                      85.96633
# VAR                  7390.209898
# SD/MEAN                72.904096
# SUM                172700.073211
# MIN                      -3218.0
# MAX                      22658.1
# P01                    -4.538268
# P05                    -1.185485
# P25                    -0.036305
# P75                     0.732423
# P95                     4.176293
# P99                    11.952488

# %%
# TimeSeries(series=maindf[FLUXVAR]).plot_interactive()
TimeSeries(series=maindf[FLUXVAR]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **START FLUX PROCESSING CHAIN**

# %% [markdown]
# ---

# %% [markdown]
# - First we need to initialize the processing chain by providing some basic info.
# - At the same time, some fundamental variables are also created: potential radiation, and two flags based on it: daytime flag (1=daytime) and nighttime flag (1=nighttime).

# %%
fpc = FluxProcessingChain(
    df=maindf,
    fluxcol=FLUXVAR,
    site_lat=SITE_LAT,
    site_lon=SITE_LON,
    utc_offset=UTC_OFFSET,    
    nighttime_threshold=NIGHTTIME_THRESHOLD,
    daytime_accept_qcf_below=DAYTIME_ACCEPT_QCF_BELOW,
    nighttimetime_accept_qcf_below=NIGHTTIMETIME_ACCEPT_QCF_BELOW
)
# Out:
# Detected base variable N2O for FN2O. (N2O was used to calculate FN2O.)
# Calculated potential radiation from latitude and longitude (SW_IN_POT) ...
# Calculated daytime flag DAYTIME and nighttime flag NIGHTTIME from SW_IN_POT ...
# ++ Added new columns ['SW_IN_POT', 'DAYTIME', 'NIGHTTIME'] to input data.

# %% [markdown]
# - Let's check the flux processing chain dataframe: this are the data the chain is working with in this run:

# %%
fpc.fpc_df
# Out:
#                      FN2O     USTAR  SW_IN_POT  DAYTIME  NIGHTTIME
# TIMESTAMP_MIDDLE
# 2012-01-01 00:15:00   NaN  0.191226        0.0      0.0        1.0
# 2012-01-01 00:45:00   NaN  0.056639        0.0      0.0        1.0
# 2012-01-01 01:15:00   NaN  0.105926        0.0      0.0        1.0
# 2012-01-01 01:45:00   NaN  0.061007        0.0      0.0        1.0
# 2012-01-01 02:15:00   NaN  0.079177        0.0      0.0        1.0
# ...                   ...       ...        ...      ...        ...
# 2022-12-31 21:45:00   NaN  0.104603        0.0      0.0        1.0
# 2022-12-31 22:15:00   NaN  0.076353        0.0      0.0        1.0
# 2022-12-31 22:45:00   NaN  0.120844        0.0      0.0        1.0
# 2022-12-31 23:15:00   NaN  0.079593        0.0      0.0        1.0
# 2022-12-31 23:45:00   NaN  0.107872        0.0      0.0        1.0
#
# [192864 rows x 5 columns]

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-2: **QUALITY FLAG EXTENSION**

# %% [markdown]
# ---

# %% [markdown]
# > Extract additional quality information from the EddyPro output and store it in newly added quality flags.
#
#
#
# Note that the USTAR filtering is not part of the Level-2 calculations.

# %% [markdown]
# </br>

# %% [markdown]
# ## User settings
# - A test for missing values is always included: flag calculated here from missing flux values in the EddyPro output file

# %% [markdown]
# </br>

# %% [markdown]
# ### SSITC tests (default: `True`)
# - Flag calculated in EddyPro
# - Combination of the two partial tests *steady state test* and *developed turbulent conditions test*
# - This notebook expects the SSITC flag to follow the flagging policy according to Mauder and Foken 2004:
#     - `0` for best quality fluxes
#     - `1` for fluxes suitable for general analysis such as annual budgets (although this is debatable for nighttime data)
#     - `2` for fluxes that should be discarded from the dataset

# %%
TEST_SSITC = True  # Default True
TEST_SSITC_SETFLAG_TIMEPERIOD = {2: [[1, '2022-05-01', '2023-09-30']]}

# %% [markdown]
# </br>

# %% [markdown]
# ### Flux base variable completeness test (default: `True`)
# - Flag newly calculated here
# - Check completeness of the variable that was used to calculate the respective flux
# - Example: `CO2` is the base variable that was used to calculate flux `FC`, the test is therefore run on `CO2`
# - Checks number of records of the relevant base variable available for each averaging Interval and calculates completeness flag as follows:
#     - `0` for files where >= 99% of base variable are available
#     - `1` for files where >= 97% and < 99% of base variable are available
#     - `2` for files where < 97% of base variable are available
#
# List of flux base variables and the corresponding fluxes:
# - `CO2`: used to calculate `FC`
# - `H2O`: used to calculate `FH2O`
# - `H2O`: used to calculate `LE`
# - `H2O`: used to calculate `ET`
# - `T_SONIC`: used to calculate `H`
# - `N2O`: used to calculate `FN2O`
# - `CH4`: used to calculate `FCH4`

# %%
TEST_GAS_COMPLETENESS = True  # Default True

# %% [markdown]
# </br>

# %% [markdown]
# ### Spectral correction factor test (default: `True`)
# - Flag calculated here from the gas `SCF` variable in EddyPro output file

# %%
TEST_SPECTRAL_CORRECTION_FACTOR = True  # Default True

# %% [markdown]
# </br>

# %% [markdown]
# ### Signal strength test

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Always recommended if flux was calculated using a gas analyzer.</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Do not use for H (sensible heat flux).</b> This test is only relevant for fluxes where the concentration/temperature was measured by a gas analyzer, e.g. FC, FH2O, LE, ET, N2O, CH4, etc ...
# </div>

# %% [markdown]
# - Signal strength / AGC / window dirtiness test (if available)
# - Flag calculated here from the signal strength / AGC variable for the gas analyzer in EddyPro output file
# - `SIGNAL_STRENGTH_COL`: Name of the column storing the signal strength, typically 'CUSTOM_AGC_MEAN' for LI-7500, 'CUSTOM_SIGNAL_STRENGTH_IRGA72_MEAN' for LI-7200, or something similar
# - `SIGNAL_STRENGTH_THRESHOLD`: Signal strength threshold, flux values where threshold is exceeded are flagged as rejected
# - `SIGNAL_STRENGTH_METHOD`: `discard above` flags fluxes where signal strength > threshold, `discard below` where signal strength < threshold

# %%
# Signal strength
TEST_SIGNAL_STRENGTH = False
TEST_SIGNAL_STRENGTH_COL = 'CUSTOM_AGC_MEAN'  # Typical variable name in fluxnet files
TEST_SIGNAL_STRENGTH_METHOD = 'discard above'
TEST_SIGNAL_STRENGTH_THRESHOLD = 90

# %%
# TimeSeries(series=df_orig[SIGNAL_STRENGTH_COL]).plot_interactive()
# TimeSeries(series=maindf[TEST_SIGNAL_STRENGTH_COL]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# ### Raw data screening tests
# - Flags were calculated in EddyPro
# - See here for more details: [Despiking and raw data statistical screening (EddyPro help)](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html)

# %%
TEST_RAWDATA = True  # Default True
TEST_RAWDATA_SPIKES = True  # Default True
TEST_RAWDATA_AMPLITUDE = True  # Default True
TEST_RAWDATA_DROPOUT = True  # Default True
TEST_RAWDATA_ABSLIM = False  # Default False
TEST_RAWDATA_SKEWKURT_HF = False  # Default False
TEST_RAWDATA_SKEWKURT_SF = False  # Default False
TEST_RAWDATA_DISCONT_HF = False  # Default False
TEST_RAWDATA_DISCONT_SF = False  # Default False

# %% [markdown]
# </br>

# %% [markdown]
# ### Angle-of-attack test (default: `False`)
# > This test calculates sample-wise Angle of Attacks throughout the current flux averaging period, and flags it if the percentage of angles of attack exceeding a user-defined range is beyond a (user-defined) threshold.
# > Source: [EddyPro help](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html?Highlight=angle%20of%20attack#Angleofattack)  *(3 Jan 2024)*
# - Flag was calculated in EddyPro
# - Flag can be useful during some time periods when the sonic anemometer had issues
# - Not used by default (similar to ICOS)

# %%
TEST_RAWDATA_ANGLE_OF_ATTACK = True  # Default False
# TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES = []
TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES = [['2008-01-01', '2010-01-01'],
                                                  ['2016-03-01', '2016-05-01'],
                                                  ['2021-12-10', '2021-12-23']]

# %% [markdown]
# </br>

# %% [markdown]
# ### Steadiness of horizontal wind test (default: `False`)
# > This test assesses whether the along-wind and crosswind components of the wind vector undergo a systematic reduction (or increase) throughout the file. If the quadratic combination of such systematic variations is beyond the user-selected limit, the flux averaging period is hard-flagged for instationary horizontal wind (Vickers and Mahrt, 1997, Par. 6g).
# > Source: [EddyPro help](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html?Highlight=angle%20of%20attack#Steadinessofhorizontalwind)  *(3 Jan 2024)*
# - Flag was calculated in EddyPro

# %%
TEST_RAWDATA_STEADINESS_OF_HORIZONTAL_WIND = False  # Default False

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Run

# %%
LEVEL2_SETTINGS = {
    'signal_strength': {
        'apply': TEST_SIGNAL_STRENGTH,
        'signal_strength_col': TEST_SIGNAL_STRENGTH_COL,
        'method': TEST_SIGNAL_STRENGTH_METHOD,
        'threshold': TEST_SIGNAL_STRENGTH_THRESHOLD},
    'raw_data_screening_vm97': {
        'apply': TEST_RAWDATA,
        'spikes': TEST_RAWDATA_SPIKES,
        'amplitude': TEST_RAWDATA_AMPLITUDE,
        'dropout': TEST_RAWDATA_DROPOUT,
        'abslim': TEST_RAWDATA_ABSLIM,
        'skewkurt_hf': TEST_RAWDATA_SKEWKURT_HF,
        'skewkurt_sf': TEST_RAWDATA_SKEWKURT_SF,
        'discont_hf': TEST_RAWDATA_DISCONT_HF,
        'discont_sf': TEST_RAWDATA_DISCONT_SF},
    'ssitc': {
        'apply': TEST_SSITC,
        'setflag_timeperiod': TEST_SSITC_SETFLAG_TIMEPERIOD},
    'gas_completeness': {
        'apply': TEST_GAS_COMPLETENESS},
    'spectral_correction_factor': {
        'apply': TEST_SPECTRAL_CORRECTION_FACTOR},
    'angle_of_attack': {
        'apply': TEST_RAWDATA_ANGLE_OF_ATTACK,
        'application_dates': TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES},
    'steadiness_of_horizontal_wind': {
        'apply': TEST_RAWDATA_STEADINESS_OF_HORIZONTAL_WIND}
}
fpc.level2_quality_flag_expansion(**LEVEL2_SETTINGS)
# Out:
# [MissingValues]  running MissingValues ...
# SSITC TEST: Generated new flag variable FLAG_L2_FN2O_SSITC_TEST, values taken from output variable FN2O_SSITC_TEST ...
#     Flag FLAG_L2_FN2O_SSITC_TEST with value 1 was set to 2 between 2022-05-01 and 2023-09-30
# FLUX BASE VARIABLE COMPLETENESS TEST: Generated new flag variable FLAG_L2_FN2O_COMPLETENESS_TEST, newly calculated from variable N2O, with flag 0 (good values) where available number of records for N2O >= 0.99, flag 1 (ok values) >= 0.97 and < 0.99, flag 2 (bad values) < 0.97...
# SPECTRAL CORRECTION FACTOR TEST: Generating new flag variable FLAG_L2_FN2O_SCF_TEST, newly calculated from output variable FN2O_SCF, withflag 0 (good values) where FN2O_SCF < 2, flag 1 (ok values) where FN2O_SCF >= 2 and < 4, flag 2 (bad values) where FN2O_SCF >= 4...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST, values taken from output variable N2O_VM97_TEST from position 1, based on N2O, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST, values taken from output variable N2O_VM97_TEST from position 2, based on N2O, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST, values taken from output variable N2O_VM97_TEST from position 3, based on N2O, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# ANGLE OF ATTACK TEST: will be applied on the following dates only: [['2008-01-01', '2010-01-01'], ['2016-03-01', '2016-05-01'], ['2021-12-10', '2021-12-23']]
# ANGLE OF ATTACK TEST: Generated new flag variable FLAG_L2_FN2O_VM97_AOA_HF_TEST, values taken from output variable None, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed ...

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Finalize Level-2

# %%
fpc.finalize_level2()
# Out:
# ++Added new column FLAG_L2_FN2O_MISSING_TEST.
# ++Added new column FLAG_L2_FN2O_SSITC_TEST.
# ++Added new column FLAG_L2_FN2O_COMPLETENESS_TEST.
# ++Added new column FLAG_L2_FN2O_SCF_TEST.
# ++Added new column FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST.
# ++Added new column FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST.
# ++Added new column FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST.
# ++Added new column FLAG_L2_FN2O_VM97_AOA_HF_TEST.
# ++Added new column SUM_L2_FN2O_HARDFLAGS.
# ++Added new column SUM_L2_FN2O_SOFTFLAGS.
# ++Added new column SUM_L2_FN2O_FLAGS.
# ++Added new column FLAG_L2_FN2O_QCF.
# ++Added new column FN2O_L2_QCF.
# ++Added new column FN2O_L2_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-2` variables
# - This shows all available Level-2 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L2' in x]
# Out:
# ['FLAG_L2_FN2O_MISSING_TEST',
#  'FLAG_L2_FN2O_SSITC_TEST',
#  'FLAG_L2_FN2O_COMPLETENESS_TEST',
#  'FLAG_L2_FN2O_SCF_TEST',
#  'FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST',
#  'FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST',
#  'FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST',
#  'FLAG_L2_FN2O_VM97_AOA_HF_TEST',
#  'SUM_L2_FN2O_HARDFLAGS',
#  'SUM_L2_FN2O_SOFTFLAGS',
#  'SUM_L2_FN2O_FLAGS',
#  'FLAG_L2_FN2O_QCF',
#  'FN2O_L2_QCF',
#  'FN2O_L2_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plots

# %%
fpc.level2_qcf.showplot_qcf_heatmaps()

# %%
# fpc.level2_qcf.showplot_qcf_timeseries()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
fpc.level2_qcf.report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FN2O.
#
# Number of FN2O records before QC: 146459
# +++ FLAG_L2_FN2O_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 146459 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FN2O_SSITC_TEST rejected 39468 values (+26.95%)      TOTALS: flag 0: 35854 (24.48%) / flag 1: 71137 (48.57%) / flag 2: 39468 (26.95%)
# +++ FLAG_L2_FN2O_COMPLETENESS_TEST rejected 3436 values (+2.35%)      TOTALS: flag 0: 33469 (22.85%) / flag 1: 70086 (47.85%) / flag 2: 42904 (29.29%)
# +++ FLAG_L2_FN2O_SCF_TEST rejected 56 values (+0.04%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 4715 values (+3.22%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_VM97_AOA_HF_TEST rejected 446 values (+0.30%)      TOTALS: flag 0: 32604 (22.26%) / flag 1: 65734 (44.88%) / flag 2: 48121 (32.86%)
#
# In total, 48121 (32.86%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2

# %%
fpc.level2_qcf.report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L2_FN2O_QCF, QCF FLAG FOR FN2O
# ========================================
# Between 2012-01-01 00:15 and 2022-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 146459 (75.94% of potential)
#     Available flux records AFTER quality checks: 98338 (67.14% of total)
#     Rejected flux records: 48121 (32.86% of total)
#     Potential flux records: 192864
#     Potential flux records missed: 46405 (24.06% of potential)

# %%
# fpc.level2_qcf.report_qcf_flags()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-3.1: **STORAGE CORRECTION**

# %% [markdown]
# ---

# %% [markdown]
# - The flux storage term (single point) is added to the flux
# - For some records, the storage term can be missing. In such cases, missing terms are gap-filled using the rolling mean in an expanding window.
# - Without gap-filling the storage term, we can lose an additional e.g. 2-3% of flux data

# %% [markdown]
# </br>

# %% [markdown]
# ## Run

# %%
fpc.level31_storage_correction(gapfill_storage_term=True)
# Out:
# Detected storage variable SN2O_SINGLE for FN2O.
# Calculating storage-corrected flux FN2O_L3.1 from flux FN2O and storage term SN2O_SINGLE ...
# Missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 480
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 5 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 311 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 7 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 50 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 9 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 35 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 11 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 23 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 13 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 16 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 15 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 11 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 17 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 9 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 25 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 8 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 29 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 7 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 31 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 6 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 37 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 5 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 87 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 4 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 93 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 3 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 95 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 2 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 99 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 1 ...
# Gap-filling storage-term SN2O_SINGLE with rolling median (window size = 2001 records, centered)  |  still missing values for storage term SN2O_SINGLE_gfRMED_L3.1: 0 ...

# %% [markdown]
# </br>

# %% [markdown]
# ## **Finalize Level-3.1**

# %%
fpc.finalize_level31()
# Out:
# ++Added new column SN2O_SINGLE.
# ++Added new column SN2O_SINGLE_gfRMED_L3.1.
# ++Added new column FLAG_SN2O_SINGLE_gfRMED_L3.1_ISFILLED.
# ++Added new column FN2O_L3.1.
# ++Added new column FN2O_L3.1_QCF (Level-3.1 with applied quality flag from Level-2).
# ++Added new column FN2O_L3.1_QCF0 (Level-3.1 with applied quality flag from Level-2).

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.1` variables
# - This shows all available Level-3.1 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.1' in x]
# Out:
# ['SN2O_SINGLE_gfRMED_L3.1',
#  'FLAG_SN2O_SINGLE_gfRMED_L3.1_ISFILLED',
#  'FN2O_L3.1',
#  'FN2O_L3.1_QCF',
#  'FN2O_L3.1_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plots

# %%
fpc.level31.showplot()

# %% [markdown]
# </br>

# %% [markdown]
# ### Report

# %%
fpc.level31.report()
# Out:
# ========================================
# REPORT: STORAGE CORRECTION FOR FN2O
# ========================================
# Swiss FluxNet processing chain, _L3.1: Storage Correction
#
# The gap-filled storage term SN2O_SINGLE_gfRMED_L3.1 was added to flux FN2O.
# The storage-corrected flux was stored as FN2O_L3.1.
#
# The flux was available for 146459 records (FN2O).
# The original, non-gapfilled storage term was available for 145979 records (SN2O_SINGLE).
# The original storage term SN2O_SINGLE was missing for 480 flux records.
# Without gap-filling the storage term (SN2O_SINGLE), 480 measured flux records (FN2O) are lost.
#
# For this run, gap-filling of SN2O_SINGLE was * SELECTED *.
# After gap-filling the storage term, it was available for an additional 480 records (SN2O_SINGLE_gfRMED_L3.1).
#
# In the storage-corrected flux FN2O_L3.1 with 146459 records,
#   - 99.7% (145979 records) of used storage terms come from originally calculated data (SN2O_SINGLE)
#   - 0.3% (480 records) of used storage terms come from gap-filled data (SN2O_SINGLE_gfRMED_L3.1)
#
# Stats for gap-filled storage terms:
#                          NOV       P01    MEDIAN       P99
# SN2O_SINGLE_gfRMED_L3.1  480 -0.213156 -0.000795  0.401271
#
# Stats for measured storage terms:
#                             NOV       P01    MEDIAN       P99
# SN2O_SINGLE_gfRMED_L3.1  145979 -0.463119 -0.000561  0.496427

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Optional: **Analyze highest-quality flux** (so far)

# %% [markdown]
# ---

# %% [markdown]
# - Analysis of fluxes after Level-3.1 where the overall quality flag `QCF` = 0
# - This helps in understanding in what range the "true" flux occurs
# - Here, the highest-quality fluxes are additionally filtered for outlier values using the relatively fast Local Outlier Factor test
# - For this quick analysis, it is possible that the outlier test cuts off some "real" values that should be retained, but it nevertheless helps in understanding the flux range
# - `QCF` = 0 is best quality, `QCF` = medium quality, `QCF` = 2 bad quality and always rejected
# - The difference between quality 0 and quality 1 or 2 is huge

# %%
analyze_highest_quality_flux(flux=fpc.fpc_df[fpc.filteredseries_hq.name], nighttime_flag=fpc.fpc_df['NIGHTTIME'])
# Out:
# >>> Removing outliers from highest-quality DAYTIME fluxes (FN2O_L3.1_QCF0)
# >>> Outlier removal method: Local outlier factor across all data (n_neighbors=105, contamination=auto, repeat=False)
# [LocalOutlierFactorAllData]  running LocalOutlierFactorAllData ...
# ITERATION#1: Total found outliers: 117 values (daytime+nighttime)
# >>> Largest non-outlier flux >= 0 DAYTIME:   33.12222168
# >>> Smallest non-outlier flux >= 0 DAYTIME:  0.0008491000000000019
# >>> Largest non-outlier flux < 0 DAYTIME:    -0.0004364999999999994
# >>> Smallest non-outlier flux < 0 DAYTIME:   -1.4311169
# >>> Largest outlier flux >= 0 DAYTIME:   192.54369
# >>> Smallest outlier flux >= 0 DAYTIME:  32.8322034
# >>> Largest outlier flux < 0 DAYTIME:    -1.454021
# >>> Smallest outlier flux < 0 DAYTIME:   -1662.4558000000002
#
# >>> Removing outliers from highest-quality NIGHTTIME fluxes (FN2O_L3.1_QCF0)
# >>> Outlier removal method: Local outlier factor across all data (n_neighbors=57, contamination=auto, repeat=False)
# [LocalOutlierFactorAllData]  running LocalOutlierFactorAllData ...
# ITERATION#1: Total found outliers: 47 values (daytime+nighttime)
# >>> Largest non-outlier flux >= 0 NIGHTTIME:   24.307214000000002
# >>> Smallest non-outlier flux >= 0 NIGHTTIME:  0.00010999999999999899
# >>> Largest non-outlier flux < 0 NIGHTTIME:    -3.199999999998343e-06
# >>> Smallest non-outlier flux < 0 NIGHTTIME:   -1.01845583
# >>> Largest outlier flux >= 0 NIGHTTIME:   50.143817
# >>> Smallest outlier flux >= 0 NIGHTTIME:  24.4222
# >>> Largest outlier flux < 0 NIGHTTIME:    -1.0316672
# >>> Smallest outlier flux < 0 NIGHTTIME:   -12.9709584

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-3.2: **OUTLIER DETECTION**

# %% [markdown]
# ---

# %% [markdown]
# - Running an outlier test creates a *preview* plot of the results
# - If the output looks as desired, run `fpc.level32_addflag()` cell below the preview to accept the results you see in the plot
# - All subsequent tests will then be based on these results
# - This means that each test is run on the data already filtered by the previous test
# - Each test creates its own quality flag
# - At the end of Level-3.2, an overall quality flag `QCF` is created that combines all of the individual flags into one single flag

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot time series

# %%
print(f"{fpc.filteredseries.name} \n(quality-controlled Level-3.1 version of {fpc.fluxcol})")
# Out:
# FN2O_L3.1_QCF
# (quality-controlled Level-3.1 version of FN2O)

# %%
# TimeSeries(series=fpc.fpc_df[fpc.filteredseries.name]).plot_interactive()
TimeSeries(series=fpc.fpc_df[fpc.filteredseries.name]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# ## Initiate calculations

# %%
fpc.level32_stepwise_outlier_detection()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Absolute limits**
# - remove values outside a physically plausible range
# - typical value for CO2 flux `FC`: +/-50 µmol m-2 s-1
# - typical value for latent evaporation flux `LE`: +800 / -50 W m-2
# - typical value for sensible heat flux `H`: +400 / -200 W m-2

# %%
# from diive.pkgs.outlierdetection.absolutelimits import AbsoluteLimits
# help(AbsoluteLimits)

# %%
MIN = -5
MAX = 70
fpc.level32_flag_outliers_abslim_test(minval=MIN, maxval=MAX, showplot=True, verbose=True)
# Out:
# [AbsoluteLimits]  running AbsoluteLimits ...

# %%
fpc.level32_addflag()
# Out:
# ++Added flag column FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST to flag data

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Manual flag**
# - The interactive plot can be used to determine the exact start and end of time ranges or data points that need to be removed, e.g. due to known instrument failure

# %%
# from diive.pkgs.outlierdetection.manualremoval import ManualRemoval
# help(ManualRemoval)

# %%
# fpc.level32.showplot_cleaned(interactive=True)  # True or False
# fpc.level32.showplot_cleaned(interactive=False)  # True or False

# %%
# REMOVE_DATES = [
#     ['2008-12-01', '2009-05-01'],  # Removes date range between two datetimes (inclusive)
#     # ['2008-12-01 00:00:15', '2022-05-03 06:45:00'],  # Removes date range between two datetimes (inclusive)
#     # '2023-12-12 12:45:00'  # Removes data point with specific timestamp
# ]
# fpc.level32_flag_manualremoval_test(
#     remove_dates=REMOVE_DATES,
#     showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %%
# fpc.level32.showplot_cleaned(interactive=True)  # True or False

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Hampel filter**, separate for daytime and nighttime
# - Recommended filter
# - Is slow compared to other filters:
#     - tested with 1 year of 30MIN time resolution data and it needed approx. 43 seconds on a fast desktop computer

# %%
# from diive.pkgs.outlierdetection.hampel import Hampel
# help(Hampel)

# %%
# %%time
# WINDOW_LENGTH = 48 * 3
# N_SIGMA_DT = 36
# N_SIGMA_NT = 36
# fpc.level32_flag_outliers_hampel_dtnt_test(window_length=WINDOW_LENGTH, n_sigma_dt=N_SIGMA_DT, n_sigma_nt=N_SIGMA_NT,
#                                            showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **z-score across all data**

# %%
# from diive.pkgs.outlierdetection.zscore import zScore
# help(zScore)

# %%
# THRES_ZSCORE = 6
# fpc.level32_flag_outliers_zscore_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Hampel filter**
# - Recommended filter
# - Is slow compared to other filters:
#     - tested with 1 year of 30MIN time resolution data and it needed approx. 33 seconds on a fast desktop computer
#     - tested with 19 years of 30MIN time resolution data and it needed approx. 20 minutes on a fast desktop computer

# %%
# from diive.pkgs.outlierdetection.hampel import Hampel
# help(Hampel)

# %%
# WINDOW_LENGTH = 48 * 3
# N_SIGMA = 32
# # %%time
# fpc.level32_flag_outliers_hampel_test(window_length=WINDOW_LENGTH, n_sigma=N_SIGMA, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **z-score over all data**, separate for daytime and nighttime

# %%
# from diive.pkgs.outlierdetection.zscore import zScoreDaytimeNighttime
# help(zScoreDaytimeNighttime)

# %%
# THRES_ZSCORE = 5
# fpc.level32_flag_outliers_zscore_dtnt_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Rolling z-score over all data**

# %%
# from diive.pkgs.outlierdetection.zscore import zScoreRolling
# help(zScoreRolling)

# %%
THRES_ZSCORE = 10
WINSIZE = 48 * 3
fpc.level32_flag_outliers_zscore_rolling_test(winsize=WINSIZE, thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)
# Out:
# [zScoreRolling]  running zScoreRolling ...
# ITERATION#1: Total found outliers: 48 values
# ITERATION#2: Total found outliers: 0 values

# %%
fpc.level32_addflag()
# Out:
# ++Added flag column FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST to flag data

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local standard deviation**, with rolling median and *rolling* standard deviation

# %%
# from diive.pkgs.outlierdetection.localsd import LocalSD
# help(LocalSD)

# %%
N_SD = 8
WINSIZE = 48 * 3
fpc.level32_flag_outliers_localsd_test(n_sd=N_SD, winsize=WINSIZE, constant_sd=False, showplot=True, verbose=True, repeat=True)
# Out:
# [LocalSD]  running LocalSD ...
# ITERATION#1: Total found outliers: 103 values
# ITERATION#2: Total found outliers: 14 values
# ITERATION#3: Total found outliers: 0 values

# %%
fpc.level32_addflag()
# Out:
# ++Added flag column FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST to flag data

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local standard deviation**, with rolling median and *constant* standard deviation
# - keep standard deviation constant by setting parameter `constant_sd=True`

# %%
# N_SD = 8
# WINSIZE = 48 * 3
# fpc.level32_flag_outliers_localsd_test(n_sd=N_SD, winsize=WINSIZE, constant_sd=True, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Increments z-score**

# %%
# from diive.pkgs.outlierdetection.incremental import zScoreIncrements
# help(zScoreIncrements)

# %%
# THRES_ZSCORE = 4
# fpc.level32_flag_outliers_increments_zcore_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local outlier factor**, daytime/nighttime
# - Test is run separately for daytime and nighttime data
# - Description of local outlier factor: [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
# from diive.pkgs.outlierdetection.lof import LocalOutlierFactorDaytimeNighttime
# help(LocalOutlierFactorDaytimeNighttime)

# %%
# N_NEIGHBORS = None
# CONTAMINATION = None
# fpc.level32_flag_outliers_lof_dtnt_test(n_neighbors=N_NEIGHBORS, contamination=CONTAMINATION, showplot=True, verbose=True, repeat=False, n_jobs=-1)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Local outlier factor**
# - Test is run across all data
# - Description of local outlier factor: [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
# from diive.pkgs.outlierdetection.lof import LocalOutlierFactorAllData
# help(LocalOutlierFactorAllData)

# %%
# N_NEIGHBORS = 24
# CONTAMINATION = None
# fpc.level32_flag_outliers_lof_test(n_neighbors=N_NEIGHBORS, contamination=CONTAMINATION, showplot=True, verbose=True, repeat=False, n_jobs=-1)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Absolute limits**, separate for daytime and nighttime data

# %%
# from diive.pkgs.outlierdetection.absolutelimits import AbsoluteLimitsDaytimeNighttime
# help(AbsoluteLimitsDaytimeNighttime)

# %%
# MIN_DT = -5
# MAX_DT = 70
# MIN_NT = -5
# MAX_NT = 40
# fpc.level32_flag_outliers_abslim_dtnt_test(daytime_minmax=[MIN_DT, MAX_DT], nighttime_minmax=[MIN_NT, MAX_NT], showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Outlier flag: **Trim nighttime flux data**

# %%
# from diive.pkgs.outlierdetection.trim import TrimLow
# help(TrimLow)

# %%
# fpc.level32_flag_outliers_trim_low_test(trim_nighttime=True, lower_limit=-5, showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## **Finalize Level-3.2**: Calculate overall quality flag (so far)

# %%
fpc.finalize_level32()
# Out:
# ++Added new column FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST.
# ++Added new column FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST.
# ++Added new column FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST.
# ++Added new column SUM_L3.2_FN2O_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.2_FN2O_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.2_FN2O_L3.1_FLAGS.
# ++Added new column FLAG_L3.2_FN2O_L3.1_QCF.
# ++Added new column FN2O_L3.1_L3.2_QCF.
# ++Added new column FN2O_L3.1_L3.2_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.2` variables
# - This shows all available Level-3.2 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.2' in x]
# Out:
# ['FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST',
#  'FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST',
#  'FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST',
#  'SUM_L3.2_FN2O_L3.1_HARDFLAGS',
#  'SUM_L3.2_FN2O_L3.1_SOFTFLAGS',
#  'SUM_L3.2_FN2O_L3.1_FLAGS',
#  'FLAG_L3.2_FN2O_L3.1_QCF',
#  'FN2O_L3.1_L3.2_QCF',
#  'FN2O_L3.1_L3.2_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plot filtered flux after Level-3.2
# In the four panels, from left to right:
# - flux after Level-3.1, before outlier removal
# - flux after Level-3.2, after outlier removal
# - sum of the individual test flags
# - overall flag `QCF` (quality control flag), where `0`=best quality, `1`=medium quality, `2`=bad quality

# %%
fpc.level32_qcf.showplot_qcf_heatmaps()

# %%
TimeSeries(series=fpc.filteredseries).plot()
# TimeSeries(series=fpc.filteredseries).plot_interactive()

# %%
# fpc.level32_qcf.showplot_qcf_timeseries()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
fpc.level32_qcf.report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FN2O_L3.1.
#
# Number of FN2O_L3.1 records before QC: 146459
# +++ FLAG_L2_FN2O_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 146459 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FN2O_SSITC_TEST rejected 39468 values (+26.95%)      TOTALS: flag 0: 35854 (24.48%) / flag 1: 71137 (48.57%) / flag 2: 39468 (26.95%)
# +++ FLAG_L2_FN2O_COMPLETENESS_TEST rejected 3436 values (+2.35%)      TOTALS: flag 0: 33469 (22.85%) / flag 1: 70086 (47.85%) / flag 2: 42904 (29.29%)
# +++ FLAG_L2_FN2O_SCF_TEST rejected 56 values (+0.04%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 4715 values (+3.22%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_VM97_AOA_HF_TEST rejected 446 values (+0.30%)      TOTALS: flag 0: 32604 (22.26%) / flag 1: 65734 (44.88%) / flag 2: 48121 (32.86%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST rejected 659 values (+0.45%)      TOTALS: flag 0: 32587 (22.25%) / flag 1: 65092 (44.44%) / flag 2: 48780 (33.31%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST rejected 48 values (+0.03%)      TOTALS: flag 0: 32586 (22.25%) / flag 1: 65045 (44.41%) / flag 2: 48828 (33.34%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST rejected 117 values (+0.08%)      TOTALS: flag 0: 32585 (22.25%) / flag 1: 64929 (44.33%) / flag 2: 48945 (33.42%)
#
# In total, 48945 (33.42%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2

# %%
fpc.level32_qcf.report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L3.2_FN2O_L3.1_QCF, QCF FLAG FOR FN2O_L3.1
# ========================================
# Between 2012-01-01 00:15 and 2022-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 146459 (75.94% of potential)
#     Available flux records AFTER quality checks: 97514 (66.58% of total)
#     Rejected flux records: 48945 (33.42% of total)
#     Potential flux records: 192864
#     Potential flux records missed: 46405 (24.06% of potential)

# %%
fpc.level32_qcf.report_qcf_flags()
# Out:
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (75.94%)
#     OVERALL flag 2.0: 46405 values (24.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (75.33%)
#     DAYTIME flag 2.0: 23377 values (24.67%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (76.53%)
#     NIGHTTIME flag 2.0: 23028 values (23.47%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (18.59%)
#     OVERALL flag 1.0: 71137 values (36.88%)
#     OVERALL flag 2.0: 39468 values (20.46%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 23042 values (24.32%)
#     DAYTIME flag 1.0: 29966 values (31.63%)
#     DAYTIME flag 2.0: 18362 values (19.38%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 12812 values (13.06%)
#     NIGHTTIME flag 1.0: 41171 values (41.96%)
#     NIGHTTIME flag 2.0: 21106 values (21.51%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (71.98%)
#     OVERALL flag 1.0: 3286 values (1.70%)
#     OVERALL flag 2.0: 4363 values (2.26%)
#     OVERALL flag missing: 46400 values (24.06%)
#
#     DAYTIME flag 0.0: 67905 values (71.67%)
#     DAYTIME flag 1.0: 1685 values (1.78%)
#     DAYTIME flag 2.0: 1782 values (1.88%)
#     DAYTIME flag missing: 23375 values (24.67%)
#
#     NIGHTTIME flag 0.0: 70910 values (72.27%)
#     NIGHTTIME flag 1.0: 1601 values (1.63%)
#     NIGHTTIME flag 2.0: 2581 values (2.63%)
#     NIGHTTIME flag missing: 23025 values (23.47%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (75.65%)
#     OVERALL flag 1.0: 463 values (0.24%)
#     OVERALL flag 2.0: 89 values (0.05%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 71215 values (75.16%)
#     DAYTIME flag 1.0: 130 values (0.14%)
#     DAYTIME flag 2.0: 25 values (0.03%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 74692 values (76.13%)
#     NIGHTTIME flag 1.0: 333 values (0.34%)
#     NIGHTTIME flag 2.0: 64 values (0.07%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136171 values (70.60%)
#     OVERALL flag 2.0: 32052 values (16.62%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 66601 values (70.29%)
#     DAYTIME flag 2.0: 15765 values (16.64%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 69570 values (70.91%)
#     NIGHTTIME flag 2.0: 16287 values (16.60%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1304 values (0.68%)
#     OVERALL flag 2.0: 798 values (0.41%)
#     OVERALL flag missing: 190762 values (98.91%)
#
#     DAYTIME flag 0.0: 638 values (0.67%)
#     DAYTIME flag 2.0: 452 values (0.48%)
#     DAYTIME flag missing: 93657 values (98.85%)
#
#     NIGHTTIME flag 0.0: 666 values (0.68%)
#     NIGHTTIME flag 2.0: 346 values (0.35%)
#     NIGHTTIME flag missing: 97105 values (98.97%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (16.91%)
#     OVERALL flag 1.0: 65734 values (34.08%)
#     OVERALL flag 2.0: 94526 values (49.01%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (22.31%)
#     DAYTIME flag 1.0: 27716 values (29.25%)
#     DAYTIME flag 2.0: 45897 values (48.44%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (11.69%)
#     NIGHTTIME flag 1.0: 38018 values (38.75%)
#     NIGHTTIME flag 2.0: 48629 values (49.56%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 192205 values (99.66%)
#     OVERALL flag 2.0: 659 values (0.34%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94555 values (99.80%)
#     DAYTIME flag 2.0: 192 values (0.20%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 97650 values (99.52%)
#     NIGHTTIME flag 2.0: 467 values (0.48%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 192816 values (99.98%)
#     OVERALL flag 2.0: 48 values (0.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94736 values (99.99%)
#     DAYTIME flag 2.0: 11 values (0.01%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98080 values (99.96%)
#     NIGHTTIME flag 2.0: 37 values (0.04%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 192747 values (99.94%)
#     OVERALL flag 2.0: 117 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94728 values (99.98%)
#     DAYTIME flag 2.0: 19 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98019 values (99.90%)
#     NIGHTTIME flag 2.0: 98 values (0.10%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (16.90%)
#     OVERALL flag 1.0: 64929 values (33.67%)
#     OVERALL flag 2.0: 95350 values (49.44%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (22.29%)
#     DAYTIME flag 1.0: 27506 values (29.03%)
#     DAYTIME flag 2.0: 46119 values (48.68%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (11.68%)
#     NIGHTTIME flag 1.0: 37423 values (38.14%)
#     NIGHTTIME flag 2.0: 49231 values (50.18%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (24.48%)
#     OVERALL flag 1.0: 71137 values (48.57%)
#     OVERALL flag 2.0: 39468 values (26.95%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 23042 values (32.29%)
#     DAYTIME flag 1.0: 29966 values (41.99%)
#     DAYTIME flag 2.0: 18362 values (25.73%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 12812 values (17.06%)
#     NIGHTTIME flag 1.0: 41171 values (54.83%)
#     NIGHTTIME flag 2.0: 21106 values (28.11%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (94.78%)
#     OVERALL flag 1.0: 3286 values (2.24%)
#     OVERALL flag 2.0: 4358 values (2.98%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 67905 values (95.15%)
#     DAYTIME flag 1.0: 1685 values (2.36%)
#     DAYTIME flag 2.0: 1780 values (2.49%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 70910 values (94.43%)
#     NIGHTTIME flag 1.0: 1601 values (2.13%)
#     NIGHTTIME flag 2.0: 2578 values (3.43%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (99.62%)
#     OVERALL flag 1.0: 463 values (0.32%)
#     OVERALL flag 2.0: 89 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71215 values (99.78%)
#     DAYTIME flag 1.0: 130 values (0.18%)
#     DAYTIME flag 2.0: 25 values (0.04%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74692 values (99.47%)
#     NIGHTTIME flag 1.0: 333 values (0.44%)
#     NIGHTTIME flag 2.0: 64 values (0.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136043 values (92.89%)
#     OVERALL flag 2.0: 10416 values (7.11%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 66492 values (93.17%)
#     DAYTIME flag 2.0: 4878 values (6.83%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 69551 values (92.62%)
#     NIGHTTIME flag 2.0: 5538 values (7.38%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1299 values (0.89%)
#     OVERALL flag 2.0: 798 values (0.54%)
#     OVERALL flag missing: 144362 values (98.57%)
#
#     DAYTIME flag 0.0: 633 values (0.89%)
#     DAYTIME flag 2.0: 452 values (0.63%)
#     DAYTIME flag missing: 70285 values (98.48%)
#
#     NIGHTTIME flag 0.0: 666 values (0.89%)
#     NIGHTTIME flag 2.0: 346 values (0.46%)
#     NIGHTTIME flag missing: 74077 values (98.65%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (22.26%)
#     OVERALL flag 1.0: 65734 values (44.88%)
#     OVERALL flag 2.0: 48121 values (32.86%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (29.61%)
#     DAYTIME flag 1.0: 27716 values (38.83%)
#     DAYTIME flag 2.0: 22520 values (31.55%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (15.28%)
#     NIGHTTIME flag 1.0: 38018 values (50.63%)
#     NIGHTTIME flag 2.0: 25601 values (34.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 145800 values (99.55%)
#     OVERALL flag 2.0: 659 values (0.45%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71178 values (99.73%)
#     DAYTIME flag 2.0: 192 values (0.27%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74622 values (99.38%)
#     NIGHTTIME flag 2.0: 467 values (0.62%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 146411 values (99.97%)
#     OVERALL flag 2.0: 48 values (0.03%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71359 values (99.98%)
#     DAYTIME flag 2.0: 11 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75052 values (99.95%)
#     NIGHTTIME flag 2.0: 37 values (0.05%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 146342 values (99.92%)
#     OVERALL flag 2.0: 117 values (0.08%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71351 values (99.97%)
#     DAYTIME flag 2.0: 19 values (0.03%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74991 values (99.87%)
#     NIGHTTIME flag 2.0: 98 values (0.13%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (22.25%)
#     OVERALL flag 1.0: 64929 values (44.33%)
#     OVERALL flag 2.0: 48945 values (33.42%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (29.60%)
#     DAYTIME flag 1.0: 27506 values (38.54%)
#     DAYTIME flag 2.0: 22742 values (31.86%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (15.27%)
#     NIGHTTIME flag 1.0: 37423 values (49.84%)
#     NIGHTTIME flag 2.0: 26203 values (34.90%)
#     NIGHTTIME flag missing: 0 values (0.00%)

# %% [markdown]
# </br>

# %% [markdown]
# ## Save Level-3.2 results to file
# - If needed, save results so far (input data and all created variables, e.g. flags and filtered fluxes) to a file
# - This can be useful if e.g. USTAR filtering is not needed and gap-filling is done elsewhere (ReddyProc...)

# %%
# results_df = fpc.get_data()
# filename = "51.1_FluxProcessingChain_after-L3.3_NEE"
# results_df.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=results_df, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-3.3: **USTAR FILTERING**

# %% [markdown]
# ---

# %% [markdown]
# - Daytime and nighttime data are filtered based on USTAR thresholds
# - Example USTAR thresholds from the analysis done by FLUXNET (2005-2023) for the intensively managed grassland [CH-CHA, Chamau](https://www.swissfluxnet.ethz.ch/index.php/sites/site-info-ch-cha/):
#     - CUT_16: `0.0529445`
#     - CUT_50: `0.0698982`
#     - CUT_84: `0.0928408`

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     No USTAR filtering for: <b>H, LE, ET and FH2O.</b>
# </div>

# %% [markdown]
# > The USTAR filtering is not applied to H and LE, because it has not been proved that when there are CO2 advective fluxes, these also impact energy fluxes, specifically due to the fact that when advection is in general large (nighttime), energy fluxes are small.
#
# source: [Pastorello et al. (2020). The FLUXNET2015 dataset and the ONEFlux processing pipeline for eddy covariance data](https://doi.org/10.1038/s41597-020-0534-3)

# %%
# USTAR_SCENARIOS = ['CUT_50']
# USTAR_THRESHOLDS = [0.0698982]
USTAR_SCENARIOS = ['CUT_16', 'CUT_50', 'CUT_84']
USTAR_THRESHOLDS = [0.0529445, 0.0698982, 0.0928408]
fpc.level33_constant_ustar(thresholds=USTAR_THRESHOLDS,
                           threshold_labels=USTAR_SCENARIOS,
                           showplot=False)
# Out:
# [FlagSingleConstantUstarThreshold]  running FlagSingleConstantUstarThreshold ...
# Total found outliers for USTAR threshold _L3.3_CUT_16 0.0529445: 31281 values
# [FlagSingleConstantUstarThreshold]  running FlagSingleConstantUstarThreshold ...
# Total found outliers for USTAR threshold _L3.3_CUT_50 0.0698982: 51101 values
# [FlagSingleConstantUstarThreshold]  running FlagSingleConstantUstarThreshold ...
# Total found outliers for USTAR threshold _L3.3_CUT_84 0.0928408: 75456 values

# %% [markdown]
# </br>

# %% [markdown]
# ## **Finalize Level-3.3**: Caculate overall final quality flag

# %%
# Finalize: stores results for each USTAR scenario in a dict
fpc.finalize_level33()
# Out:
# Calculating overall quality flag QCF for USTAR scenario CUT_16...
# ++Added new column FLAG_L3.3_CUT_16_FN2O_L3.1_USTAR_TEST.
# ++Added new column SUM_L3.3_CUT_16_FN2O_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.3_CUT_16_FN2O_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.3_CUT_16_FN2O_L3.1_FLAGS.
# ++Added new column FLAG_L3.3_CUT_16_FN2O_L3.1_QCF.
# ++Added new column FN2O_L3.1_L3.3_CUT_16_QCF.
# ++Added new column FN2O_L3.1_L3.3_CUT_16_QCF0.
# Calculating overall quality flag QCF for USTAR scenario CUT_50...
# ++Added new column FLAG_L3.3_CUT_50_FN2O_L3.1_USTAR_TEST.
# ++Added new column SUM_L3.3_CUT_50_FN2O_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.3_CUT_50_FN2O_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.3_CUT_50_FN2O_L3.1_FLAGS.
# ++Added new column FLAG_L3.3_CUT_50_FN2O_L3.1_QCF.
# ++Added new column FN2O_L3.1_L3.3_CUT_50_QCF.
# ++Added new column FN2O_L3.1_L3.3_CUT_50_QCF0.
# Calculating overall quality flag QCF for USTAR scenario CUT_84...
# ++Added new column FLAG_L3.3_CUT_84_FN2O_L3.1_USTAR_TEST.
# ++Added new column SUM_L3.3_CUT_84_FN2O_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.3_CUT_84_FN2O_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.3_CUT_84_FN2O_L3.1_FLAGS.
# ++Added new column FLAG_L3.3_CUT_84_FN2O_L3.1_QCF.
# ++Added new column FN2O_L3.1_L3.3_CUT_84_QCF.
# ++Added new column FN2O_L3.1_L3.3_CUT_84_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.3` variables
# - This shows all available Level-3.3 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.3' in x]
# Out:
# ['FLAG_L3.3_CUT_16_FN2O_L3.1_USTAR_TEST',
#  'SUM_L3.3_CUT_16_FN2O_L3.1_HARDFLAGS',
#  'SUM_L3.3_CUT_16_FN2O_L3.1_SOFTFLAGS',
#  'SUM_L3.3_CUT_16_FN2O_L3.1_FLAGS',
#  'FLAG_L3.3_CUT_16_FN2O_L3.1_QCF',
#  'FN2O_L3.1_L3.3_CUT_16_QCF',
#  'FN2O_L3.1_L3.3_CUT_16_QCF0',
#  'FLAG_L3.3_CUT_50_FN2O_L3.1_USTAR_TEST',
#  'SUM_L3.3_CUT_50_FN2O_L3.1_HARDFLAGS',
#  'SUM_L3.3_CUT_50_FN2O_L3.1_SOFTFLAGS',
#  'SUM_L3.3_CUT_50_FN2O_L3.1_FLAGS',
#  'FLAG_L3.3_CUT_50_FN2O_L3.1_QCF',
#  'FN2O_L3.1_L3.3_CUT_50_QCF',
#  'FN2O_L3.1_L3.3_CUT_50_QCF0',
#  'FLAG_L3.3_CUT_84_FN2O_L3.1_USTAR_TEST',
#  'SUM_L3.3_CUT_84_FN2O_L3.1_HARDFLAGS',
#  'SUM_L3.3_CUT_84_FN2O_L3.1_SOFTFLAGS',
#  'SUM_L3.3_CUT_84_FN2O_L3.1_FLAGS',
#  'FLAG_L3.3_CUT_84_FN2O_L3.1_QCF',
#  'FN2O_L3.1_L3.3_CUT_84_QCF',
#  'FN2O_L3.1_L3.3_CUT_84_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plot filtered flux after Level-3.3
# In the four panels, from left to right:
# - flux after Level-3.1, before outlier removal and USTAR filtering
# - flux after Level-3.3, after outlier removal and USTAR filtering
# - sum of the individual test flags
# - overall flag `QCF` (quality control flag), where `0`=best quality, `1`=medium quality, `2`=bad quality

# %%
for key, value in fpc.level33_qcf.items():
    # TimeSeries(series=fpc.fpc_df[fluxhq]).plot_interactive()
    # TimeSeries(series=fpc.fpc_df[FLUXVAR33QCF[key].name]).plot()
    fpc.level33_qcf[key].showplot_qcf_heatmaps()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FN2O_L3.1.
#
# Number of FN2O_L3.1 records before QC: 146459
# +++ FLAG_L2_FN2O_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 146459 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FN2O_SSITC_TEST rejected 39468 values (+26.95%)      TOTALS: flag 0: 35854 (24.48%) / flag 1: 71137 (48.57%) / flag 2: 39468 (26.95%)
# +++ FLAG_L2_FN2O_COMPLETENESS_TEST rejected 3436 values (+2.35%)      TOTALS: flag 0: 33469 (22.85%) / flag 1: 70086 (47.85%) / flag 2: 42904 (29.29%)
# +++ FLAG_L2_FN2O_SCF_TEST rejected 56 values (+0.04%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 4715 values (+3.22%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_VM97_AOA_HF_TEST rejected 446 values (+0.30%)      TOTALS: flag 0: 32604 (22.26%) / flag 1: 65734 (44.88%) / flag 2: 48121 (32.86%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST rejected 659 values (+0.45%)      TOTALS: flag 0: 32587 (22.25%) / flag 1: 65092 (44.44%) / flag 2: 48780 (33.31%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST rejected 48 values (+0.03%)      TOTALS: flag 0: 32586 (22.25%) / flag 1: 65045 (44.41%) / flag 2: 48828 (33.34%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST rejected 117 values (+0.08%)      TOTALS: flag 0: 32585 (22.25%) / flag 1: 64929 (44.33%) / flag 2: 48945 (33.42%)
# +++ FLAG_L3.3_CUT_16_FN2O_L3.1_USTAR_TEST rejected 15280 values (+10.43%)      TOTALS: flag 0: 29680 (20.27%) / flag 1: 52554 (35.88%) / flag 2: 64225 (43.85%)
#
# In total, 64225 (43.85%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2
#
#
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FN2O_L3.1.
#
# Number of FN2O_L3.1 records before QC: 146459
# +++ FLAG_L2_FN2O_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 146459 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FN2O_SSITC_TEST rejected 39468 values (+26.95%)      TOTALS: flag 0: 35854 (24.48%) / flag 1: 71137 (48.57%) / flag 2: 39468 (26.95%)
# +++ FLAG_L2_FN2O_COMPLETENESS_TEST rejected 3436 values (+2.35%)      TOTALS: flag 0: 33469 (22.85%) / flag 1: 70086 (47.85%) / flag 2: 42904 (29.29%)
# +++ FLAG_L2_FN2O_SCF_TEST rejected 56 values (+0.04%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 4715 values (+3.22%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_VM97_AOA_HF_TEST rejected 446 values (+0.30%)      TOTALS: flag 0: 32604 (22.26%) / flag 1: 65734 (44.88%) / flag 2: 48121 (32.86%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST rejected 659 values (+0.45%)      TOTALS: flag 0: 32587 (22.25%) / flag 1: 65092 (44.44%) / flag 2: 48780 (33.31%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST rejected 48 values (+0.03%)      TOTALS: flag 0: 32586 (22.25%) / flag 1: 65045 (44.41%) / flag 2: 48828 (33.34%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST rejected 117 values (+0.08%)      TOTALS: flag 0: 32585 (22.25%) / flag 1: 64929 (44.33%) / flag 2: 48945 (33.42%)
# +++ FLAG_L3.3_CUT_50_FN2O_L3.1_USTAR_TEST rejected 25203 values (+17.21%)      TOTALS: flag 0: 27461 (18.75%) / flag 1: 44850 (30.62%) / flag 2: 74148 (50.63%)
#
# In total, 74148 (50.63%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2
#
#
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FN2O_L3.1.
#
# Number of FN2O_L3.1 records before QC: 146459
# +++ FLAG_L2_FN2O_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 146459 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FN2O_SSITC_TEST rejected 39468 values (+26.95%)      TOTALS: flag 0: 35854 (24.48%) / flag 1: 71137 (48.57%) / flag 2: 39468 (26.95%)
# +++ FLAG_L2_FN2O_COMPLETENESS_TEST rejected 3436 values (+2.35%)      TOTALS: flag 0: 33469 (22.85%) / flag 1: 70086 (47.85%) / flag 2: 42904 (29.29%)
# +++ FLAG_L2_FN2O_SCF_TEST rejected 56 values (+0.04%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 33410 (22.81%) / flag 1: 70089 (47.86%) / flag 2: 42960 (29.33%)
# +++ FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST rejected 4715 values (+3.22%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 32626 (22.28%) / flag 1: 66158 (45.17%) / flag 2: 47675 (32.55%)
# +++ FLAG_L2_FN2O_VM97_AOA_HF_TEST rejected 446 values (+0.30%)      TOTALS: flag 0: 32604 (22.26%) / flag 1: 65734 (44.88%) / flag 2: 48121 (32.86%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST rejected 659 values (+0.45%)      TOTALS: flag 0: 32587 (22.25%) / flag 1: 65092 (44.44%) / flag 2: 48780 (33.31%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST rejected 48 values (+0.03%)      TOTALS: flag 0: 32586 (22.25%) / flag 1: 65045 (44.41%) / flag 2: 48828 (33.34%)
# +++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST rejected 117 values (+0.08%)      TOTALS: flag 0: 32585 (22.25%) / flag 1: 64929 (44.33%) / flag 2: 48945 (33.42%)
# +++ FLAG_L3.3_CUT_84_FN2O_L3.1_USTAR_TEST rejected 37707 values (+25.75%)      TOTALS: flag 0: 23952 (16.35%) / flag 1: 35855 (24.48%) / flag 2: 86652 (59.16%)
#
# In total, 86652 (59.16%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L3.3_CUT_16_FN2O_L3.1_QCF, QCF FLAG FOR FN2O_L3.1
# ========================================
# Between 2012-01-01 00:15 and 2022-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 146459 (75.94% of potential)
#     Available flux records AFTER quality checks: 82234 (56.15% of total)
#     Rejected flux records: 64225 (43.85% of total)
#     Potential flux records: 192864
#     Potential flux records missed: 46405 (24.06% of potential)
#
#
#
# ========================================
# SUMMARY: FLAG_L3.3_CUT_50_FN2O_L3.1_QCF, QCF FLAG FOR FN2O_L3.1
# ========================================
# Between 2012-01-01 00:15 and 2022-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 146459 (75.94% of potential)
#     Available flux records AFTER quality checks: 72311 (49.37% of total)
#     Rejected flux records: 74148 (50.63% of total)
#     Potential flux records: 192864
#     Potential flux records missed: 46405 (24.06% of potential)
#
#
#
# ========================================
# SUMMARY: FLAG_L3.3_CUT_84_FN2O_L3.1_QCF, QCF FLAG FOR FN2O_L3.1
# ========================================
# Between 2012-01-01 00:15 and 2022-12-31 23:45 ...
#     Total flux records BEFORE quality checks: 146459 (75.94% of potential)
#     Available flux records AFTER quality checks: 59807 (40.84% of total)
#     Rejected flux records: 86652 (59.16% of total)
#     Potential flux records: 192864
#     Potential flux records missed: 46405 (24.06% of potential)

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_flags()
# Out:
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (75.94%)
#     OVERALL flag 2.0: 46405 values (24.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (75.33%)
#     DAYTIME flag 2.0: 23377 values (24.67%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (76.53%)
#     NIGHTTIME flag 2.0: 23028 values (23.47%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (18.59%)
#     OVERALL flag 1.0: 71137 values (36.88%)
#     OVERALL flag 2.0: 39468 values (20.46%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 23042 values (24.32%)
#     DAYTIME flag 1.0: 29966 values (31.63%)
#     DAYTIME flag 2.0: 18362 values (19.38%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 12812 values (13.06%)
#     NIGHTTIME flag 1.0: 41171 values (41.96%)
#     NIGHTTIME flag 2.0: 21106 values (21.51%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (71.98%)
#     OVERALL flag 1.0: 3286 values (1.70%)
#     OVERALL flag 2.0: 4363 values (2.26%)
#     OVERALL flag missing: 46400 values (24.06%)
#
#     DAYTIME flag 0.0: 67905 values (71.67%)
#     DAYTIME flag 1.0: 1685 values (1.78%)
#     DAYTIME flag 2.0: 1782 values (1.88%)
#     DAYTIME flag missing: 23375 values (24.67%)
#
#     NIGHTTIME flag 0.0: 70910 values (72.27%)
#     NIGHTTIME flag 1.0: 1601 values (1.63%)
#     NIGHTTIME flag 2.0: 2581 values (2.63%)
#     NIGHTTIME flag missing: 23025 values (23.47%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (75.65%)
#     OVERALL flag 1.0: 463 values (0.24%)
#     OVERALL flag 2.0: 89 values (0.05%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 71215 values (75.16%)
#     DAYTIME flag 1.0: 130 values (0.14%)
#     DAYTIME flag 2.0: 25 values (0.03%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 74692 values (76.13%)
#     NIGHTTIME flag 1.0: 333 values (0.34%)
#     NIGHTTIME flag 2.0: 64 values (0.07%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136171 values (70.60%)
#     OVERALL flag 2.0: 32052 values (16.62%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 66601 values (70.29%)
#     DAYTIME flag 2.0: 15765 values (16.64%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 69570 values (70.91%)
#     NIGHTTIME flag 2.0: 16287 values (16.60%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1304 values (0.68%)
#     OVERALL flag 2.0: 798 values (0.41%)
#     OVERALL flag missing: 190762 values (98.91%)
#
#     DAYTIME flag 0.0: 638 values (0.67%)
#     DAYTIME flag 2.0: 452 values (0.48%)
#     DAYTIME flag missing: 93657 values (98.85%)
#
#     NIGHTTIME flag 0.0: 666 values (0.68%)
#     NIGHTTIME flag 2.0: 346 values (0.35%)
#     NIGHTTIME flag missing: 97105 values (98.97%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (16.91%)
#     OVERALL flag 1.0: 65734 values (34.08%)
#     OVERALL flag 2.0: 94526 values (49.01%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (22.31%)
#     DAYTIME flag 1.0: 27716 values (29.25%)
#     DAYTIME flag 2.0: 45897 values (48.44%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (11.69%)
#     NIGHTTIME flag 1.0: 38018 values (38.75%)
#     NIGHTTIME flag 2.0: 48629 values (49.56%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 192205 values (99.66%)
#     OVERALL flag 2.0: 659 values (0.34%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94555 values (99.80%)
#     DAYTIME flag 2.0: 192 values (0.20%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 97650 values (99.52%)
#     NIGHTTIME flag 2.0: 467 values (0.48%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 192816 values (99.98%)
#     OVERALL flag 2.0: 48 values (0.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94736 values (99.99%)
#     DAYTIME flag 2.0: 11 values (0.01%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98080 values (99.96%)
#     NIGHTTIME flag 2.0: 37 values (0.04%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 192747 values (99.94%)
#     OVERALL flag 2.0: 117 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94728 values (99.98%)
#     DAYTIME flag 2.0: 19 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98019 values (99.90%)
#     NIGHTTIME flag 2.0: 98 values (0.10%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (16.90%)
#     OVERALL flag 1.0: 64929 values (33.67%)
#     OVERALL flag 2.0: 95350 values (49.44%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (22.29%)
#     DAYTIME flag 1.0: 27506 values (29.03%)
#     DAYTIME flag 2.0: 46119 values (48.68%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (11.68%)
#     NIGHTTIME flag 1.0: 37423 values (38.14%)
#     NIGHTTIME flag 2.0: 49231 values (50.18%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_16_FN2O_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 161583 values (83.78%)
#     OVERALL flag 2.0: 31281 values (16.22%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 88545 values (93.45%)
#     DAYTIME flag 2.0: 6202 values (6.55%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 73038 values (74.44%)
#     NIGHTTIME flag 2.0: 25079 values (25.56%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_16_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 29680 values (15.39%)
#     OVERALL flag 1.0: 52554 values (27.25%)
#     OVERALL flag 2.0: 110630 values (57.36%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 20150 values (21.27%)
#     DAYTIME flag 1.0: 25370 values (26.78%)
#     DAYTIME flag 2.0: 49227 values (51.96%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 9530 values (9.71%)
#     NIGHTTIME flag 1.0: 27184 values (27.71%)
#     NIGHTTIME flag 2.0: 61403 values (62.58%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (24.48%)
#     OVERALL flag 1.0: 71137 values (48.57%)
#     OVERALL flag 2.0: 39468 values (26.95%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 23042 values (32.29%)
#     DAYTIME flag 1.0: 29966 values (41.99%)
#     DAYTIME flag 2.0: 18362 values (25.73%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 12812 values (17.06%)
#     NIGHTTIME flag 1.0: 41171 values (54.83%)
#     NIGHTTIME flag 2.0: 21106 values (28.11%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (94.78%)
#     OVERALL flag 1.0: 3286 values (2.24%)
#     OVERALL flag 2.0: 4358 values (2.98%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 67905 values (95.15%)
#     DAYTIME flag 1.0: 1685 values (2.36%)
#     DAYTIME flag 2.0: 1780 values (2.49%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 70910 values (94.43%)
#     NIGHTTIME flag 1.0: 1601 values (2.13%)
#     NIGHTTIME flag 2.0: 2578 values (3.43%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (99.62%)
#     OVERALL flag 1.0: 463 values (0.32%)
#     OVERALL flag 2.0: 89 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71215 values (99.78%)
#     DAYTIME flag 1.0: 130 values (0.18%)
#     DAYTIME flag 2.0: 25 values (0.04%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74692 values (99.47%)
#     NIGHTTIME flag 1.0: 333 values (0.44%)
#     NIGHTTIME flag 2.0: 64 values (0.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136043 values (92.89%)
#     OVERALL flag 2.0: 10416 values (7.11%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 66492 values (93.17%)
#     DAYTIME flag 2.0: 4878 values (6.83%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 69551 values (92.62%)
#     NIGHTTIME flag 2.0: 5538 values (7.38%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1299 values (0.89%)
#     OVERALL flag 2.0: 798 values (0.54%)
#     OVERALL flag missing: 144362 values (98.57%)
#
#     DAYTIME flag 0.0: 633 values (0.89%)
#     DAYTIME flag 2.0: 452 values (0.63%)
#     DAYTIME flag missing: 70285 values (98.48%)
#
#     NIGHTTIME flag 0.0: 666 values (0.89%)
#     NIGHTTIME flag 2.0: 346 values (0.46%)
#     NIGHTTIME flag missing: 74077 values (98.65%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (22.26%)
#     OVERALL flag 1.0: 65734 values (44.88%)
#     OVERALL flag 2.0: 48121 values (32.86%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (29.61%)
#     DAYTIME flag 1.0: 27716 values (38.83%)
#     DAYTIME flag 2.0: 22520 values (31.55%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (15.28%)
#     NIGHTTIME flag 1.0: 38018 values (50.63%)
#     NIGHTTIME flag 2.0: 25601 values (34.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 145800 values (99.55%)
#     OVERALL flag 2.0: 659 values (0.45%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71178 values (99.73%)
#     DAYTIME flag 2.0: 192 values (0.27%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74622 values (99.38%)
#     NIGHTTIME flag 2.0: 467 values (0.62%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 146411 values (99.97%)
#     OVERALL flag 2.0: 48 values (0.03%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71359 values (99.98%)
#     DAYTIME flag 2.0: 11 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75052 values (99.95%)
#     NIGHTTIME flag 2.0: 37 values (0.05%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 146342 values (99.92%)
#     OVERALL flag 2.0: 117 values (0.08%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71351 values (99.97%)
#     DAYTIME flag 2.0: 19 values (0.03%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74991 values (99.87%)
#     NIGHTTIME flag 2.0: 98 values (0.13%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (22.25%)
#     OVERALL flag 1.0: 64929 values (44.33%)
#     OVERALL flag 2.0: 48945 values (33.42%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (29.60%)
#     DAYTIME flag 1.0: 27506 values (38.54%)
#     DAYTIME flag 2.0: 22742 values (31.86%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (15.27%)
#     NIGHTTIME flag 1.0: 37423 values (49.84%)
#     NIGHTTIME flag 2.0: 26203 values (34.90%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_16_FN2O_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 122648 values (83.74%)
#     OVERALL flag 2.0: 23811 values (16.26%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 66694 values (93.45%)
#     DAYTIME flag 2.0: 4676 values (6.55%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 55954 values (74.52%)
#     NIGHTTIME flag 2.0: 19135 values (25.48%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_16_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 29680 values (20.27%)
#     OVERALL flag 1.0: 52554 values (35.88%)
#     OVERALL flag 2.0: 64225 values (43.85%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 20150 values (28.23%)
#     DAYTIME flag 1.0: 25370 values (35.55%)
#     DAYTIME flag 2.0: 25850 values (36.22%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 9530 values (12.69%)
#     NIGHTTIME flag 1.0: 27184 values (36.20%)
#     NIGHTTIME flag 2.0: 38375 values (51.11%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (75.94%)
#     OVERALL flag 2.0: 46405 values (24.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (75.33%)
#     DAYTIME flag 2.0: 23377 values (24.67%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (76.53%)
#     NIGHTTIME flag 2.0: 23028 values (23.47%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (18.59%)
#     OVERALL flag 1.0: 71137 values (36.88%)
#     OVERALL flag 2.0: 39468 values (20.46%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 23042 values (24.32%)
#     DAYTIME flag 1.0: 29966 values (31.63%)
#     DAYTIME flag 2.0: 18362 values (19.38%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 12812 values (13.06%)
#     NIGHTTIME flag 1.0: 41171 values (41.96%)
#     NIGHTTIME flag 2.0: 21106 values (21.51%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (71.98%)
#     OVERALL flag 1.0: 3286 values (1.70%)
#     OVERALL flag 2.0: 4363 values (2.26%)
#     OVERALL flag missing: 46400 values (24.06%)
#
#     DAYTIME flag 0.0: 67905 values (71.67%)
#     DAYTIME flag 1.0: 1685 values (1.78%)
#     DAYTIME flag 2.0: 1782 values (1.88%)
#     DAYTIME flag missing: 23375 values (24.67%)
#
#     NIGHTTIME flag 0.0: 70910 values (72.27%)
#     NIGHTTIME flag 1.0: 1601 values (1.63%)
#     NIGHTTIME flag 2.0: 2581 values (2.63%)
#     NIGHTTIME flag missing: 23025 values (23.47%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (75.65%)
#     OVERALL flag 1.0: 463 values (0.24%)
#     OVERALL flag 2.0: 89 values (0.05%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 71215 values (75.16%)
#     DAYTIME flag 1.0: 130 values (0.14%)
#     DAYTIME flag 2.0: 25 values (0.03%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 74692 values (76.13%)
#     NIGHTTIME flag 1.0: 333 values (0.34%)
#     NIGHTTIME flag 2.0: 64 values (0.07%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136171 values (70.60%)
#     OVERALL flag 2.0: 32052 values (16.62%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 66601 values (70.29%)
#     DAYTIME flag 2.0: 15765 values (16.64%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 69570 values (70.91%)
#     NIGHTTIME flag 2.0: 16287 values (16.60%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1304 values (0.68%)
#     OVERALL flag 2.0: 798 values (0.41%)
#     OVERALL flag missing: 190762 values (98.91%)
#
#     DAYTIME flag 0.0: 638 values (0.67%)
#     DAYTIME flag 2.0: 452 values (0.48%)
#     DAYTIME flag missing: 93657 values (98.85%)
#
#     NIGHTTIME flag 0.0: 666 values (0.68%)
#     NIGHTTIME flag 2.0: 346 values (0.35%)
#     NIGHTTIME flag missing: 97105 values (98.97%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (16.91%)
#     OVERALL flag 1.0: 65734 values (34.08%)
#     OVERALL flag 2.0: 94526 values (49.01%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (22.31%)
#     DAYTIME flag 1.0: 27716 values (29.25%)
#     DAYTIME flag 2.0: 45897 values (48.44%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (11.69%)
#     NIGHTTIME flag 1.0: 38018 values (38.75%)
#     NIGHTTIME flag 2.0: 48629 values (49.56%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 192205 values (99.66%)
#     OVERALL flag 2.0: 659 values (0.34%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94555 values (99.80%)
#     DAYTIME flag 2.0: 192 values (0.20%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 97650 values (99.52%)
#     NIGHTTIME flag 2.0: 467 values (0.48%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 192816 values (99.98%)
#     OVERALL flag 2.0: 48 values (0.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94736 values (99.99%)
#     DAYTIME flag 2.0: 11 values (0.01%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98080 values (99.96%)
#     NIGHTTIME flag 2.0: 37 values (0.04%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 192747 values (99.94%)
#     OVERALL flag 2.0: 117 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94728 values (99.98%)
#     DAYTIME flag 2.0: 19 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98019 values (99.90%)
#     NIGHTTIME flag 2.0: 98 values (0.10%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (16.90%)
#     OVERALL flag 1.0: 64929 values (33.67%)
#     OVERALL flag 2.0: 95350 values (49.44%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (22.29%)
#     DAYTIME flag 1.0: 27506 values (29.03%)
#     DAYTIME flag 2.0: 46119 values (48.68%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (11.68%)
#     NIGHTTIME flag 1.0: 37423 values (38.14%)
#     NIGHTTIME flag 2.0: 49231 values (50.18%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_FN2O_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 141763 values (73.50%)
#     OVERALL flag 2.0: 51101 values (26.50%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 82753 values (87.34%)
#     DAYTIME flag 2.0: 11994 values (12.66%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 59010 values (60.14%)
#     NIGHTTIME flag 2.0: 39107 values (39.86%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 27461 values (14.24%)
#     OVERALL flag 1.0: 44850 values (23.25%)
#     OVERALL flag 2.0: 120553 values (62.51%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 19070 values (20.13%)
#     DAYTIME flag 1.0: 23513 values (24.82%)
#     DAYTIME flag 2.0: 52164 values (55.06%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 8391 values (8.55%)
#     NIGHTTIME flag 1.0: 21337 values (21.75%)
#     NIGHTTIME flag 2.0: 68389 values (69.70%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (24.48%)
#     OVERALL flag 1.0: 71137 values (48.57%)
#     OVERALL flag 2.0: 39468 values (26.95%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 23042 values (32.29%)
#     DAYTIME flag 1.0: 29966 values (41.99%)
#     DAYTIME flag 2.0: 18362 values (25.73%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 12812 values (17.06%)
#     NIGHTTIME flag 1.0: 41171 values (54.83%)
#     NIGHTTIME flag 2.0: 21106 values (28.11%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (94.78%)
#     OVERALL flag 1.0: 3286 values (2.24%)
#     OVERALL flag 2.0: 4358 values (2.98%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 67905 values (95.15%)
#     DAYTIME flag 1.0: 1685 values (2.36%)
#     DAYTIME flag 2.0: 1780 values (2.49%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 70910 values (94.43%)
#     NIGHTTIME flag 1.0: 1601 values (2.13%)
#     NIGHTTIME flag 2.0: 2578 values (3.43%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (99.62%)
#     OVERALL flag 1.0: 463 values (0.32%)
#     OVERALL flag 2.0: 89 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71215 values (99.78%)
#     DAYTIME flag 1.0: 130 values (0.18%)
#     DAYTIME flag 2.0: 25 values (0.04%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74692 values (99.47%)
#     NIGHTTIME flag 1.0: 333 values (0.44%)
#     NIGHTTIME flag 2.0: 64 values (0.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136043 values (92.89%)
#     OVERALL flag 2.0: 10416 values (7.11%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 66492 values (93.17%)
#     DAYTIME flag 2.0: 4878 values (6.83%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 69551 values (92.62%)
#     NIGHTTIME flag 2.0: 5538 values (7.38%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1299 values (0.89%)
#     OVERALL flag 2.0: 798 values (0.54%)
#     OVERALL flag missing: 144362 values (98.57%)
#
#     DAYTIME flag 0.0: 633 values (0.89%)
#     DAYTIME flag 2.0: 452 values (0.63%)
#     DAYTIME flag missing: 70285 values (98.48%)
#
#     NIGHTTIME flag 0.0: 666 values (0.89%)
#     NIGHTTIME flag 2.0: 346 values (0.46%)
#     NIGHTTIME flag missing: 74077 values (98.65%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (22.26%)
#     OVERALL flag 1.0: 65734 values (44.88%)
#     OVERALL flag 2.0: 48121 values (32.86%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (29.61%)
#     DAYTIME flag 1.0: 27716 values (38.83%)
#     DAYTIME flag 2.0: 22520 values (31.55%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (15.28%)
#     NIGHTTIME flag 1.0: 38018 values (50.63%)
#     NIGHTTIME flag 2.0: 25601 values (34.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 145800 values (99.55%)
#     OVERALL flag 2.0: 659 values (0.45%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71178 values (99.73%)
#     DAYTIME flag 2.0: 192 values (0.27%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74622 values (99.38%)
#     NIGHTTIME flag 2.0: 467 values (0.62%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 146411 values (99.97%)
#     OVERALL flag 2.0: 48 values (0.03%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71359 values (99.98%)
#     DAYTIME flag 2.0: 11 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75052 values (99.95%)
#     NIGHTTIME flag 2.0: 37 values (0.05%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 146342 values (99.92%)
#     OVERALL flag 2.0: 117 values (0.08%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71351 values (99.97%)
#     DAYTIME flag 2.0: 19 values (0.03%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74991 values (99.87%)
#     NIGHTTIME flag 2.0: 98 values (0.13%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (22.25%)
#     OVERALL flag 1.0: 64929 values (44.33%)
#     OVERALL flag 2.0: 48945 values (33.42%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (29.60%)
#     DAYTIME flag 1.0: 27506 values (38.54%)
#     DAYTIME flag 2.0: 22742 values (31.86%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (15.27%)
#     NIGHTTIME flag 1.0: 37423 values (49.84%)
#     NIGHTTIME flag 2.0: 26203 values (34.90%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_FN2O_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 107532 values (73.42%)
#     OVERALL flag 2.0: 38927 values (26.58%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 62332 values (87.34%)
#     DAYTIME flag 2.0: 9038 values (12.66%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 45200 values (60.20%)
#     NIGHTTIME flag 2.0: 29889 values (39.80%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 27461 values (18.75%)
#     OVERALL flag 1.0: 44850 values (30.62%)
#     OVERALL flag 2.0: 74148 values (50.63%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 19070 values (26.72%)
#     DAYTIME flag 1.0: 23513 values (32.95%)
#     DAYTIME flag 2.0: 28787 values (40.33%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 8391 values (11.17%)
#     NIGHTTIME flag 1.0: 21337 values (28.42%)
#     NIGHTTIME flag 2.0: 45361 values (60.41%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (75.94%)
#     OVERALL flag 2.0: 46405 values (24.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (75.33%)
#     DAYTIME flag 2.0: 23377 values (24.67%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (76.53%)
#     NIGHTTIME flag 2.0: 23028 values (23.47%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (18.59%)
#     OVERALL flag 1.0: 71137 values (36.88%)
#     OVERALL flag 2.0: 39468 values (20.46%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 23042 values (24.32%)
#     DAYTIME flag 1.0: 29966 values (31.63%)
#     DAYTIME flag 2.0: 18362 values (19.38%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 12812 values (13.06%)
#     NIGHTTIME flag 1.0: 41171 values (41.96%)
#     NIGHTTIME flag 2.0: 21106 values (21.51%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (71.98%)
#     OVERALL flag 1.0: 3286 values (1.70%)
#     OVERALL flag 2.0: 4363 values (2.26%)
#     OVERALL flag missing: 46400 values (24.06%)
#
#     DAYTIME flag 0.0: 67905 values (71.67%)
#     DAYTIME flag 1.0: 1685 values (1.78%)
#     DAYTIME flag 2.0: 1782 values (1.88%)
#     DAYTIME flag missing: 23375 values (24.67%)
#
#     NIGHTTIME flag 0.0: 70910 values (72.27%)
#     NIGHTTIME flag 1.0: 1601 values (1.63%)
#     NIGHTTIME flag 2.0: 2581 values (2.63%)
#     NIGHTTIME flag missing: 23025 values (23.47%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (75.65%)
#     OVERALL flag 1.0: 463 values (0.24%)
#     OVERALL flag 2.0: 89 values (0.05%)
#     OVERALL flag missing: 46405 values (24.06%)
#
#     DAYTIME flag 0.0: 71215 values (75.16%)
#     DAYTIME flag 1.0: 130 values (0.14%)
#     DAYTIME flag 2.0: 25 values (0.03%)
#     DAYTIME flag missing: 23377 values (24.67%)
#
#     NIGHTTIME flag 0.0: 74692 values (76.13%)
#     NIGHTTIME flag 1.0: 333 values (0.34%)
#     NIGHTTIME flag 2.0: 64 values (0.07%)
#     NIGHTTIME flag missing: 23028 values (23.47%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136171 values (70.60%)
#     OVERALL flag 2.0: 32052 values (16.62%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 66601 values (70.29%)
#     DAYTIME flag 2.0: 15765 values (16.64%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 69570 values (70.91%)
#     NIGHTTIME flag 2.0: 16287 values (16.60%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 168223 values (87.22%)
#     OVERALL flag missing: 24641 values (12.78%)
#
#     DAYTIME flag 0.0: 82366 values (86.93%)
#     DAYTIME flag missing: 12381 values (13.07%)
#
#     NIGHTTIME flag 0.0: 85857 values (87.50%)
#     NIGHTTIME flag missing: 12260 values (12.50%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1304 values (0.68%)
#     OVERALL flag 2.0: 798 values (0.41%)
#     OVERALL flag missing: 190762 values (98.91%)
#
#     DAYTIME flag 0.0: 638 values (0.67%)
#     DAYTIME flag 2.0: 452 values (0.48%)
#     DAYTIME flag missing: 93657 values (98.85%)
#
#     NIGHTTIME flag 0.0: 666 values (0.68%)
#     NIGHTTIME flag 2.0: 346 values (0.35%)
#     NIGHTTIME flag missing: 97105 values (98.97%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (16.91%)
#     OVERALL flag 1.0: 65734 values (34.08%)
#     OVERALL flag 2.0: 94526 values (49.01%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (22.31%)
#     DAYTIME flag 1.0: 27716 values (29.25%)
#     DAYTIME flag 2.0: 45897 values (48.44%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (11.69%)
#     NIGHTTIME flag 1.0: 38018 values (38.75%)
#     NIGHTTIME flag 2.0: 48629 values (49.56%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 192205 values (99.66%)
#     OVERALL flag 2.0: 659 values (0.34%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94555 values (99.80%)
#     DAYTIME flag 2.0: 192 values (0.20%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 97650 values (99.52%)
#     NIGHTTIME flag 2.0: 467 values (0.48%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 192816 values (99.98%)
#     OVERALL flag 2.0: 48 values (0.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94736 values (99.99%)
#     DAYTIME flag 2.0: 11 values (0.01%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98080 values (99.96%)
#     NIGHTTIME flag 2.0: 37 values (0.04%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 192747 values (99.94%)
#     OVERALL flag 2.0: 117 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 94728 values (99.98%)
#     DAYTIME flag 2.0: 19 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 98019 values (99.90%)
#     NIGHTTIME flag 2.0: 98 values (0.10%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (16.90%)
#     OVERALL flag 1.0: 64929 values (33.67%)
#     OVERALL flag 2.0: 95350 values (49.44%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (22.29%)
#     DAYTIME flag 1.0: 27506 values (29.03%)
#     DAYTIME flag 2.0: 46119 values (48.68%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (11.68%)
#     NIGHTTIME flag 1.0: 37423 values (38.14%)
#     NIGHTTIME flag 2.0: 49231 values (50.18%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_84_FN2O_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 117408 values (60.88%)
#     OVERALL flag 2.0: 75456 values (39.12%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 73038 values (77.09%)
#     DAYTIME flag 2.0: 21709 values (22.91%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 44370 values (45.22%)
#     NIGHTTIME flag 2.0: 53747 values (54.78%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_84_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 23952 values (12.42%)
#     OVERALL flag 1.0: 35855 values (18.59%)
#     OVERALL flag 2.0: 133057 values (68.99%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 17101 values (18.05%)
#     DAYTIME flag 1.0: 20418 values (21.55%)
#     DAYTIME flag 2.0: 57228 values (60.40%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 6851 values (6.98%)
#     NIGHTTIME flag 1.0: 15437 values (15.73%)
#     NIGHTTIME flag 2.0: 75829 values (77.28%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FN2O_MISSING_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SSITC_TEST:
#     OVERALL flag 0.0: 35854 values (24.48%)
#     OVERALL flag 1.0: 71137 values (48.57%)
#     OVERALL flag 2.0: 39468 values (26.95%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 23042 values (32.29%)
#     DAYTIME flag 1.0: 29966 values (41.99%)
#     DAYTIME flag 2.0: 18362 values (25.73%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 12812 values (17.06%)
#     NIGHTTIME flag 1.0: 41171 values (54.83%)
#     NIGHTTIME flag 2.0: 21106 values (28.11%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_COMPLETENESS_TEST:
#     OVERALL flag 0.0: 138815 values (94.78%)
#     OVERALL flag 1.0: 3286 values (2.24%)
#     OVERALL flag 2.0: 4358 values (2.98%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 67905 values (95.15%)
#     DAYTIME flag 1.0: 1685 values (2.36%)
#     DAYTIME flag 2.0: 1780 values (2.49%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 70910 values (94.43%)
#     NIGHTTIME flag 1.0: 1601 values (2.13%)
#     NIGHTTIME flag 2.0: 2578 values (3.43%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_SCF_TEST:
#     OVERALL flag 0.0: 145907 values (99.62%)
#     OVERALL flag 1.0: 463 values (0.32%)
#     OVERALL flag 2.0: 89 values (0.06%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71215 values (99.78%)
#     DAYTIME flag 1.0: 130 values (0.18%)
#     DAYTIME flag 2.0: 25 values (0.04%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74692 values (99.47%)
#     NIGHTTIME flag 1.0: 333 values (0.44%)
#     NIGHTTIME flag 2.0: 64 values (0.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST:
#     OVERALL flag 0.0: 136043 values (92.89%)
#     OVERALL flag 2.0: 10416 values (7.11%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 66492 values (93.17%)
#     DAYTIME flag 2.0: 4878 values (6.83%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 69551 values (92.62%)
#     NIGHTTIME flag 2.0: 5538 values (7.38%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 146459 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71370 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75089 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FN2O_VM97_AOA_HF_TEST:
#     OVERALL flag 0.0: 1299 values (0.89%)
#     OVERALL flag 2.0: 798 values (0.54%)
#     OVERALL flag missing: 144362 values (98.57%)
#
#     DAYTIME flag 0.0: 633 values (0.89%)
#     DAYTIME flag 2.0: 452 values (0.63%)
#     DAYTIME flag missing: 70285 values (98.48%)
#
#     NIGHTTIME flag 0.0: 666 values (0.89%)
#     NIGHTTIME flag 2.0: 346 values (0.46%)
#     NIGHTTIME flag missing: 74077 values (98.65%)
#
# FLAG_L2_FN2O_QCF:
#     OVERALL flag 0.0: 32604 values (22.26%)
#     OVERALL flag 1.0: 65734 values (44.88%)
#     OVERALL flag 2.0: 48121 values (32.86%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21134 values (29.61%)
#     DAYTIME flag 1.0: 27716 values (38.83%)
#     DAYTIME flag 2.0: 22520 values (31.55%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11470 values (15.28%)
#     NIGHTTIME flag 1.0: 38018 values (50.63%)
#     NIGHTTIME flag 2.0: 25601 values (34.09%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST:
#     OVERALL flag 0.0: 145800 values (99.55%)
#     OVERALL flag 2.0: 659 values (0.45%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71178 values (99.73%)
#     DAYTIME flag 2.0: 192 values (0.27%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74622 values (99.38%)
#     NIGHTTIME flag 2.0: 467 values (0.62%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST:
#     OVERALL flag 0.0: 146411 values (99.97%)
#     OVERALL flag 2.0: 48 values (0.03%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71359 values (99.98%)
#     DAYTIME flag 2.0: 11 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 75052 values (99.95%)
#     NIGHTTIME flag 2.0: 37 values (0.05%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST:
#     OVERALL flag 0.0: 146342 values (99.92%)
#     OVERALL flag 2.0: 117 values (0.08%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 71351 values (99.97%)
#     DAYTIME flag 2.0: 19 values (0.03%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 74991 values (99.87%)
#     NIGHTTIME flag 2.0: 98 values (0.13%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 32585 values (22.25%)
#     OVERALL flag 1.0: 64929 values (44.33%)
#     OVERALL flag 2.0: 48945 values (33.42%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 21122 values (29.60%)
#     DAYTIME flag 1.0: 27506 values (38.54%)
#     DAYTIME flag 2.0: 22742 values (31.86%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 11463 values (15.27%)
#     NIGHTTIME flag 1.0: 37423 values (49.84%)
#     NIGHTTIME flag 2.0: 26203 values (34.90%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_84_FN2O_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 88823 values (60.65%)
#     OVERALL flag 2.0: 57636 values (39.35%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 54959 values (77.01%)
#     DAYTIME flag 2.0: 16411 values (22.99%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 33864 values (45.10%)
#     NIGHTTIME flag 2.0: 41225 values (54.90%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_84_FN2O_L3.1_QCF:
#     OVERALL flag 0.0: 23952 values (16.35%)
#     OVERALL flag 1.0: 35855 values (24.48%)
#     OVERALL flag 2.0: 86652 values (59.16%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 17101 values (23.96%)
#     DAYTIME flag 1.0: 20418 values (28.61%)
#     DAYTIME flag 2.0: 33851 values (47.43%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 6851 values (9.12%)
#     NIGHTTIME flag 1.0: 15437 values (20.56%)
#     NIGHTTIME flag 2.0: 52801 values (70.32%)
#     NIGHTTIME flag missing: 0 values (0.00%)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Overview: data after `Level-3.3`

# %% [markdown]
# ## Flux variable names

# %%
fluxes_qcf = [c for c in fpc.fpc_df.columns if str(c).endswith("_QCF") and not str(c).startswith("FLAG_") and "L3.3" in c]
fluxes_qcf0 = [c for c in fpc.fpc_df.columns if
               str(c).endswith("_QCF0") and not str(c).startswith("FLAG_") and "L3.3" in c]
print(f"Quality-controlled fluxes: {fluxes_qcf}")
print(f"Quality-controlled fluxes, HIGHEST QUALITY: {fluxes_qcf0}")
if (DAYTIME_ACCEPT_QCF_BELOW == 1) & (NIGHTTIMETIME_ACCEPT_QCF_BELOW == 1):
    print(f"{'*' * 100}\nNote that since only QCF below 1 is accepted for daytime and nighttime data, "
          f"the _QCF and _QCF0 variables are identical.")
# Out:
# Quality-controlled fluxes: ['FN2O_L3.1_L3.3_CUT_16_QCF', 'FN2O_L3.1_L3.3_CUT_50_QCF', 'FN2O_L3.1_L3.3_CUT_84_QCF']
# Quality-controlled fluxes, HIGHEST QUALITY: ['FN2O_L3.1_L3.3_CUT_16_QCF0', 'FN2O_L3.1_L3.3_CUT_50_QCF0', 'FN2O_L3.1_L3.3_CUT_84_QCF0']

# %% [markdown]
# </br>

# %%
FLUXVAR2QCF = fpc.filteredseries_level2_qcf.name
FLUXVAR31QCF = fpc.filteredseries_level31_qcf.name
FLUXVAR32QCF = fpc.filteredseries_level32_qcf.name
FLUXVAR32QCF_HQ = f"{FLUXVAR32QCF}0"
FLUXVAR33QCF = fpc.filteredseries_level33_qcf

print("--------------------------")
print("OVERVIEW OF FLUX VARIABLES")
print("--------------------------")
print(
    f""
    f"{FLUXVAR} ... original input flux\n"
    f"{FLUXVAR2QCF} ... flux quality-controlled with Level-2 flags\n    -->  not used in any further processing steps\n"
    f"{FLUXVAR31QCF} ... flux quality-controlled with Level-2 flags, including Level-3.1 storage correction\n   -->  not used in any further processing steps\n"
    f"{FLUXVAR32QCF} ... flux quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)\n    -->  not used in any further processing steps\n"
    f"{FLUXVAR32QCF_HQ} ... highest-quality flux (QCF=0), quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)\n    -->  not used in any further processing steps\n"
)
print("Variables for further steps:")
for key, value in FLUXVAR33QCF.items():
    print(
        f"{FLUXVAR33QCF[key].name} ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering ({key}), including Level-3.1 storage correction\n-->   to be used in gap-filling and all further steps")

if (DAYTIME_ACCEPT_QCF_BELOW == 1) & (NIGHTTIMETIME_ACCEPT_QCF_BELOW == 1):
    print(f"{'*' * 100}\nNote that since only QCF below 1 is accepted for daytime and nighttime data, "
          f"the _QCF and _QCF0 variables are identical.")
# Out:
# --------------------------
# OVERVIEW OF FLUX VARIABLES
# --------------------------
# FN2O ... original input flux
# FN2O_L2_QCF ... flux quality-controlled with Level-2 flags
#     -->  not used in any further processing steps
# FN2O_L3.1_QCF ... flux quality-controlled with Level-2 flags, including Level-3.1 storage correction
#    -->  not used in any further processing steps
# FN2O_L3.1_L3.2_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)
#     -->  not used in any further processing steps
# FN2O_L3.1_L3.2_QCF0 ... highest-quality flux (QCF=0), quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)
#     -->  not used in any further processing steps
#
# Variables for further steps:
# FN2O_L3.1_L3.3_CUT_16_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering (CUT_16), including Level-3.1 storage correction
# -->   to be used in gap-filling and all further steps
# FN2O_L3.1_L3.3_CUT_50_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering (CUT_50), including Level-3.1 storage correction
# -->   to be used in gap-filling and all further steps
# FN2O_L3.1_L3.3_CUT_84_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering (CUT_84), including Level-3.1 storage correction
# -->   to be used in gap-filling and all further steps

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot quality-controlled flux after `Level-3.3`
# - Plot flux after storage-correction, flux quality control, outlier removal and USTAR filtering

# %%
for key, value in FLUXVAR33QCF.items():
    # TimeSeries(series=fpc.fpc_df[fluxhq]).plot_interactive()
    TimeSeries(series=fpc.fpc_df[FLUXVAR33QCF[key].name]).plot()

# %%
# Creating a dictionary by passing Series objects as values

frame = {
    f'original ({FLUXVAR})': fpc.fpc_df[FLUXVAR],
    f'+ flux quality flags ({FLUXVAR2QCF})': fpc.fpc_df[FLUXVAR2QCF],
    f'++ storage correction ({FLUXVAR31QCF})': fpc.fpc_df[FLUXVAR31QCF],
    f'+++ outlier removal ({FLUXVAR32QCF})': fpc.fpc_df[FLUXVAR32QCF]
}
for key, value in FLUXVAR33QCF.items():
    frame[f'+++ USTAR filtering ({key}, {FLUXVAR33QCF[key].name})'] = FLUXVAR33QCF[key]

overview = pd.DataFrame(frame)
overview.cumsum().plot(title=f"Cumulative", figsize=(14, 7), x_compat=True, alpha=1);

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Available `Level-3.3` fluxes

# %%
_fluxcols = [x for x in fpc.fpc_df.columns if
             'L3.1' and 'L3.3' in x and str(x).endswith('_QCF') and not str(x).startswith('FLAG_')]
_fluxcols
# Out:
# ['FN2O_L3.1_L3.3_CUT_16_QCF',
#  'FN2O_L3.1_L3.3_CUT_50_QCF',
#  'FN2O_L3.1_L3.3_CUT_84_QCF']

# %%
_subset = fpc.fpc_df[_fluxcols].copy()
_subset.head()
# Out:
#                      FN2O_L3.1_L3.3_CUT_16_QCF  FN2O_L3.1_L3.3_CUT_50_QCF  FN2O_L3.1_L3.3_CUT_84_QCF
# TIMESTAMP_MIDDLE
# 2012-01-01 00:15:00                        NaN                        NaN                        NaN
# 2012-01-01 00:45:00                        NaN                        NaN                        NaN
# 2012-01-01 01:15:00                        NaN                        NaN                        NaN
# 2012-01-01 01:45:00                        NaN                        NaN                        NaN
# 2012-01-01 02:15:00                        NaN                        NaN                        NaN

# %%
_subset.plot(subplots=True, x_compat=True,
             title="Available Level-3.3 fluxes after application of all quality checks", figsize=(12, 4.5));

# %%
# # Draw boxplots
# for _f in _fluxcols:
#     boxplots_df = fpc.fpc_df[[_f, "DAYTIME"]].copy()
#     boxplots_df["MONTH"] = boxplots_df.index.month
#     sns.set_theme(style="ticks", palette="pastel")
#     plt.figure(figsize=(12, 3))
#     sns.boxplot(x="MONTH", y=_f, palette=["r", "b"], hue="DAYTIME", data=boxplots_df).set_title(f"Boxplot of {_f}")
#     sns.despine(offset=10, trim=True)
#     plt.axhline(0, color="black");

# %%
# # Draw a nested violinplot and split the violins for easier comparison
# for _f in _fluxcols:
#     plt.figure(figsize=(20, 2))
#     sns.violinplot(data=boxplots_df, x="MONTH", y=fpc.fpc_df[_f], hue="DAYTIME", split=True, palette=["r", "b"], gap=.1,
#                    inner="quart")
#     plt.axhline(0, color="black")

# %% [markdown]
# </br>

# %% [markdown]
# ## Save Level-3.3 results to file
# - If needed, save results so far (input data and all created variables, e.g. flags and filtered fluxes) to a file
# - This can be useful if e.g. gap-filling should be done elsewhere (ReddyProc...)

# %%
# # results_df = fpc.get_data()
# out_df = fpc.fpc_df.copy()
# filename = "32.2_FluxProcessingChain_L3.3_NEE-results"
# out_df.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=out_df, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Export for MDS gap-filling in REddyProc

# %%
# from diive.core.times.times import insert_timestamp
# export = results_df.copy()

# %%
# exportcols = ['NEE_L3.1_L3.3_CUT_16_QCF', 'NEE_L3.1_L3.3_CUT_50_QCF', 'NEE_L3.1_L3.3_CUT_84_QCF',
#               'SW_IN_T1_2_1', 'TA_T1_2_1', 'VPD_T1_2_1']
# export = export[exportcols].copy()
# locs = (export.index.year >= 2005) & (export.index.year <= 2023)
# export = export[locs].copy()
# export = insert_timestamp(data=export, convention="end", set_as_index=True)
# export

# %%
# filename = "32.3_FluxProcessingChain_L3.3_NEE-subset-forREddyProc"
# export.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=export, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Level-4.1: **GAP-FILLING**

# %% [markdown]
# ---

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %%
# %%time
# Management variables
MGMT_VARS = [
    "TIMESINCE_MGMT_FERT_MIN_FOOTPRINT", "TIMESINCE_MGMT_FERT_ORG_FOOTPRINT",
    "TIMESINCE_MGMT_GRAZING_FOOTPRINT", "TIMESINCE_MGMT_MOWING_FOOTPRINT",
    "TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT", "TIMESINCE_MGMT_SOWING_FOOTPRINT",
    "TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT", "TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1"
]

# Already lagged variants of SWC, TS and PRECIP
AGG_VARS = [
    # SWC
    "SWC_GF1_0.15_1_gfXG_MEAN3H",
    ".SWC_GF1_0.15_1_gfXG_MEAN3H-24", ".SWC_GF1_0.15_1_gfXG_MEAN3H-18",
    ".SWC_GF1_0.15_1_gfXG_MEAN3H-12", ".SWC_GF1_0.15_1_gfXG_MEAN3H-6",
    # TS
    "TS_GF1_0.04_1_gfXG_MEAN3H",
    ".TS_GF1_0.04_1_gfXG_MEAN3H-24", ".TS_GF1_0.04_1_gfXG_MEAN3H-18",
    ".TS_GF1_0.04_1_gfXG_MEAN3H-12", ".TS_GF1_0.04_1_gfXG_MEAN3H-6",
    "TS_GF1_0.15_1_gfXG_MEAN3H",
    ".TS_GF1_0.15_1_gfXG_MEAN3H-24", ".TS_GF1_0.15_1_gfXG_MEAN3H-18",
    ".TS_GF1_0.15_1_gfXG_MEAN3H-12", ".TS_GF1_0.15_1_gfXG_MEAN3H-6",
    "TS_GF1_0.4_1_gfXG_MEAN3H",
    ".TS_GF1_0.4_1_gfXG_MEAN3H-24", ".TS_GF1_0.4_1_gfXG_MEAN3H-18",
    ".TS_GF1_0.4_1_gfXG_MEAN3H-12", ".TS_GF1_0.4_1_gfXG_MEAN3H-6",
    # PRECIP
    "PREC_RAIN_TOT_GF1_0.5_1_MEAN3H",
    ".PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24", ".PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18",
    ".PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12", ".PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6"
]

METEO_VARS = [
    "TS_GF1_0.04_1_gfXG",
    "TS_GF1_0.15_1_gfXG",
    "TS_GF1_0.4_1_gfXG",
    "SWC_GF1_0.15_1_gfXG", 
    "PREC_RAIN_TOT_GF1_0.5_1"
]

FEATURES = METEO_VARS + AGG_VARS + MGMT_VARS

fpc.level41_gapfilling_longterm(
    run_mds=False,
    run_random_forest=True,
    verbose=True,
    ml_feature_settings={
        'features': FEATURES,
        'features_lag': [-1, -1],
        'features_lag_stepsize': 1,
        'features_lag_exclude_cols': MGMT_VARS + AGG_VARS,  # Management variables and already lagged variables are not lagged here
        'reduce_features': True,
        'include_timestamp_as_features': True,
        'add_continuous_record_number': False,
        'perm_n_repeats': 5,
        },
    rf_settings={
        'n_estimators': 500,
        'random_state': 42,
        'min_samples_split': 2,
        'min_samples_leaf': 1,
        'n_jobs': -1
        },
    # mds_settings={
    #     'swin': "SW_IN_T1_2_1",
    #     'ta': "TA_T1_2_1",
    #     'vpd': "VPD_T1_2_1",
    #     'swin_class': 50,
    #     'ta_class': 2.5,
    #     'vpd_class': 0.5,
    #     'min_n_vals_nt': 0
    # }
)
# Out:
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TS_GF1_0.04_1_gfXG', 'TS_GF1_0.15_1_gfXG', 'TS_GF1_0.4_1_gfXG', 'SWC_GF1_0.15_1_gfXG', 'PREC_RAIN_TOT_GF1_0.5_1'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['SWC_GF1_0.15_1_gfXG_MEAN3H', '.SWC_GF1_0.15_1_gfXG_MEAN3H-24', '.SWC_GF1_0.15_1_gfXG_MEAN3H-18', '.SWC_GF1_0.15_1_gfXG_MEAN3H-12', '.SWC_GF1_0.15_1_gfXG_MEAN3H-6', 'TS_GF1_0.04_1_gfXG_MEAN3H', '.TS_GF1_0.04_1_gfXG_MEAN3H-24', '.TS_GF1_0.04_1_gfXG_MEAN3H-18', '.TS_GF1_0.04_1_gfXG_MEAN3H-12', '.TS_GF1_0.04_1_gfXG_MEAN3H-6', 'TS_GF1_0.15_1_gfXG_MEAN3H', '.TS_GF1_0.15_1_gfXG_MEAN3H-24', '.TS_GF1_0.15_1_gfXG_MEAN3H-18', '.TS_GF1_0.15_1_gfXG_MEAN3H-12', '.TS_GF1_0.15_1_gfXG_MEAN3H-6', 'TS_GF1_0.4_1_gfXG_MEAN3H', '.TS_GF1_0.4_1_gfXG_MEAN3H-24', '.TS_GF1_0.4_1_gfXG_MEAN3H-18', '.TS_GF1_0.4_1_gfXG_MEAN3H-12', '.TS_GF1_0.4_1_gfXG_MEAN3H-6', 'PREC_RAIN_TOT_GF1_0.5_1_MEAN3H', '.PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24', '.PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18', '.PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12', '.PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6', 'TIMESINCE_MGMT_FERT_MIN_FOOTPRINT', 'TIMESINCE_MGMT_FERT_ORG_FOOTPRINT', 'TIMESINCE_MGMT_GRAZING_FOOTPRINT', 'TIMESINCE_MGMT_MOWING_FOOTPRINT', 'TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT', 'TIMESINCE_MGMT_SOWING_FOOTPRINT', 'TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT', 'TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1', 'FN2O_L3.1_L3.3_CUT_16_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.MONTH', '.WEEK', '.DOY', '.HOUR', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2012-01-01 00:15:00 and 2022-12-31 23:45:00 ...
# [neighboring_years] Assigned [2012, 2013, 2014] to data pool for 2012.
# [neighboring_years] Assigned [2012, 2013, 2014] to data pool for 2013.
# [neighboring_years] Assigned [2013, 2014, 2015] to data pool for 2014.
# [neighboring_years] Assigned [2014, 2015, 2016] to data pool for 2015.
# [neighboring_years] Assigned [2015, 2016, 2017] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2022.
# Initializing model for 2012 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2013 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2014 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2015 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# FN2O_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# ---
# Reducing features based on permutation importance for year 2012 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.021883477011435136.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.665663
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.309907
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.194790
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.162270
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.154537
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.080109
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.078238
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                       0.074038
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.061730
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.060245
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.042412
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.036921
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.034658
# .TS_GF1_0.04_1_gfXG-1                                0.033749
# TS_GF1_0.04_1_gfXG                                   0.032974
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.031665
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.031518
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.030502
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.029017
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                        0.023256
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                     PERM_IMPORTANCE
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                0.021858
# TS_GF1_0.04_1_gfXG_MEAN3H                  0.021775
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12             0.021264
# .TS_GF1_0.15_1_gfXG_MEAN3H-18              0.021250
# .TS_GF1_0.15_1_gfXG_MEAN3H-6               0.020802
# SWC_GF1_0.15_1_gfXG                        0.020088
# .HOUR                                      0.020055
# TS_GF1_0.4_1_gfXG                          0.018864
# SWC_GF1_0.15_1_gfXG_MEAN3H                 0.017599
# .TS_GF1_0.4_1_gfXG-1                       0.016991
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6              0.016356
# TIMESINCE_MGMT_GRAZING_FOOTPRINT           0.015244
# .SWC_GF1_0.15_1_gfXG-1                     0.013586
# TS_GF1_0.4_1_gfXG_MEAN3H                   0.013489
# TS_GF1_0.15_1_gfXG                         0.011842
# TS_GF1_0.15_1_gfXG_MEAN3H                  0.011618
# .DOY                                       0.011416
# .TS_GF1_0.15_1_gfXG-1                      0.009529
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24         0.007880
# .YEARDOY                                   0.006786
# PREC_RAIN_TOT_GF1_0.5_1                    0.004297
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6          0.004017
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18         0.003377
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H             0.002664
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12         0.002173
# .WEEK                                      0.001621
# .YEARWEEK                                  0.001317
# .PREC_RAIN_TOT_GF1_0.5_1-1                 0.001072
# .SEASON                                    0.000607
# .YEARMONTH                                 0.000481
# .MONTH                                     0.000262
# .YEAR                                      0.000053
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2013 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.021883477011435136.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.665663
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.309907
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.194790
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.162270
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.154537
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.080109
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.078238
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                       0.074038
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.061730
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.060245
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.042412
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.036921
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.034658
# .TS_GF1_0.04_1_gfXG-1                                0.033749
# TS_GF1_0.04_1_gfXG                                   0.032974
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.031665
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.031518
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.030502
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.029017
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                        0.023256
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                     PERM_IMPORTANCE
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                0.021858
# TS_GF1_0.04_1_gfXG_MEAN3H                  0.021775
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12             0.021264
# .TS_GF1_0.15_1_gfXG_MEAN3H-18              0.021250
# .TS_GF1_0.15_1_gfXG_MEAN3H-6               0.020802
# SWC_GF1_0.15_1_gfXG                        0.020088
# .HOUR                                      0.020055
# TS_GF1_0.4_1_gfXG                          0.018864
# SWC_GF1_0.15_1_gfXG_MEAN3H                 0.017599
# .TS_GF1_0.4_1_gfXG-1                       0.016991
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6              0.016356
# TIMESINCE_MGMT_GRAZING_FOOTPRINT           0.015244
# .SWC_GF1_0.15_1_gfXG-1                     0.013586
# TS_GF1_0.4_1_gfXG_MEAN3H                   0.013489
# TS_GF1_0.15_1_gfXG                         0.011842
# TS_GF1_0.15_1_gfXG_MEAN3H                  0.011618
# .DOY                                       0.011416
# .TS_GF1_0.15_1_gfXG-1                      0.009529
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24         0.007880
# .YEARDOY                                   0.006786
# PREC_RAIN_TOT_GF1_0.5_1                    0.004297
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6          0.004017
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18         0.003377
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H             0.002664
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12         0.002173
# .WEEK                                      0.001621
# .YEARWEEK                                  0.001317
# .PREC_RAIN_TOT_GF1_0.5_1-1                 0.001072
# .SEASON                                    0.000607
# .YEARMONTH                                 0.000481
# .MONTH                                     0.000262
# .YEAR                                      0.000053
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2014 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.07841272587633638.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.591511
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.349450
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.268018
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.165153
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.158955
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.155350
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.151259
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.140553
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.134523
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.114455
# TS_GF1_0.04_1_gfXG                                   0.087226
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                           PERM_IMPORTANCE
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                   0.072287
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                    0.070918
# .HOUR                                            0.070140
# TS_GF1_0.04_1_gfXG_MEAN3H                        0.064785
# SWC_GF1_0.15_1_gfXG                              0.062107
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                     0.051958
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                     0.050657
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                    0.048566
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                   0.048053
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                    0.045489
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                    0.042481
# .TS_GF1_0.04_1_gfXG-1                            0.042128
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                   0.038832
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                     0.035197
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                     0.033329
# .SWC_GF1_0.15_1_gfXG-1                           0.032678
# .DOY                                             0.030985
# TS_GF1_0.4_1_gfXG                                0.030038
# TS_GF1_0.15_1_gfXG_MEAN3H                        0.029964
# TIMESINCE_MGMT_SOWING_FOOTPRINT                  0.027989
# TS_GF1_0.15_1_gfXG                               0.027251
# .TS_GF1_0.15_1_gfXG-1                            0.026147
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT         0.025861
# SWC_GF1_0.15_1_gfXG_MEAN3H                       0.025852
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                      0.025105
# .TS_GF1_0.4_1_gfXG-1                             0.025014
# .YEARDOY                                         0.019316
# TS_GF1_0.4_1_gfXG_MEAN3H                         0.019130
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24               0.016006
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18               0.015725
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12               0.015428
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6                0.014366
# PREC_RAIN_TOT_GF1_0.5_1                          0.012777
# .YEARWEEK                                        0.005723
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H                   0.003624
# .WEEK                                            0.003276
# .YEARMONTH                                       0.002611
# .PREC_RAIN_TOT_GF1_0.5_1-1                       0.001814
# .SEASON                                          0.000828
# .MONTH                                           0.000698
# .YEAR                                            0.000227
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2015 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.06936270480939224.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      3.159318
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        1.068800
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.513059
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.462578
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.316591
# .YEARDOY                                             0.279669
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.248770
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.214165
# TS_GF1_0.04_1_gfXG_MEAN3H                            0.207006
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.190219
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.177609
# .DOY                                                 0.140928
# TS_GF1_0.04_1_gfXG                                   0.128692
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.110379
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.094792
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.091759
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.087566
# .HOUR                                                0.072135
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                           PERM_IMPORTANCE
# .TS_GF1_0.04_1_gfXG-1                            0.063553
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                    0.061589
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                    0.054305
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                     0.052308
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                 0.052051
# SWC_GF1_0.15_1_gfXG                              0.046451
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                   0.044031
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                     0.040676
# TS_GF1_0.15_1_gfXG                               0.037593
# TS_GF1_0.15_1_gfXG_MEAN3H                        0.036620
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT         0.036142
# TIMESINCE_MGMT_SOWING_FOOTPRINT                  0.033430
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                    0.032343
# .TS_GF1_0.4_1_gfXG-1                             0.032326
# .SWC_GF1_0.15_1_gfXG-1                           0.029161
# TS_GF1_0.4_1_gfXG                                0.028439
# .TS_GF1_0.15_1_gfXG-1                            0.028310
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                   0.027626
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                      0.025059
# TS_GF1_0.4_1_gfXG_MEAN3H                         0.021874
# SWC_GF1_0.15_1_gfXG_MEAN3H                       0.021619
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18               0.015093
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12               0.013570
# .WEEK                                            0.012477
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H                   0.012278
# .YEARWEEK                                        0.007787
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24               0.007311
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6                0.005278
# PREC_RAIN_TOT_GF1_0.5_1                          0.003271
# .YEARMONTH                                       0.002626
# .PREC_RAIN_TOT_GF1_0.5_1-1                       0.001726
# .MONTH                                           0.000853
# .YEAR                                            0.000540
# .SEASON                                          0.000246
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2016 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.06362575551099303.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.706848
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.485825
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.388461
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.374835
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.286527
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.265615
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.264854
# TS_GF1_0.04_1_gfXG                                   0.197731
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                         0.191059
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.149429
# TS_GF1_0.15_1_gfXG_MEAN3H                            0.142266
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.104845
# .TS_GF1_0.04_1_gfXG-1                                0.104585
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.101893
# TS_GF1_0.04_1_gfXG_MEAN3H                            0.096934
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                        0.095507
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.079641
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.073939
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.067465
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.065715
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.064435
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                           PERM_IMPORTANCE
# TIMESINCE_MGMT_SOWING_FOOTPRINT                  0.056186
# TS_GF1_0.4_1_gfXG_MEAN3H                         0.055472
# TS_GF1_0.15_1_gfXG                               0.054392
# .HOUR                                            0.054240
# .TS_GF1_0.15_1_gfXG-1                            0.053169
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT         0.052093
# .YEARDOY                                         0.050180
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                   0.047463
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                    0.041278
# TS_GF1_0.4_1_gfXG                                0.037825
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                      0.037008
# SWC_GF1_0.15_1_gfXG                              0.035635
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                   0.033665
# .TS_GF1_0.4_1_gfXG-1                             0.031782
# .DOY                                             0.031422
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                    0.030976
# SWC_GF1_0.15_1_gfXG_MEAN3H                       0.022632
# .SWC_GF1_0.15_1_gfXG-1                           0.022054
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6                0.009660
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12               0.008103
# .WEEK                                            0.006488
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24               0.005813
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18               0.004591
# .YEARWEEK                                        0.004571
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H                   0.004136
# PREC_RAIN_TOT_GF1_0.5_1                          0.003232
# .YEARMONTH                                       0.002330
# .PREC_RAIN_TOT_GF1_0.5_1-1                       0.002117
# .YEAR                                            0.000912
# .MONTH                                           0.000698
# .SEASON                                          0.000431
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2017 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.039886883241581406.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                         0.703729
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.488201
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.388027
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.244528
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.220041
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.213341
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.212048
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.199247
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.199164
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.172938
# TS_GF1_0.4_1_gfXG                                    0.160002
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                        0.136792
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                       0.129250
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.117516
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.096218
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.091694
# TS_GF1_0.04_1_gfXG                                   0.087227
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.087200
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.078146
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.070036
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                       0.066387
# .HOUR                                                0.059388
# .TS_GF1_0.4_1_gfXG-1                                 0.056790
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.056644
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.051308
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                          0.045597
# TS_GF1_0.4_1_gfXG_MEAN3H                             0.045549
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                        0.045392
# TS_GF1_0.04_1_gfXG_MEAN3H                            0.041977
# .TS_GF1_0.04_1_gfXG-1                                0.040232
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                     PERM_IMPORTANCE
# SWC_GF1_0.15_1_gfXG                        0.034972
# .SWC_GF1_0.15_1_gfXG-1                     0.030785
# SWC_GF1_0.15_1_gfXG_MEAN3H                 0.026202
# .TS_GF1_0.15_1_gfXG_MEAN3H-12              0.024560
# TS_GF1_0.15_1_gfXG_MEAN3H                  0.020323
# .DOY                                       0.019612
# .YEARDOY                                   0.019590
# TS_GF1_0.15_1_gfXG                         0.018004
# .YEARMONTH                                 0.017799
# .TS_GF1_0.15_1_gfXG-1                      0.017165
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12         0.013514
# .YEARWEEK                                  0.013051
# .WEEK                                      0.008409
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18         0.006391
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24         0.006378
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H             0.006103
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6          0.003688
# .SEASON                                    0.003102
# .PREC_RAIN_TOT_GF1_0.5_1-1                 0.002822
# PREC_RAIN_TOT_GF1_0.5_1                    0.002526
# .MONTH                                     0.000959
# .YEAR                                      0.000106
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2018 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.05646023804089943.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                    PERM_IMPORTANCE
# TIMESINCE_MGMT_MOWING_FOOTPRINT           0.800670
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6             0.526590
# TIMESINCE_MGMT_SOWING_FOOTPRINT           0.358134
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT         0.310737
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24            0.226935
# .HOUR                                     0.149857
# .TS_GF1_0.04_1_gfXG_MEAN3H-6              0.131797
# .TS_GF1_0.4_1_gfXG_MEAN3H-24              0.112780
# .TS_GF1_0.15_1_gfXG_MEAN3H-24             0.092201
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1         0.067937
# .TS_GF1_0.04_1_gfXG_MEAN3H-24             0.063318
# .TS_GF1_0.04_1_gfXG_MEAN3H-12             0.061320
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                               PERM_IMPORTANCE
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24                   0.052045
# TS_GF1_0.04_1_gfXG                                   0.048186
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                       0.044870
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.044065
# .TS_GF1_0.04_1_gfXG-1                                0.041971
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.039737
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.038490
# TS_GF1_0.04_1_gfXG_MEAN3H                            0.036490
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                        0.033181
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.031193
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                       0.027890
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                          0.026899
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                         0.025521
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.024938
# .TS_GF1_0.15_1_gfXG-1                                0.024517
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                        0.023235
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6                    0.023054
# SWC_GF1_0.15_1_gfXG                                  0.022860
# TS_GF1_0.4_1_gfXG                                    0.021641
# .SWC_GF1_0.15_1_gfXG-1                               0.021525
# TS_GF1_0.15_1_gfXG                                   0.020962
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H                       0.020893
# .DOY                                                 0.020239
# TS_GF1_0.15_1_gfXG_MEAN3H                            0.020223
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.019368
# SWC_GF1_0.15_1_gfXG_MEAN3H                           0.017656
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12                   0.016545
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.015652
# TS_GF1_0.4_1_gfXG_MEAN3H                             0.014950
# .TS_GF1_0.4_1_gfXG-1                                 0.014373
# .YEARDOY                                             0.010903
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18                   0.009762
# .WEEK                                                0.005135
# PREC_RAIN_TOT_GF1_0.5_1                              0.003906
# .YEARWEEK                                            0.002318
# .PREC_RAIN_TOT_GF1_0.5_1-1                           0.001983
# .YEARMONTH                                           0.000754
# .MONTH                                               0.000412
# .SEASON                                              0.000227
# .YEAR                                                0.000031
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2019 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.035478618617606414.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# .DOY                                                 1.131258
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.577262
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.569153
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.494674
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.381948
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.272687
# .YEARDOY                                             0.148900
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.132536
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.127152
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                        0.116545
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.088075
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.077841
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                       0.071849
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.062418
# TS_GF1_0.15_1_gfXG                                   0.062172
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.059032
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.056101
# .HOUR                                                0.055497
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                          0.047394
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.046924
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.044151
# SWC_GF1_0.15_1_gfXG                                  0.042375
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                           PERM_IMPORTANCE
# TS_GF1_0.04_1_gfXG_MEAN3H                        0.033820
# .TS_GF1_0.04_1_gfXG-1                            0.033300
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                   0.030685
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                    0.023864
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                    0.021478
# TS_GF1_0.04_1_gfXG                               0.021456
# TS_GF1_0.15_1_gfXG_MEAN3H                        0.021071
# TS_GF1_0.4_1_gfXG                                0.019900
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                     0.019806
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT         0.018528
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                     0.017967
# .TS_GF1_0.15_1_gfXG-1                            0.016638
# .WEEK                                            0.015879
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                    0.015711
# TS_GF1_0.4_1_gfXG_MEAN3H                         0.014685
# .SWC_GF1_0.15_1_gfXG-1                           0.013902
# SWC_GF1_0.15_1_gfXG_MEAN3H                       0.013563
# .YEARWEEK                                        0.010211
# .TS_GF1_0.4_1_gfXG-1                             0.009477
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12               0.006854
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24               0.006601
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H                   0.004670
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18               0.004540
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6                0.003922
# .YEARMONTH                                       0.001837
# PREC_RAIN_TOT_GF1_0.5_1                          0.001768
# .PREC_RAIN_TOT_GF1_0.5_1-1                       0.000793
# .YEAR                                            0.000662
# .MONTH                                           0.000223
# .SEASON                                          0.000109
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2020 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.01788656593976874.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.572210
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.397807
# .DOY                                                 0.387733
# TS_GF1_0.04_1_gfXG                                   0.319855
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.282941
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                         0.219169
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.164789
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.133082
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.094996
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.092345
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.090957
# .YEARDOY                                             0.088245
# TS_GF1_0.15_1_gfXG_MEAN3H                            0.085900
# TS_GF1_0.4_1_gfXG                                    0.078657
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.073700
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.071844
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.060104
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                        0.054117
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.052954
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.051882
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.051842
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.035648
# .HOUR                                                0.032179
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                          0.026498
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                       0.026443
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.022321
# .TS_GF1_0.15_1_gfXG-1                                0.022100
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                        0.020659
# TS_GF1_0.15_1_gfXG                                   0.018975
# TS_GF1_0.04_1_gfXG_MEAN3H                            0.018722
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                     PERM_IMPORTANCE
# TS_GF1_0.4_1_gfXG_MEAN3H                   0.013297
# .TS_GF1_0.15_1_gfXG_MEAN3H-18              0.013156
# SWC_GF1_0.15_1_gfXG                        0.012965
# .TS_GF1_0.04_1_gfXG-1                      0.011461
# .TS_GF1_0.4_1_gfXG-1                       0.011272
# .YEAR                                      0.011009
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18             0.010723
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12             0.010594
# .SWC_GF1_0.15_1_gfXG-1                     0.007560
# SWC_GF1_0.15_1_gfXG_MEAN3H                 0.007487
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24         0.004648
# .WEEK                                      0.004014
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6          0.003339
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12         0.003317
# .YEARWEEK                                  0.002990
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18         0.002887
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H             0.001793
# .YEARMONTH                                 0.001565
# PREC_RAIN_TOT_GF1_0.5_1                    0.001149
# .PREC_RAIN_TOT_GF1_0.5_1-1                 0.000654
# .MONTH                                     0.000161
# .SEASON                                    0.000083
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2021 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.016189399661423763.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TS_GF1_0.15_1_gfXG_MEAN3H                            0.864580
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.735122
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.395306
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.273240
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.233844
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                         0.188218
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.121276
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.116920
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.081889
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                        0.063600
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.061638
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.054809
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.054153
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.048630
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.046248
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.039239
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.038191
# .DOY                                                 0.035873
# .YEARDOY                                             0.035266
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.033890
# .HOUR                                                0.031391
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.030088
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                       0.024653
# TS_GF1_0.04_1_gfXG                                   0.022752
# TS_GF1_0.4_1_gfXG                                    0.020448
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                        0.016568
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                     PERM_IMPORTANCE
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24             0.015646
# TS_GF1_0.04_1_gfXG_MEAN3H                  0.015439
# .TS_GF1_0.4_1_gfXG-1                       0.014345
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18             0.014156
# TS_GF1_0.15_1_gfXG                         0.012692
# .TS_GF1_0.04_1_gfXG-1                      0.012046
# SWC_GF1_0.15_1_gfXG                        0.010712
# SWC_GF1_0.15_1_gfXG_MEAN3H                 0.010581
# .TS_GF1_0.15_1_gfXG_MEAN3H-12              0.009025
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                0.008560
# TS_GF1_0.4_1_gfXG_MEAN3H                   0.007894
# .TS_GF1_0.15_1_gfXG-1                      0.007417
# .SWC_GF1_0.15_1_gfXG-1                     0.007092
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6          0.004866
# .YEARMONTH                                 0.003684
# .YEARWEEK                                  0.003613
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12         0.003060
# .WEEK                                      0.002339
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24         0.001914
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18         0.001896
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H             0.001076
# PREC_RAIN_TOT_GF1_0.5_1                    0.000865
# .PREC_RAIN_TOT_GF1_0.5_1-1                 0.000481
# .SEASON                                    0.000419
# .MONTH                                     0.000406
# .YEAR                                      0.000207
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Reducing features based on permutation importance for year 2022 ...
#
# [ FEATURE REDUCTION ] Feature reduction based on permutation importance ...
# [ FEATURE REDUCTION ] >>> Calculating feature importances (permutation importance, 5 repeats) ...
# [ FEATURE REDUCTION ] >>> Setting threshold for feature rejection to 0.016189399661423763.
#
# [ FEATURE REDUCTION ] >>> Accepted features and their importance:
#                                               PERM_IMPORTANCE
# TS_GF1_0.15_1_gfXG_MEAN3H                            0.864580
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT             0.735122
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1                    0.395306
# TIMESINCE_MGMT_MOWING_FOOTPRINT                      0.273240
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                         0.233844
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                         0.188218
# TIMESINCE_MGMT_GRAZING_FOOTPRINT                     0.121276
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT                    0.116920
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                        0.081889
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                        0.063600
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                        0.061638
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT                    0.054809
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT         0.054153
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                         0.048630
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                         0.046248
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                        0.039239
# TIMESINCE_MGMT_SOWING_FOOTPRINT                      0.038191
# .DOY                                                 0.035873
# .YEARDOY                                             0.035266
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                        0.033890
# .HOUR                                                0.031391
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                         0.030088
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                       0.024653
# TS_GF1_0.04_1_gfXG                                   0.022752
# TS_GF1_0.4_1_gfXG                                    0.020448
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                        0.016568
#
# [ FEATURE REDUCTION ] >>> Rejected features and their importance:
#                                     PERM_IMPORTANCE
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24             0.015646
# TS_GF1_0.04_1_gfXG_MEAN3H                  0.015439
# .TS_GF1_0.4_1_gfXG-1                       0.014345
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18             0.014156
# TS_GF1_0.15_1_gfXG                         0.012692
# .TS_GF1_0.04_1_gfXG-1                      0.012046
# SWC_GF1_0.15_1_gfXG                        0.010712
# SWC_GF1_0.15_1_gfXG_MEAN3H                 0.010581
# .TS_GF1_0.15_1_gfXG_MEAN3H-12              0.009025
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                0.008560
# TS_GF1_0.4_1_gfXG_MEAN3H                   0.007894
# .TS_GF1_0.15_1_gfXG-1                      0.007417
# .SWC_GF1_0.15_1_gfXG-1                     0.007092
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6          0.004866
# .YEARMONTH                                 0.003684
# .YEARWEEK                                  0.003613
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12         0.003060
# .WEEK                                      0.002339
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24         0.001914
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18         0.001896
# PREC_RAIN_TOT_GF1_0.5_1_MEAN3H             0.001076
# PREC_RAIN_TOT_GF1_0.5_1                    0.000865
# .PREC_RAIN_TOT_GF1_0.5_1-1                 0.000481
# .SEASON                                    0.000419
# .MONTH                                     0.000406
# .YEAR                                      0.000207
# [ FEATURE REDUCTION ] >>> Removing rejected features from model data ...
# ---
# Finished reducing features based on permutation importance for all years.
# List of features after reduction: ['.DOY', '.HOUR', '.SWC_GF1_0.15_1_gfXG_MEAN3H-12', '.SWC_GF1_0.15_1_gfXG_MEAN3H-18', '.SWC_GF1_0.15_1_gfXG_MEAN3H-24', '.SWC_GF1_0.15_1_gfXG_MEAN3H-6', '.TS_GF1_0.04_1_gfXG-1', '.TS_GF1_0.04_1_gfXG_MEAN3H-12', '.TS_GF1_0.04_1_gfXG_MEAN3H-18', '.TS_GF1_0.04_1_gfXG_MEAN3H-24', '.TS_GF1_0.04_1_gfXG_MEAN3H-6', '.TS_GF1_0.15_1_gfXG-1', '.TS_GF1_0.15_1_gfXG_MEAN3H-12', '.TS_GF1_0.15_1_gfXG_MEAN3H-18', '.TS_GF1_0.15_1_gfXG_MEAN3H-24', '.TS_GF1_0.15_1_gfXG_MEAN3H-6', '.TS_GF1_0.4_1_gfXG-1', '.TS_GF1_0.4_1_gfXG_MEAN3H-12', '.TS_GF1_0.4_1_gfXG_MEAN3H-18', '.TS_GF1_0.4_1_gfXG_MEAN3H-24', '.TS_GF1_0.4_1_gfXG_MEAN3H-6', '.YEARDOY', 'SWC_GF1_0.15_1_gfXG', 'TIMESINCE_MGMT_FERT_MIN_FOOTPRINT', 'TIMESINCE_MGMT_FERT_ORG_FOOTPRINT', 'TIMESINCE_MGMT_GRAZING_FOOTPRINT', 'TIMESINCE_MGMT_MOWING_FOOTPRINT', 'TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT', 'TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT', 'TIMESINCE_MGMT_SOWING_FOOTPRINT', 'TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1', 'TS_GF1_0.04_1_gfXG', 'TS_GF1_0.04_1_gfXG_MEAN3H', 'TS_GF1_0.15_1_gfXG', 'TS_GF1_0.15_1_gfXG_MEAN3H', 'TS_GF1_0.4_1_gfXG', 'TS_GF1_0.4_1_gfXG_MEAN3H'].
# Each feature was selected in at least one year.
# ---
# [neighboring_years] Assigned [2012, 2013, 2014] to data pool for 2012.
# ...
# >>> Collecting results for final model ...
# >>> Filling 30817 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2013 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2012-01-18 10:45:00 and 2014-12-31 21:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2013 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 30817 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2014 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2013-01-01 05:15:00 and 2015-12-31 20:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2014 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52560 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 32486 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2015 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2014-01-01 01:15:00 and 2016-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2015 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 34708 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2015-01-01 02:45:00 and 2017-03-11 13:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 40362 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-01 02:45:00 and 2018-12-31 20:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 44824 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 20:45:00 and 2019-12-31 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52560 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 43533 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-02-05 15:45:00 and 2020-12-31 18:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 37882 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 06:15:00 and 2021-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 32055 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-01 02:15:00 and 2022-07-05 18:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 34938 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-01 02:15:00 and 2022-07-05 18:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target FN2O_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target FN2O_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting FN2O_L3.1_L3.3_CUT_84_QCF ...
# predicted 52608 records.2O_L3.1_L3.3_CUT_84_QCF where all features are available ...
# >>> Collecting results for final model ...
# >>> Filling 34938 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable FN2O_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in FN2O_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2012 ...
# Collecting results for 2013 ...
# Collecting results for 2014 ...
# Collecting results for 2015 ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# CPU times: total: 16h 55s
# Wall time: 3h 51min 4s

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
results = fpc.get_data(verbose=1)
results
# Out:
# NEW VARIABLES FROM FLUX PROCESSING CHAIN:
# ++ FLAG_L2_FN2O_MISSING_TEST
# ++ FLAG_L2_FN2O_SSITC_TEST
# ++ FLAG_L2_FN2O_COMPLETENESS_TEST
# ++ FLAG_L2_FN2O_SCF_TEST
# ++ FLAG_L2_FN2O_N2O_VM97_SPIKE_HF_TEST
# ++ FLAG_L2_FN2O_N2O_VM97_AMPLITUDE_RESOLUTION_HF_TEST
# ++ FLAG_L2_FN2O_N2O_VM97_DROPOUT_TEST
# ++ FLAG_L2_FN2O_VM97_AOA_HF_TEST
# ++ SUM_L2_FN2O_HARDFLAGS
# ++ SUM_L2_FN2O_SOFTFLAGS
# ++ SUM_L2_FN2O_FLAGS
# ++ FLAG_L2_FN2O_QCF
# ++ FN2O_L2_QCF
# ++ FN2O_L2_QCF0
# ++ SN2O_SINGLE_gfRMED_L3.1
# ++ FLAG_SN2O_SINGLE_gfRMED_L3.1_ISFILLED
# ++ FN2O_L3.1
# ++ FN2O_L3.1_QCF
# ++ FN2O_L3.1_QCF0
# ++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ABSLIM_TEST
# ++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_ZSCOREROLLING_TEST
# ++ FLAG_L3.2_FN2O_L3.1_QCF_OUTLIER_LOCALSD_TEST
# ++ SUM_L3.2_FN2O_L3.1_HARDFLAGS
# ++ SUM_L3.2_FN2O_L3.1_SOFTFLAGS
# ++ SUM_L3.2_FN2O_L3.1_FLAGS
# ++ FLAG_L3.2_FN2O_L3.1_QCF
# ++ FN2O_L3.1_L3.2_QCF
# ++ FN2O_L3.1_L3.2_QCF0
# ++ FLAG_L3.3_CUT_16_FN2O_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_16_FN2O_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_16_FN2O_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_16_FN2O_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_16_FN2O_L3.1_QCF
# ++ FN2O_L3.1_L3.3_CUT_16_QCF
# ++ FN2O_L3.1_L3.3_CUT_16_QCF0
# ++ FLAG_L3.3_CUT_50_FN2O_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_50_FN2O_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_50_FN2O_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_50_FN2O_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_50_FN2O_L3.1_QCF
# ++ FN2O_L3.1_L3.3_CUT_50_QCF
# ++ FN2O_L3.1_L3.3_CUT_50_QCF0
# ++ FLAG_L3.3_CUT_84_FN2O_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_84_FN2O_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_84_FN2O_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_84_FN2O_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_84_FN2O_L3.1_QCF
# ++ FN2O_L3.1_L3.3_CUT_84_QCF
# ++ FN2O_L3.1_L3.3_CUT_84_QCF0
# ++ FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# ++ FLAG_FN2O_L3.1_L3.3_CUT_16_QCF_gfRF_ISFILLED
# ++ FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# ++ FLAG_FN2O_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED
# ++ FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# ++ FLAG_FN2O_L3.1_L3.3_CUT_84_QCF_gfRF_ISFILLED
# No variables in input data were overwritten, only new variables added.
#                      .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-18  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-24  .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-6  .SWC_GF1_0.15_1_gfXG_MEAN3H-12  .SWC_GF1_0.15_1_gfXG_MEAN3H-18  ...  FN2O_L3.1_L3.3_CUT_16_QCF_gfRF  FLAG_FN2O_L3.1_L3.3_CUT_16_QCF_gfRF_ISFILLED  FN2O_L3.1_L3.3_CUT_50_QCF_gfRF  FLAG_FN2O_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED  FN2O_L3.1_L3.3_CUT_84_QCF_gfRF  FLAG_FN2O_L3.1_L3.3_CUT_84_QCF_gfRF_ISFILLED
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                    ...
# 2012-01-01 00:15:00                             0.57070                             1.00970                             1.53650                            0.72435                       47.686902                       47.485823  ...                        0.615439                                             1                        1.692910                                             1                        1.303387                                             1
# 2012-01-01 00:45:00                             0.65850                             0.85605                             1.58040                            0.70240                       47.700829                       47.515553  ...                        0.357831                                             1                        0.479658                                             1                        0.340526                                             1
# 2012-01-01 01:15:00                             0.59265                             0.81215                             1.55845                            0.87800                       47.711383                       47.553562  ...                        0.299795                                             1                        0.349175                                             1                        0.300821                                             1
# 2012-01-01 01:45:00                             0.57070                             0.70240                             1.38285                            0.92190                       47.721239                       47.595919  ...                        0.547467                                             1                        1.663710                                             1                        1.312394                                             1
# 2012-01-01 02:15:00                             0.57070                             0.68045                             1.33895                            0.81215                       47.730956                       47.639129  ...                        0.560168                                             1                        1.668482                                             1                        1.311202                                             1
# ...                                                 ...                                 ...                                 ...                                ...                             ...                             ...  ...                             ...                                           ...                             ...                                           ...                             ...                                           ...
# 2022-12-31 21:45:00                             0.00000                             0.00000                             0.00000                            0.00000                       40.171948                       40.264608  ...                        2.700377                                             1                        1.951956                                             1                        2.465051                                             1
# 2022-12-31 22:15:00                             0.00000                             0.00000                             0.00000                            0.00000                       40.159655                       40.246906  ...                        2.706764                                             1                        1.952504                                             1                        2.474936                                             1
# 2022-12-31 22:45:00                             0.00000                             0.00000                             0.00000                            0.00000                       40.148197                       40.229251  ...                        2.706721                                             1                        1.947602                                             1                        2.470965                                             1
# 2022-12-31 23:15:00                             0.00000                             0.00000                             0.00000                            0.00000                       40.136638                       40.213242  ...                        2.674002                                             1                        1.946745                                             1                        2.466969                                             1
# 2022-12-31 23:45:00                             0.00000                             0.00000                             0.00000                            0.00000                       40.124632                       40.198751  ...                        2.659807                                             1                        1.936364                                             1                        2.459216                                             1
#
# [192864 rows x 595 columns]

# %% [markdown]
# ## Model scores

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.width', 9999)
fpc.report_gapfilling_model_scores()
# Out:
# MODEL SCORES (random_forest): CUT_16
#             2012       2013       2014       2015       2016       2017       2018       2019       2020       2021       2022
# mae     0.631689   0.631689   0.474404   0.429994   0.355020   0.309914   0.285838   0.287608   0.322379   0.305467   0.305467
# medae   0.260654   0.260654   0.193890   0.160075   0.116964   0.082083   0.094991   0.085666   0.094360   0.094417   0.094417
# mse     1.867257   1.867257   0.985679   0.959762   0.866653   0.747376   0.516506   0.758962   0.919253   0.836238   0.836238
# rmse    1.366476   1.366476   0.992814   0.979674   0.930942   0.864509   0.718683   0.871185   0.958777   0.914460   0.914460
# mape    1.948598   1.948598   5.668236   1.674938   1.579036   1.066937   0.829590   0.878946   1.072120   1.121189   1.121189
# maxe   35.607357  35.607357  25.904347  24.297394  32.078152  29.005165  15.873261  47.358726  50.456938  37.073567  37.073567
# r2      0.883507   0.883507   0.695930   0.671522   0.641760   0.674595   0.732303   0.815743   0.846153   0.872341   0.872341
#
# MODEL SCORES (random_forest): CUT_50
#             2012       2013       2014       2015       2016       2017       2018       2019       2020       2021       2022
# mae     0.649477   0.649477   0.488287   0.439382   0.359715   0.310489   0.281973   0.269617   0.309154   0.300858   0.300858
# medae   0.266103   0.266103   0.196494   0.160704   0.117078   0.080782   0.091184   0.083687   0.092776   0.092900   0.092900
# mse     2.080972   2.080972   1.135190   1.010657   0.836868   0.821793   0.681233   0.556114   0.794981   0.761668   0.761668
# rmse    1.442557   1.442557   1.065453   1.005314   0.914805   0.906528   0.825369   0.745731   0.891617   0.872736   0.872736
# mape    1.327701   1.327701   2.679346   1.980685   1.644601   0.973703   0.762953   0.879496   0.945916   1.002547   1.002547
# maxe   40.617914  40.617914  33.877877  24.749773  32.978054  21.615604  20.165791  29.155953  33.375716  27.596001  27.596001
# r2      0.878583   0.878583   0.669274   0.673917   0.670564   0.661037   0.638666   0.871441   0.873976   0.890714   0.890714
#
# MODEL SCORES (random_forest): CUT_84
#             2012       2013       2014       2015       2016       2017      2018       2019       2020       2021       2022
# mae     0.663638   0.663638   0.507871   0.458860   0.374575   0.328921  0.269978   0.262627   0.306457   0.293761   0.293761
# medae   0.275281   0.275281   0.203046   0.167081   0.117779   0.082234  0.090338   0.082687   0.088285   0.088247   0.088247
# mse     1.980592   1.980592   1.167313   1.200973   0.964277   1.094405  0.436975   0.533472   0.849848   0.753621   0.753621
# rmse    1.407335   1.407335   1.080423   1.095889   0.981976   1.046138  0.661041   0.730391   0.921872   0.868114   0.868114
# mape    9.483291   9.483291   4.922209   1.763177   2.119524   0.928201  0.698897   0.825755   0.814814   0.936860   0.936860
# maxe   38.612599  38.612599  19.378430  32.175347  30.419089  30.739519  9.875578  21.058016  33.386473  24.304152  24.304152
# r2      0.894440   0.894440   0.694978   0.650407   0.659147   0.595297  0.764066   0.888857   0.877385   0.901944   0.901944

# %%
fpc.report_gapfilling_feature_importances()
# Out:
# FEATURE IMPORTANCES (random_forest): CUT_16
# YEAR                                              2012      2013      2014      2015      2016      2017      2018      2019      2020      2021      2022
# FEATURE
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT      0.649982  0.649982  0.033688  0.029667  0.038912  0.056235  0.030181  0.016088  0.551948  0.796379  0.796379
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT  0.292845  0.292845  0.139636  0.231212  0.063863  0.291891  0.023823  0.329487  0.059978  0.055270  0.055270
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                0.197908  0.197908  0.080486  0.483411  0.378113  0.241779  0.281805  0.071610  0.028142  0.019665  0.019665
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT             0.146019  0.146019  0.530933  0.279384  0.237263  0.181627  0.331475  0.250272  0.119456  0.101151  0.101151
# TIMESINCE_MGMT_MOWING_FOOTPRINT               0.143789  0.143789  0.314920  3.344078  0.618106  0.521070  1.002794  0.048331  0.019533  0.277828  0.277828
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                 0.078593  0.078593  0.067911  1.150833  0.358863  0.442749  0.088189  0.120003  0.030118  0.032694  0.032694
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                  0.071003  0.071003  0.028381  0.079472  0.088334  0.193666  0.034999  0.071263  0.050127  0.030420  0.030420
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                0.067112  0.067112  0.034848  0.026472  0.042730  0.054289  0.055384  0.026551  0.011168  0.017087  0.017087
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1             0.056828  0.056828  0.109318  0.085778  0.058374  0.095854  0.084012  0.062111  0.274168  0.382098  0.382098
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                  0.052028  0.052028  0.044486  0.090814  0.138376  0.245924  0.171178  0.609462  0.171373  0.065432  0.065432
# SWC_GF1_0.15_1_gfXG                           0.044428  0.044428  0.135361  0.083667  0.045501  0.097577  0.074864  0.054487  0.021088  0.021048  0.021048
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT             0.036569  0.036569  0.270259  0.184609  0.068290  0.093392  0.046034  0.124452  0.080358  0.049199  0.049199
# .TS_GF1_0.04_1_gfXG-1                         0.033693  0.033693  0.039172  0.057385  0.087880  0.042580  0.042007  0.027049  0.011172  0.011353  0.011353
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                  0.032190  0.032190  0.042727  0.033741  0.056884  0.079716  0.037664  0.017583  0.400119  0.254328  0.254328
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                 0.031163  0.031163  0.140879  0.186770  0.340286  0.233692  0.058986  0.063971  0.048867  0.042985  0.042985
# TS_GF1_0.04_1_gfXG                            0.030644  0.030644  0.080609  0.124386  0.219391  0.094621  0.049168  0.021139  0.321426  0.021356  0.021356
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                 0.027596  0.027596  0.165978  0.177123  0.279446  0.123907  0.058875  0.038402  0.072473  0.100757  0.100757
# TIMESINCE_MGMT_SOWING_FOOTPRINT               0.027431  0.027431  0.027113  0.028020  0.044479  0.073547  0.319683  0.043786  0.081650  0.048376  0.048376
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                  0.027393  0.027393  0.151157  0.474708  0.432801  0.143676  0.110978  0.446039  0.062545  0.048024  0.048024
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                 0.027238  0.027238  0.137010  0.085745  0.055355  0.057213  0.046915  0.018186  0.089261  0.070159  0.070159
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                 0.022055  0.022055  0.041219  0.050744  0.033558  0.023079  0.032309  0.019175  0.020311  0.009717  0.009717
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                 0.021353  0.021353  0.040647  0.053598  0.075042  0.054687  0.023686  0.015676  0.013408  0.014368  0.014368
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                0.021269  0.021269  0.052527  0.045387  0.034953  0.113282  0.040269  0.079529  0.013992  0.032915  0.032915
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                   0.019504  0.019504  0.022991  0.021085  0.035161  0.053107  0.025472  0.042753  0.023763  0.007445  0.007445
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                  0.019349  0.019349  0.054333  0.048823  0.158489  0.694006  0.027606  0.014848  0.206027  0.227034  0.227034
# TS_GF1_0.04_1_gfXG_MEAN3H                     0.019338  0.019338  0.059320  0.193389  0.081563  0.041289  0.038418  0.030043  0.018429  0.014620  0.014620
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                 0.018766  0.018766  0.058201  0.045013  0.031066  0.193630  0.968115  0.128201  0.060384  0.079237  0.079237
# .TS_GF1_0.4_1_gfXG-1                          0.017299  0.017299  0.022989  0.027695  0.021787  0.055494  0.011623  0.007817  0.011625  0.014954  0.014954
# .HOUR                                         0.016537  0.016537  0.057480  0.056996  0.039964  0.047003  0.127354  0.041891  0.028043  0.026195  0.026195
# TS_GF1_0.4_1_gfXG                             0.016140  0.016140  0.030539  0.024572  0.036932  0.147372  0.020642  0.016914  0.093783  0.018531  0.018531
# TIMESINCE_MGMT_GRAZING_FOOTPRINT              0.013403  0.013403  0.168882  0.046468  0.078436  0.228311  0.011334  0.665995  0.123891  0.174874  0.174874
# TS_GF1_0.4_1_gfXG_MEAN3H                      0.013191  0.013191  0.017148  0.018951  0.058852  0.050990  0.013672  0.009420  0.014757  0.007383  0.007383
# .DOY                                          0.011004  0.011004  0.033785  0.197473  0.037887  0.018468  0.022233  1.040124  0.375546  0.039107  0.039107
# TS_GF1_0.15_1_gfXG                            0.010656  0.010656  0.027352  0.036346  0.049271  0.019567  0.021014  0.048176  0.016152  0.014292  0.014292
# TS_GF1_0.15_1_gfXG_MEAN3H                     0.010369  0.010369  0.029053  0.028886  0.120631  0.019630  0.016489  0.016852  0.082414  1.045697  1.045697
# .TS_GF1_0.15_1_gfXG-1                         0.008856  0.008856  0.026629  0.026848  0.041194  0.019340  0.022943  0.013399  0.020820  0.007129  0.007129
# .YEARDOY                                      0.005783  0.005783  0.014245  0.239305  0.037494  0.022650  0.010491  0.154634  0.096723  0.053918  0.053918
#
# FEATURE IMPORTANCES (random_forest): CUT_50
# YEAR                                              2012      2013      2014      2015      2016      2017      2018      2019      2020      2021      2022
# FEATURE
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT  0.977351  0.977351  0.110245  0.276321  0.084819  0.157573  0.016330  0.291479  0.035603  0.047829  0.047829
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT      0.407898  0.407898  0.039254  0.032893  0.028777  0.133727  0.033730  0.041949  0.657669  0.726147  0.726147
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                0.267136  0.267136  0.080051  0.206068  0.304460  0.270298  0.147237  0.084176  0.023186  0.015782  0.015782
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                  0.206910  0.206910  0.028331  0.074511  0.080649  0.129814  0.020092  0.024317  0.036234  0.011867  0.011867
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT             0.138228  0.138228  0.499053  0.265632  0.189486  0.391914  0.173228  0.387560  0.141977  0.155168  0.155168
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1             0.061848  0.061848  0.089383  0.075335  0.072356  0.078200  0.078738  0.101508  0.210832  0.348706  0.348706
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                  0.061099  0.061099  0.047231  0.040108  0.142790  0.109943  0.043092  0.630473  0.323709  0.069387  0.069387
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                   0.059826  0.059826  0.019260  0.021227  0.033542  0.065616  0.022080  0.026431  0.013250  0.007430  0.007430
# TIMESINCE_MGMT_MOWING_FOOTPRINT               0.054534  0.054534  0.247044  2.023588  2.617721  0.294935  0.545036  0.061483  0.017113  0.118146  0.118146
# SWC_GF1_0.15_1_gfXG                           0.047793  0.047793  0.094970  0.089378  0.054808  0.116404  0.091916  0.036356  0.018612  0.028479  0.028479
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                 0.046969  0.046969  0.128225  0.686489  1.298904  0.126528  0.156762  0.080792  0.062587  0.035471  0.035471
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                  0.042179  0.042179  0.184751  0.454865  0.253167  0.094484  0.153411  0.237232  0.035790  0.017184  0.017184
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                 0.039462  0.039462  0.099429  0.087578  0.047449  0.041569  0.050028  0.023702  0.073674  0.047434  0.047434
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                 0.038939  0.038939  0.250286  0.688243  1.354623  0.073117  0.036398  0.050794  0.063766  0.027593  0.027593
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                  0.035958  0.035958  0.038494  0.034188  0.048879  0.049324  0.028331  0.026248  0.108465  0.340592  0.340592
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                 0.035599  0.035599  0.110216  0.127841  0.352455  0.086951  0.059503  0.020679  0.068387  0.050861  0.050861
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT             0.033462  0.033462  0.197382  0.120785  0.122496  0.036324  0.028548  0.150959  0.078389  0.053545  0.053545
# TS_GF1_0.04_1_gfXG_MEAN3H                     0.032188  0.032188  0.058028  0.066459  0.090013  0.064279  0.060626  0.070993  0.017021  0.020067  0.020067
# TS_GF1_0.4_1_gfXG_MEAN3H                      0.030327  0.030327  0.016653  0.019440  0.037748  0.039471  0.012923  0.015302  0.010216  0.005086  0.005086
# TS_GF1_0.04_1_gfXG                            0.028909  0.028909  0.066526  0.086914  0.144174  0.091829  0.022786  0.017688  0.208656  0.224636  0.224636
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                 0.025571  0.025571  0.030563  0.075976  0.112596  0.052042  0.036424  0.010395  0.011572  0.008668  0.008668
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                 0.021478  0.021478  0.048179  0.076609  0.025469  0.183245  0.499986  0.153938  0.028027  0.046646  0.046646
# .TS_GF1_0.04_1_gfXG-1                         0.021299  0.021299  0.037374  0.054032  0.136868  0.039913  0.064562  0.016842  0.012396  0.015842  0.015842
# .HOUR                                         0.020648  0.020648  0.072619  0.071278  0.062197  0.046303  0.062918  0.046546  0.039102  0.034144  0.034144
# TIMESINCE_MGMT_GRAZING_FOOTPRINT              0.018353  0.018353  0.057180  0.045571  0.055262  0.123977  0.010025  0.328542  0.135895  0.248456  0.248456
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                0.017980  0.017980  0.056436  0.029382  0.028767  0.317719  0.050270  0.033946  0.014249  0.044484  0.044484
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                0.017764  0.017764  0.034842  0.034049  0.025247  0.033988  0.044064  0.015661  0.016502  0.011961  0.011961
# TIMESINCE_MGMT_SOWING_FOOTPRINT               0.017041  0.017041  0.039307  0.034965  0.028738  0.143135  0.539116  0.048287  0.059444  0.099946  0.099946
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                 0.015039  0.015039  0.030184  0.041804  0.034539  0.021020  0.021235  0.009810  0.022603  0.014619  0.014619
# TS_GF1_0.4_1_gfXG                             0.013672  0.013672  0.025288  0.024210  0.087558  0.075564  0.013883  0.014014  0.029771  0.167717  0.167717
# .TS_GF1_0.4_1_gfXG-1                          0.013333  0.013333  0.025569  0.024564  0.138930  0.035462  0.010652  0.007870  0.010116  0.030205  0.030205
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                  0.012627  0.012627  0.030134  0.039822  0.101731  0.685013  0.018694  0.010677  0.260284  0.237049  0.237049
# TS_GF1_0.15_1_gfXG                            0.011514  0.011514  0.029711  0.042640  0.039328  0.027225  0.021838  0.019645  0.030788  0.012392  0.012392
# TS_GF1_0.15_1_gfXG_MEAN3H                     0.009767  0.009767  0.026492  0.029276  0.121401  0.021474  0.041745  0.008237  0.227995  0.635540  0.635540
# .DOY                                          0.009147  0.009147  0.032281  0.108663  0.021478  0.020256  0.038946  0.568413  0.280992  0.014981  0.014981
# .YEARDOY                                      0.007320  0.007320  0.020136  0.235256  0.065267  0.043362  0.033766  0.142234  0.053267  0.016558  0.016558
#
# FEATURE IMPORTANCES (random_forest): CUT_84
# YEAR                                              2012      2013      2014      2015      2016      2017      2018      2019      2020      2021      2022
# FEATURE
# TIMESINCE_MGMT_PESTICIDE_HERBICIDE_FOOTPRINT  1.190245  1.190245  0.096771  0.182555  0.058573  0.059329  0.026227  0.160268  0.026606  0.025011  0.025011
# .TS_GF1_0.4_1_gfXG_MEAN3H-12                  0.282530  0.282530  0.029783  0.062955  0.039488  0.167193  0.046833  0.016858  0.016329  0.011988  0.011988
# .SWC_GF1_0.15_1_gfXG_MEAN3H-24                0.267092  0.267092  0.083494  0.101385  0.091011  0.042050  0.139897  0.183190  0.020742  0.018153  0.018153
# TIMESINCE_MGMT_SOILCULTIVATION_FOOTPRINT      0.180617  0.180617  0.031353  0.046025  0.049618  0.058050  0.032934  0.034278  0.651626  0.587455  0.587455
# TIMESINCE_MGMT_FERT_ORG_FOOTPRINT             0.137856  0.137856  0.552481  0.296070  1.232925  1.130327  0.258728  0.455136  0.092388  0.081357  0.081357
# .TS_GF1_0.4_1_gfXG_MEAN3H-18                  0.077547  0.077547  0.029000  0.037568  0.027262  0.025239  0.054111  0.018961  0.305051  0.093461  0.093461
# .TS_GF1_0.4_1_gfXG_MEAN3H-24                  0.068334  0.068334  0.036769  0.046800  0.030461  0.042205  0.075532  0.950136  0.310816  0.040659  0.040659
# .TS_GF1_0.04_1_gfXG_MEAN3H-12                 0.064520  0.064520  0.366190  0.883054  1.376143  0.244415  0.083274  0.183779  0.038411  0.031508  0.031508
# SWC_GF1_0.15_1_gfXG                           0.062189  0.062189  0.119663  0.085850  0.039451  0.072562  0.093431  0.041682  0.021911  0.016538  0.016538
# .TS_GF1_0.15_1_gfXG_MEAN3H-24                 0.058861  0.058861  0.086537  0.116401  0.385240  0.093321  0.214782  0.040034  0.046333  0.076950  0.076950
# TIMESINCE_PREC_RAIN_TOT_GF1_0.5_1             0.047671  0.047671  0.094548  0.070597  0.075647  0.123320  0.103771  0.294822  0.217526  0.740043  0.740043
# TIMESINCE_MGMT_FERT_MIN_FOOTPRINT             0.042622  0.042622  0.397390  0.264069  0.076612  0.028172  0.034284  0.114899  0.105803  0.060809  0.060809
# .TS_GF1_0.4_1_gfXG_MEAN3H-6                   0.040885  0.040885  0.021717  0.023404  0.058731  0.026355  0.020220  0.033636  0.012551  0.006008  0.006008
# TIMESINCE_MGMT_MOWING_FOOTPRINT               0.037695  0.037695  0.265929  0.423940  0.818565  0.261191  0.653167  0.049905  0.014303  0.101027  0.101027
# .TS_GF1_0.04_1_gfXG_MEAN3H-6                  0.033867  0.033867  0.125850  0.172085  0.199136  0.070902  0.097154  0.389337  0.031770  0.026695  0.026695
# .TS_GF1_0.04_1_gfXG_MEAN3H-18                 0.033034  0.033034  0.061222  0.059091  0.063038  0.050138  0.035576  0.024833  0.065539  0.040605  0.040605
# TS_GF1_0.04_1_gfXG                            0.032984  0.032984  0.070982  0.045363  0.152973  0.033256  0.037285  0.020131  0.141205  0.060617  0.060617
# .HOUR                                         0.028566  0.028566  0.090659  0.087999  0.080749  0.052567  0.116312  0.069444  0.040179  0.043811  0.043811
# .TS_GF1_0.15_1_gfXG_MEAN3H-18                 0.024969  0.024969  0.026183  0.041019  0.096290  0.026718  0.021451  0.013368  0.010020  0.008436  0.008436
# .TS_GF1_0.04_1_gfXG_MEAN3H-24                 0.023076  0.023076  0.086690  0.083886  0.094556  0.089801  0.121725  0.023601  0.062825  0.046055  0.046055
# .TS_GF1_0.15_1_gfXG_MEAN3H-12                 0.020372  0.020372  0.028943  0.028907  0.026858  0.018148  0.047471  0.010872  0.013356  0.009956  0.009956
# .SWC_GF1_0.15_1_gfXG_MEAN3H-18                0.018202  0.018202  0.038556  0.035937  0.022721  0.032146  0.048446  0.073743  0.008355  0.074892  0.074892
# TS_GF1_0.04_1_gfXG_MEAN3H                     0.017484  0.017484  0.049993  0.033002  0.061458  0.047625  0.032024  0.042410  0.023439  0.008946  0.008946
# TS_GF1_0.4_1_gfXG_MEAN3H                      0.017291  0.017291  0.014169  0.015611  0.085346  0.016863  0.025412  0.016242  0.005766  0.006481  0.006481
# .SWC_GF1_0.15_1_gfXG_MEAN3H-12                0.017214  0.017214  0.037880  0.028451  0.025566  0.052551  0.035593  0.034448  0.008718  0.180367  0.180367
# .TS_GF1_0.15_1_gfXG_MEAN3H-6                  0.017207  0.017207  0.022021  0.034535  0.040138  0.596090  0.049504  0.014603  0.576815  0.793864  0.793864
# .SWC_GF1_0.15_1_gfXG_MEAN3H-6                 0.016323  0.016323  0.037258  0.026457  0.019592  0.084678  0.834205  0.120086  0.046444  0.040429  0.040429
# .DOY                                          0.014767  0.014767  0.034068  0.047436  0.035945  0.032804  0.092208  0.246542  0.343322  0.020238  0.020238
# TIMESINCE_MGMT_SOWING_FOOTPRINT               0.013709  0.013709  0.029136  0.047897  0.063178  0.083611  1.170229  0.039830  0.139347  0.156685  0.156685
# .TS_GF1_0.04_1_gfXG-1                         0.013513  0.013513  0.040881  0.030032  0.086591  0.020051  0.048299  0.014130  0.011616  0.006883  0.006883
# TS_GF1_0.15_1_gfXG_MEAN3H                     0.013490  0.013490  0.037795  0.030235  0.051686  0.019783  0.039933  0.026652  0.089399  0.156118  0.156118
# TIMESINCE_MGMT_GRAZING_FOOTPRINT              0.013255  0.013255  0.246380  0.062554  0.503482  0.117882  0.014239  0.172853  0.124643  0.133771  0.133771
# TS_GF1_0.4_1_gfXG                             0.010803  0.010803  0.025283  0.027134  0.023684  0.026575  0.017487  0.013467  0.149715  0.109397  0.109397
# .TS_GF1_0.4_1_gfXG-1                          0.009027  0.009027  0.022021  0.021138  0.038082  0.030634  0.015867  0.009636  0.011762  0.034712  0.034712
# .YEARDOY                                      0.007396  0.007396  0.046778  0.103277  0.047146  0.041883  0.014392  0.051299  0.047382  0.020891  0.020891
# .PREC_RAIN_TOT_GF1_0.5_1_MEAN3H-12            0.001985  0.001985  0.016410  0.010880  0.006739  0.012743  0.071407  0.012598  0.004395  0.005866  0.005866
# .MONTH                                        0.000195  0.000195  0.000558  0.000607  0.000633  0.000629  0.000827  0.006250  0.000325  0.046189  0.046189

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2012: random_forest used data from [2012, 2013, 2014] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2013: random_forest used data from [2012, 2013, 2014] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2014: random_forest used data from [2013, 2014, 2015] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2015: random_forest used data from [2014, 2015, 2016] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2016: random_forest used data from [2015, 2016, 2017] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2017: random_forest used data from [2016, 2017, 2018] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2018: random_forest used data from [2017, 2018, 2019] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2019: random_forest used data from [2018, 2019, 2020] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2020: random_forest used data from [2019, 2020, 2021] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2021: random_forest used data from [2020, 2021, 2022] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2022: random_forest used data from [2020, 2021, 2022] for gap-filling FN2O_L3.1_L3.3_CUT_16_QCF and producing --> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# 2012: random_forest used data from [2012, 2013, 2014] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2013: random_forest used data from [2012, 2013, 2014] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2014: random_forest used data from [2013, 2014, 2015] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2015: random_forest used data from [2014, 2015, 2016] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2016: random_forest used data from [2015, 2016, 2017] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2017: random_forest used data from [2016, 2017, 2018] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2018: random_forest used data from [2017, 2018, 2019] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2019: random_forest used data from [2018, 2019, 2020] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2020: random_forest used data from [2019, 2020, 2021] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2021: random_forest used data from [2020, 2021, 2022] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2022: random_forest used data from [2020, 2021, 2022] for gap-filling FN2O_L3.1_L3.3_CUT_50_QCF and producing --> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# 2012: random_forest used data from [2012, 2013, 2014] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2013: random_forest used data from [2012, 2013, 2014] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2014: random_forest used data from [2013, 2014, 2015] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2015: random_forest used data from [2014, 2015, 2016] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2016: random_forest used data from [2015, 2016, 2017] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2017: random_forest used data from [2016, 2017, 2018] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2018: random_forest used data from [2017, 2018, 2019] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2019: random_forest used data from [2018, 2019, 2020] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2020: random_forest used data from [2019, 2020, 2021] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2021: random_forest used data from [2020, 2021, 2022] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF
# 2022: random_forest used data from [2020, 2021, 2022] for gap-filling FN2O_L3.1_L3.3_CUT_84_QCF and producing --> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# random_forest (CUT_16): FN2O_L3.1_L3.3_CUT_16_QCF -> FN2O_L3.1_L3.3_CUT_16_QCF_gfRF
# random_forest (CUT_50): FN2O_L3.1_L3.3_CUT_50_QCF -> FN2O_L3.1_L3.3_CUT_50_QCF_gfRF
# random_forest (CUT_84): FN2O_L3.1_L3.3_CUT_84_QCF -> FN2O_L3.1_L3.3_CUT_84_QCF_gfRF

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['FN2O_L3.1_L3.3_CUT_16_QCF_gfRF',
#  'FN2O_L3.1_L3.3_CUT_50_QCF_gfRF',
#  'FN2O_L3.1_L3.3_CUT_84_QCF_gfRF']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      FN2O_L3.1_L3.3_CUT_16_QCF_gfRF  FN2O_L3.1_L3.3_CUT_50_QCF_gfRF  FN2O_L3.1_L3.3_CUT_84_QCF_gfRF  FN2O_L3.1_L3.3_CUT_16_QCF  FN2O_L3.1_L3.3_CUT_50_QCF  FN2O_L3.1_L3.3_CUT_84_QCF
# TIMESTAMP_MIDDLE
# 2012-01-01 00:15:00                        0.615439                        1.692910                        1.303387                        NaN                        NaN                        NaN
# 2012-01-01 00:45:00                        0.357831                        0.479658                        0.340526                        NaN                        NaN                        NaN
# 2012-01-01 01:15:00                        0.299795                        0.349175                        0.300821                        NaN                        NaN                        NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['FN2O_L3.1_L3.3_CUT_16_QCF',
#  'FN2O_L3.1_L3.3_CUT_50_QCF',
#  'FN2O_L3.1_L3.3_CUT_84_QCF']

# %% [markdown]
# ## Plot: gap-filled heatmaps

# %%
fpc.showplot_gapfilled_heatmap()

# %% [markdown]
# ## Plot: Gap-filled cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=0.0002521206, units=r'($\mathrm{kg\ N_2O-N\ ha^{-1}}$)', per_year=True)

# %% [markdown]
# ## Plot: gap-filled cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.0002521206, units=r'($\mathrm{kg\ N_2O-N\ ha^{-1}}$)', per_year=False)

# %% [markdown]
# ## Plot: model feature ranks per year

# %%
fpc.showplot_feature_ranks_per_year()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # Save results to file

# %% [markdown]
# ---

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %%
suffix = "FN2O"

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results)

# %%
# outfile = f"FluxProcessingChain_L4.1_complete_{suffix}"
# results.to_csv(f"{outfile}.csv")  # large file, slow to read
# save_parquet(data=results, filename=f"{outfile}")  # Smaller file, very fast to read

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save flux processing chain results (without input data)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
outfile = f"51.1_FluxProcessingChain_L4.1_{suffix}"
fpc.fpc_df.to_csv(f"{outfile}.csv")  # large file, slow to read
save_parquet(data=fpc.fpc_df, filename=f"{outfile}")  # Smaller file, very fast to read
# Out:
# Saved file 51.1_FluxProcessingChain_L4.1_FN2O.parquet (0.555 seconds).
# '51.1_FluxProcessingChain_L4.1_FN2O.parquet'

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ---

# %% [markdown]
# # **End of notebook**

# %% [markdown]
# ---

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2025-03-05 21:42:48
